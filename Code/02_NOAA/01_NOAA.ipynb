# %%
import matplotlib.pyplot as plt

from dotenv import load_dotenv 
import os 

import pandas as pd
import geopandas as gpd

from datetime import timedelta

import requests
import json

import time

# %% [markdown]
# https://www.ncdc.noaa.gov/cdo-web/webservices/v2

# %%
la_bounds_gdf = gpd.read_file("../../Data/Inputs/Boundary_Shapefile/la_mainland.geojson")

# %%
sensors_gdf = gpd.read_file('../../Data/Outputs/sensors.geojson')

# %%
load_dotenv()

api_key = os.getenv("noaa_key") 
debug = os.getenv("DEBUG", "False")

# %%
headers = {
    "token": api_key
}

# %%
session = requests.Session()
session.headers.update({"token": api_key})

# %%
def get_response(url):
    try: 
        response = requests.get(url,headers=headers)
        data = response.json()
        return data['results']
    except:
        print(response.status_code)

# %%
def to_gdf(results_json):
    results_df = pd.DataFrame(results_json)
    results_gdf = gpd.GeoDataFrame(
   results_df, geometry=gpd.points_from_xy(results_df['longitude'], results_df['latitude']), crs="EPSG:4326"
)
    return results_gdf

# %% [markdown]
# ### Location Categories

# %%
location_categories = get_response('https://www.ncei.noaa.gov/cdo-web/api/v2/locationcategories')
# Out:
# 503

# %%
location_categories

# %% [markdown]
# def get_response(url, headers=headers, retries=3, timeout=60):
#     for attempt in range(retries):
#         try:
#             response = requests.get(url, headers=headers, timeout=timeout)
#             response.raise_for_status()
#             data = response.json()
#             time.sleep(3)
#             return data.get('results', [])
#         except requests.exceptions.HTTPError as e:
#             print(f"HTTP error {e} for URL {url}")
#             return None
#         except requests.exceptions.RequestException as e:
#             print(f"Request error {e}, attempt {attempt + 1}/{retries}")
#         except ValueError as e:
#             print(f"JSON decode error for URL {url}: {e}")
#             return None
#     print(f"Failed to get data from {url} after {retries} attempts")
#     return None

# %%
def get_response(url, session=session, retries=3, timeout=60):
    for attempt in range(retries):
        try:
            print(f"Making request to {url}")
            response = session.get(url, timeout=timeout)
            response.raise_for_status()
            data = response.json()
            time.sleep(3)
            return data.get('results', [])
        except requests.exceptions.HTTPError as e:
            print(f"HTTP error {e} for URL {url}")
            return None
        except requests.exceptions.RequestException as e:
            print(f"Request error {e}, attempt {attempt + 1}/{retries}")
        except ValueError as e:
            print(f"JSON decode error for URL {url}: {e}")
            return None
    print(f"Failed to get data from {url} after {retries} attempts")
    return None

# %% [markdown]
# Finding the ID for the state of California. It's in alphabetical order so we don't need to pull in every option, only the first 10 or so.

# %%
state_data = get_response('https://www.ncei.noaa.gov/cdo-web/api/v2/locations?locationcategoryid=ST&limit=10')

# %%
state_data[4]
# Out:
# {'mindate': '1850-10-01',
#  'maxdate': '2025-12-11',
#  'name': 'California',
#  'datacoverage': 1,
#  'id': 'FIPS:06'}

# %% [markdown]
# ### Finding the FIPS code for Los Angeles County

# %% [markdown]
# https://www.ncdc.noaa.gov/cdo-web/webservices/v2#locations

# %%
counties = get_response('https://www.ncei.noaa.gov/cdo-web/api/v2/locations?locationcategoryid=CNTY&limit=1000&sortfield=name&sortorder=asc&offset=1000')

# %%
counties[733]
# Out:
# {'mindate': '1893-01-01',
#  'maxdate': '2025-12-11',
#  'name': 'Los Angeles County, CA',
#  'datacoverage': 1,
#  'id': 'FIPS:06037'}

# %% [markdown]
# ### Los Angeles County Stations

# %% [markdown]
# https://www.ncdc.noaa.gov/cdo-web/webservices/v2#stations

# %%
la_stations = get_response('https://www.ncei.noaa.gov/cdo-web/api/v2/stations?locationid=FIPS:06037&limit=1000')

# %%
la_stations[:5]
# Out:
# [{'elevation': 863.5,
#   'mindate': '1931-01-01',
#   'maxdate': '2013-12-01',
#   'latitude': 34.4938,
#   'name': 'ACTON ESCONDIDO CANYON, CA US',
#   'datacoverage': 0.8986,
#   'id': 'COOP:040014',
#   'elevationUnit': 'METERS',
#   'longitude': -118.2713},
#  {'elevation': 721.5,
#   'mindate': '1939-09-01',
#   'maxdate': '1992-10-30',
#   'latitude': 34.31667,
#   'name': 'ALISO CANYON FC 446, CA US',
#   'datacoverage': 0.9711,
#   'id': 'COOP:040115',
#   'elevationUnit': 'METERS',
#   'longitude': -118.55},
#  {'elevation': 343.5,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 34.18211,
#   'name': 'ALTADENA, CA US',
#   'datacoverage': 0.9362,
#   'id': 'COOP:040144',
#   'elevationUnit': 'METERS',
#   'longitude': -118.13827},
#  {'elevation': 371.9,
#   'mindate': '1931-01-01',
#   'maxdate': '1974-06-01',
#   'latitude': 34.21667,
#   'name': 'ARROYO SECO RANGER STATION FC508, CA US',
#   'datacoverage': 0.9962,
#   'id': 'COOP:040327',
#   'elevationUnit': 'METERS',
#   'longitude': -118.16667},
#  {'elevation': 27.4,
#   'mindate': '2011-01-01',
#   'maxdate': '2011-12-01',
#   'latitude': 33.338,
#   'name': 'AVALON INLAND, CA US',
#   'datacoverage': 1,
#   'id': 'COOP:040392',
#   'elevationUnit': 'METERS',
#   'longitude': -118.3305}]

# %%
len(la_stations)
# Out:
# 384

# %%
la_stations_gdf = to_gdf(la_stations)

# %%
la_stations_gdf.head()
# Out:
#    elevation     mindate     maxdate  latitude  \
# 0      863.5  1931-01-01  2013-12-01  34.49380
# 1      721.5  1939-09-01  1992-10-30  34.31667
# 2      343.5  1931-01-01  2015-11-01  34.18211
# 3      371.9  1931-01-01  1974-06-01  34.21667
# 4       27.4  2011-01-01  2011-12-01  33.33800
#
#                                       name  datacoverage           id  \
# 0            ACTON ESCONDIDO CANYON, CA US        0.8986  COOP:040014
# 1               ALISO CANYON FC 446, CA US        0.9711  COOP:040115
# 2                          ALTADENA, CA US        0.9362  COOP:040144
# 3  ARROYO SECO RANGER STATION FC508, CA US        0.9962  COOP:040327
# 4                     AVALON INLAND, CA US        1.0000  COOP:040392
#
#   elevationUnit  longitude                     geometry
# 0        METERS -118.27130    POINT (-118.2713 34.4938)
# 1        METERS -118.55000     POINT (-118.55 34.31667)
# 2        METERS -118.13827  POINT (-118.13827 34.18211)
# 3        METERS -118.16667  POINT (-118.16667 34.21667)
# 4        METERS -118.33050     POINT (-118.3305 33.338)

# %% [markdown]
# I need to verify that this is the correct crs for the NOAA data, but since it's lat/long I'll assume it's ok for now

# %% [markdown]
# ### La County Recents

# %% [markdown]
# I take the extent from OpenAq/01_Data_Collection

# %% [markdown]
# The absolute oldest data for LA County in the OpenAQ dataset is from 2016-03-06, so I use this in the NOAA url as the start date

# %%
sensors_gdf.sort_values(by='datetime_first.utc').head()
# Out:
#     sensors_id  station_id pollutant                  name  \
# 0         1502         847     PM2.5      South Long Beach
# 32        8683        1575       SO₂  Los Angeles - N. Mai
# 33        2794        1585        O₃                Upland
# 34        2793        1585      PM10                Upland
# 35        2792        1585     PM2.5                Upland
#
#           datetime_first.utc         datetime_last.utc             timezone  \
# 0  2016-03-06 20:00:00+00:00 2022-05-05 22:00:00+00:00  America/Los_Angeles
# 32 2016-03-06 20:00:00+00:00 2017-06-07 21:00:00+00:00  America/Los_Angeles
# 33 2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00  America/Los_Angeles
# 34 2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00  America/Los_Angeles
# 35 2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00  America/Los_Angeles
#
#     is_mobile  is_monitor                                            bounds  \
# 0       False        True  [-118.175278, 33.792221, -118.175278, 33.792221]
# 32      False        True          [-118.2417, 34.0669, -118.2417, 34.0669]
# 33      False        True          [-117.6733, 34.0986, -117.6733, 34.0986]
# 34      False        True          [-117.6733, 34.0986, -117.6733, 34.0986]
# 35      False        True          [-117.6733, 34.0986, -117.6733, 34.0986]
#
#     ...   country.name owner.id                         owner.name  \
# 0   ...  United States        4  Unknown Governmental Organization
# 32  ...  United States        4  Unknown Governmental Organization
# 33  ...  United States        4  Unknown Governmental Organization
# 34  ...  United States        4  Unknown Governmental Organization
# 35  ...  United States        4  Unknown Governmental Organization
#
#     provider.id provider.name  coordinates.latitude coordinates.longitude  \
# 0           119        AirNow             33.792221           -118.175278
# 32          119        AirNow             34.066900           -118.241700
# 33          119        AirNow             34.098600           -117.673300
# 34          119        AirNow             34.098600           -117.673300
# 35          119        AirNow             34.098600           -117.673300
#
#        instrument_name  instrument_id                     geometry
# 0   Government Monitor              2  POINT (-118.17528 33.79222)
# 32  Government Monitor              2    POINT (-118.2417 34.0669)
# 33  Government Monitor              2    POINT (-117.6733 34.0986)
# 34  Government Monitor              2    POINT (-117.6733 34.0986)
# 35  Government Monitor              2    POINT (-117.6733 34.0986)
#
# [5 rows x 22 columns]

# %%
recent_stations = get_response('https://www.ncei.noaa.gov/cdo-web/api/v2/stations?locationid=FIPS:06037&startdate=2016-03-06&extent=33.7046743723892,-118.944703049253,34.823304156602,-117.646385981235&limit=1000')

# %%
recent_stations_gdf = to_gdf(recent_stations)

# %%
recent_stations_gdf.head()
# Out:
#    elevation     mindate     maxdate   latitude                       name  \
# 0      155.8  2008-09-23  2024-05-24  34.168900    GLENDALE 2.4 WSW, CA US
# 1       88.1  2008-10-16  2019-12-04  33.937285    WHITTIER 3.6 ESE, CA US
# 2       61.0  2008-10-31  2022-06-04  33.790180     TORRANCE 2.8 SW, CA US
# 3      403.3  2008-11-10  2024-03-07  34.187426    ALTADENA 0.7 ESE, CA US
# 4      207.9  2008-12-11  2017-03-06  34.078600  MONTE NIDO 0.2 SSW, CA US
#
#    datacoverage                 id elevationUnit   longitude  \
# 0        0.9999  GHCND:US1CALA0001        METERS -118.294700
# 1        0.1124  GHCND:US1CALA0002        METERS -117.984379
# 2        0.9754  GHCND:US1CALA0003        METERS -118.336890
# 3        0.6690  GHCND:US1CALA0005        METERS -118.124477
# 4        0.8517  GHCND:US1CALA0008        METERS -118.687000
#
#                       geometry
# 0    POINT (-118.2947 34.1689)
# 1  POINT (-117.98438 33.93728)
# 2  POINT (-118.33689 33.79018)
# 3  POINT (-118.12448 34.18743)
# 4     POINT (-118.687 34.0786)

# %%
recent_stations_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   elevation      129 non-null    float64
#  1   mindate        129 non-null    object
#  2   maxdate        129 non-null    object
#  3   latitude       129 non-null    float64
#  4   name           129 non-null    object
#  5   datacoverage   129 non-null    float64
#  6   id             129 non-null    object
#  7   elevationUnit  129 non-null    object
#  8   longitude      129 non-null    float64
#  9   geometry       129 non-null    geometry
# dtypes: float64(4), geometry(1), object(5)
# memory usage: 10.2+ KB

# %%
fig, ax = plt.subplots(figsize=(10, 10), label='Inline label');
recent_stations_gdf.plot(ax=ax, color='none', edgecolor='red');
la_bounds_gdf.plot(ax=ax, color='none', edgecolor='black');
ax.set_title('NOAA Stations in LA County with Data After 2016-03-06');

# %% [markdown]
# ### Datasets

# %% [markdown]
# https://www.ncdc.noaa.gov/cdo-web/webservices/v2#datasets

# %%
all_datasets = get_response('https://www.ncei.noaa.gov/cdo-web/api/v2/datasets')

# %%
all_datasets
# Out:
# [{'uid': 'gov.noaa.ncdc:C00861',
#   'mindate': '1763-01-01',
#   'maxdate': '2025-12-10',
#   'name': 'Daily Summaries',
#   'datacoverage': 1,
#   'id': 'GHCND'},
#  {'uid': 'gov.noaa.ncdc:C00946',
#   'mindate': '1763-01-01',
#   'maxdate': '2025-11-01',
#   'name': 'Global Summary of the Month',
#   'datacoverage': 1,
#   'id': 'GSOM'},
#  {'uid': 'gov.noaa.ncdc:C00947',
#   'mindate': '1763-01-01',
#   'maxdate': '2025-01-01',
#   'name': 'Global Summary of the Year',
#   'datacoverage': 1,
#   'id': 'GSOY'},
#  {'uid': 'gov.noaa.ncdc:C00345',
#   'mindate': '1991-06-05',
#   'maxdate': '2025-12-11',
#   'name': 'Weather Radar (Level II)',
#   'datacoverage': 0.95,
#   'id': 'NEXRAD2'},
#  {'uid': 'gov.noaa.ncdc:C00708',
#   'mindate': '1994-05-20',
#   'maxdate': '2025-12-09',
#   'name': 'Weather Radar (Level III)',
#   'datacoverage': 0.95,
#   'id': 'NEXRAD3'},
#  {'uid': 'gov.noaa.ncdc:C00821',
#   'mindate': '2010-01-01',
#   'maxdate': '2010-01-01',
#   'name': 'Normals Annual/Seasonal',
#   'datacoverage': 1,
#   'id': 'NORMAL_ANN'},
#  {'uid': 'gov.noaa.ncdc:C00823',
#   'mindate': '2010-01-01',
#   'maxdate': '2010-12-31',
#   'name': 'Normals Daily',
#   'datacoverage': 1,
#   'id': 'NORMAL_DLY'},
#  {'uid': 'gov.noaa.ncdc:C00824',
#   'mindate': '2010-01-01',
#   'maxdate': '2010-12-31',
#   'name': 'Normals Hourly',
#   'datacoverage': 1,
#   'id': 'NORMAL_HLY'},
#  {'uid': 'gov.noaa.ncdc:C00822',
#   'mindate': '2010-01-01',
#   'maxdate': '2010-12-01',
#   'name': 'Normals Monthly',
#   'datacoverage': 1,
#   'id': 'NORMAL_MLY'},
#  {'uid': 'gov.noaa.ncdc:C00505',
#   'mindate': '1970-05-12',
#   'maxdate': '2014-01-01',
#   'name': 'Precipitation 15 Minute',
#   'datacoverage': 0.25,
#   'id': 'PRECIP_15'},
#  {'uid': 'gov.noaa.ncdc:C00313',
#   'mindate': '1900-01-01',
#   'maxdate': '2014-01-01',
#   'name': 'Precipitation Hourly',
#   'datacoverage': 1,
#   'id': 'PRECIP_HLY'}]

# %%
len(all_datasets)
# Out:
# 11

# %% [markdown]
# #### Datasets available within LA County and with most recent entries after 2016:

# %%
la_county_datasets = get_response('https://www.ncei.noaa.gov/cdo-web/api/v2/datasets?locationid=FIPS:06037&startdate=2016-03-06&extent=33.7046743723892,-118.944703049253,34.823304156602,-117.646385981235&limit=15')

# %%
la_county_datasets
# Out:
# [{'uid': 'gov.noaa.ncdc:C00861',
#   'mindate': '1763-01-01',
#   'maxdate': '2025-12-10',
#   'name': 'Daily Summaries',
#   'datacoverage': 1,
#   'id': 'GHCND'},
#  {'uid': 'gov.noaa.ncdc:C00946',
#   'mindate': '1763-01-01',
#   'maxdate': '2025-11-01',
#   'name': 'Global Summary of the Month',
#   'datacoverage': 1,
#   'id': 'GSOM'},
#  {'uid': 'gov.noaa.ncdc:C00947',
#   'mindate': '1763-01-01',
#   'maxdate': '2025-01-01',
#   'name': 'Global Summary of the Year',
#   'datacoverage': 1,
#   'id': 'GSOY'},
#  {'uid': 'gov.noaa.ncdc:C00345',
#   'mindate': '1991-06-05',
#   'maxdate': '2025-12-11',
#   'name': 'Weather Radar (Level II)',
#   'datacoverage': 0.95,
#   'id': 'NEXRAD2'},
#  {'uid': 'gov.noaa.ncdc:C00708',
#   'mindate': '1994-05-20',
#   'maxdate': '2025-12-09',
#   'name': 'Weather Radar (Level III)',
#   'datacoverage': 0.95,
#   'id': 'NEXRAD3'}]

# %%
len(la_county_datasets)
# Out:
# 5

# %%
la_county_datasets[0]
# Out:
# {'uid': 'gov.noaa.ncdc:C00861',
#  'mindate': '1763-01-01',
#  'maxdate': '2025-12-10',
#  'name': 'Daily Summaries',
#  'datacoverage': 1,
#  'id': 'GHCND'}

# %% [markdown]
# This looks like the most promising dataset ^

# %% [markdown]
# ### Daily Summaries

# %%
la_ds_stations = get_response('https://www.ncei.noaa.gov/cdo-web/api/v2/stations?datasetid=GHCND&locationid=FIPS:06037&startdate=2016-03-06&extent=33.7046743723892,-118.944703049253,34.823304156602,-117.646385981235&limit=1000')
# Out:
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/stations?datasetid=GHCND&locationid=FIPS:06037&startdate=2016-03-06&extent=33.7046743723892,-118.944703049253,34.823304156602,-117.646385981235&limit=1000

# %%
la_ds_gdf = to_gdf(la_ds_stations)

# %%
dt_cols = la_ds_gdf.columns[1:3]
dt_cols
# Out:
# Index(['mindate', 'maxdate'], dtype='object')

# %%
for col in dt_cols:
    la_ds_gdf[col] = pd.to_datetime(la_ds_gdf[col])

# %%
la_ds_gdf.head()
# Out:
#    elevation    mindate    maxdate   latitude                       name  \
# 0      155.8 2008-09-23 2024-05-24  34.168900    GLENDALE 2.4 WSW, CA US
# 1       88.1 2008-10-16 2019-12-04  33.937285    WHITTIER 3.6 ESE, CA US
# 2       61.0 2008-10-31 2022-06-04  33.790180     TORRANCE 2.8 SW, CA US
# 3      403.3 2008-11-10 2024-03-07  34.187426    ALTADENA 0.7 ESE, CA US
# 4      207.9 2008-12-11 2017-03-06  34.078600  MONTE NIDO 0.2 SSW, CA US
#
#    datacoverage                 id elevationUnit   longitude  \
# 0        0.9829  GHCND:US1CALA0001        METERS -118.294700
# 1        0.1124  GHCND:US1CALA0002        METERS -117.984379
# 2        0.9629  GHCND:US1CALA0003        METERS -118.336890
# 3        0.5791  GHCND:US1CALA0005        METERS -118.124477
# 4        0.8517  GHCND:US1CALA0008        METERS -118.687000
#
#                       geometry
# 0    POINT (-118.2947 34.1689)
# 1  POINT (-117.98438 33.93728)
# 2  POINT (-118.33689 33.79018)
# 3  POINT (-118.12448 34.18743)
# 4     POINT (-118.687 34.0786)

# %%
la_ds_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   elevation      114 non-null    float64
#  1   mindate        114 non-null    datetime64[ns]
#  2   maxdate        114 non-null    datetime64[ns]
#  3   latitude       114 non-null    float64
#  4   name           114 non-null    object
#  5   datacoverage   114 non-null    float64
#  6   id             114 non-null    object
#  7   elevationUnit  114 non-null    object
#  8   longitude      114 non-null    float64
#  9   geometry       114 non-null    geometry
# dtypes: datetime64[ns](2), float64(4), geometry(1), object(3)
# memory usage: 9.0+ KB

# %%
la_ds_gdf.to_file('../../Data/Outputs/la_ds_gdf.geojson',driver='geojson')

# %%
fig, ax = plt.subplots(figsize=(10, 10), label='Inline label');
sensors_gdf[sensors_gdf['pollutant']=='PM2.5'].plot(ax=ax, color='none', edgecolor='red', label='PM2.5 Sensor');
la_ds_gdf.plot(ax=ax, color='none', edgecolor='blue', label='NOAA Daily Summary Station');
la_bounds_gdf.plot(ax=ax, color='none', edgecolor='black');
ax.legend()
ax.set_title('Distribution of NOAA Daily Summaries vs OpenAQ PM2.5 Stations in LA County');

# %% [markdown]
# The Daily Summaries stations have an even spatial distribution, including in areas where the OpenAQ sensors are far more sparse. This should help with predictions in this area.

# %% [markdown]
# ### Investigating Daily Summaries

# %%
la_ds_gdf.iloc[0]
# Out:
# elevation                            155.8
# mindate                2008-09-23 00:00:00
# maxdate                2024-05-24 00:00:00
# latitude                           34.1689
# name               GLENDALE 2.4 WSW, CA US
# datacoverage                        0.9829
# id                       GHCND:US1CALA0001
# elevationUnit                       METERS
# longitude                        -118.2947
# geometry         POINT (-118.2947 34.1689)
# Name: 0, dtype: object

# %%
la_ds_gdf.iloc[0]['id']
# Out:
# 'GHCND:US1CALA0001'

# %%
US1CALA0001_ds = get_response('https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2022-06-02&enddate=2023-06-01')

# %%
US1CALA0001_ds_df = pd.DataFrame(US1CALA0001_ds)

# %%
US1CALA0001_ds_df.head()
# Out:
#                   date datatype            station attributes  value
# 0  2022-06-02T00:00:00     PRCP  GHCND:US1CALA0001   ,,N,0800    0.0
# 1  2022-06-02T00:00:00     SNOW  GHCND:US1CALA0001   ,,N,0800    0.0
# 2  2022-06-02T00:00:00     SNWD  GHCND:US1CALA0001   ,,N,0800    0.0
# 3  2022-06-02T00:00:00     WESD  GHCND:US1CALA0001   ,,N,0800    0.0
# 4  2022-06-02T00:00:00     WESF  GHCND:US1CALA0001   ,,N,0800    0.0

# %%
US1CALA0001_ds_df['datatype'].unique()
# Out:
# array(['PRCP', 'SNOW', 'SNWD', 'WESD', 'WESF'], dtype=object)

# %%
US1CALA0001_ds_df[US1CALA0001_ds_df['datatype'] == 'WESD'].head()
# Out:
#                    date datatype            station attributes  value
# 3   2022-06-02T00:00:00     WESD  GHCND:US1CALA0001   ,,N,0800    0.0
# 8   2022-06-03T00:00:00     WESD  GHCND:US1CALA0001   ,,N,0800    0.0
# 13  2022-06-04T00:00:00     WESD  GHCND:US1CALA0001   ,,N,0800    0.0
# 18  2022-06-05T00:00:00     WESD  GHCND:US1CALA0001   ,,N,0800    0.0
# 23  2022-06-06T00:00:00     WESD  GHCND:US1CALA0001   ,,N,0800    0.0

# %%
US1CALA0001_ds_df[US1CALA0001_ds_df['datatype'] == 'WESD']['value'].unique()
# Out:
# array([0.])

# %%
US1CALA0001_ds_df[US1CALA0001_ds_df['datatype'] == 'WESF'].head()
# Out:
#                    date datatype            station attributes  value
# 4   2022-06-02T00:00:00     WESF  GHCND:US1CALA0001   ,,N,0800    0.0
# 9   2022-06-03T00:00:00     WESF  GHCND:US1CALA0001   ,,N,0800    0.0
# 14  2022-06-04T00:00:00     WESF  GHCND:US1CALA0001   ,,N,0800    0.0
# 19  2022-06-05T00:00:00     WESF  GHCND:US1CALA0001   ,,N,0800    0.0
# 24  2022-06-06T00:00:00     WESF  GHCND:US1CALA0001   ,,N,0800    0.0

# %%
la_ds_gdf.iloc[0]
# Out:
# elevation                            155.8
# mindate                2008-09-23 00:00:00
# maxdate                2024-05-24 00:00:00
# latitude                           34.1689
# name               GLENDALE 2.4 WSW, CA US
# datacoverage                        0.9829
# id                       GHCND:US1CALA0001
# elevationUnit                       METERS
# longitude                        -118.2947
# geometry         POINT (-118.2947 34.1689)
# Name: 0, dtype: object

# %%
start_date = '2010-01-01'
end_date = '2011-01-01'

# %%
US1CALA0001_ds_2010 = get_response(f'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate={start_date}&enddate={end_date}&limit=1000')
US1CALA0001_ds_2010_df = pd.DataFrame(US1CALA0001_ds_2010)
US1CALA0001_ds_2010_df['datatype'].unique()
# Out:
# array(['PRCP', 'SNOW'], dtype=object)

# %%
US1CALA0001_ds_2010_df.head()
# Out:
#                   date datatype            station attributes  value
# 0  2010-01-01T00:00:00     PRCP  GHCND:US1CALA0001   ,,N,0800    0.0
# 1  2010-01-01T00:00:00     SNOW  GHCND:US1CALA0001   ,,N,0800    0.0
# 2  2010-01-02T00:00:00     PRCP  GHCND:US1CALA0001   ,,N,0800    0.0
# 3  2010-01-02T00:00:00     SNOW  GHCND:US1CALA0001   ,,N,0800    0.0
# 4  2010-01-03T00:00:00     PRCP  GHCND:US1CALA0001   ,,N,0800    0.0

# %%
US1CALA0001_ds_2010_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        732 non-null    object
#  1   datatype    732 non-null    object
#  2   station     732 non-null    object
#  3   attributes  732 non-null    object
#  4   value       732 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 28.7+ KB

# %% [markdown]
# ### Complete DS Dataset

# %% [markdown]
# The oldest OpenAQ reading in LA is from 2016-03-06, so I will set this as the mindate for NOAA

# %% [markdown]
# OpenAQ states that their dates are in `YYYY-MM-DD` format, as does NOAA:
#
# https://docs.openaq.org/using-the-api/dates-datetimes
#
# https://www.ncdc.noaa.gov/cdo-web/webservices/v2#data

# %%
len(la_ds_gdf)
# Out:
# 114

# %% [markdown]
# There are 114 daily summary stations in LA county.

# %%
la_ds_gdf.head()
# Out:
#    elevation    mindate    maxdate   latitude                       name  \
# 0      155.8 2008-09-23 2024-05-24  34.168900    GLENDALE 2.4 WSW, CA US
# 1       88.1 2008-10-16 2019-12-04  33.937285    WHITTIER 3.6 ESE, CA US
# 2       61.0 2008-10-31 2022-06-04  33.790180     TORRANCE 2.8 SW, CA US
# 3      403.3 2008-11-10 2024-03-07  34.187426    ALTADENA 0.7 ESE, CA US
# 4      207.9 2008-12-11 2017-03-06  34.078600  MONTE NIDO 0.2 SSW, CA US
#
#    datacoverage                 id elevationUnit   longitude  \
# 0        0.9829  GHCND:US1CALA0001        METERS -118.294700
# 1        0.1124  GHCND:US1CALA0002        METERS -117.984379
# 2        0.9629  GHCND:US1CALA0003        METERS -118.336890
# 3        0.5791  GHCND:US1CALA0005        METERS -118.124477
# 4        0.8517  GHCND:US1CALA0008        METERS -118.687000
#
#                       geometry
# 0    POINT (-118.2947 34.1689)
# 1  POINT (-117.98438 33.93728)
# 2  POINT (-118.33689 33.79018)
# 3  POINT (-118.12448 34.18743)
# 4     POINT (-118.687 34.0786)

# %%
la_ds_gdf.shape
# Out:
# (114, 10)

# %%
la_ds_gdf.columns
# Out:
# Index(['elevation', 'mindate', 'maxdate', 'latitude', 'name', 'datacoverage',
#        'id', 'elevationUnit', 'longitude', 'geometry'],
#       dtype='object')

# %%
la_ds_gdf['maxdate'][0].date()
# Out:
# datetime.date(2024, 5, 24)

# %%
la_ds_gdf['maxdate'][0]
# Out:
# Timestamp('2024-05-24 00:00:00')

# %% [markdown]
# all_results = []
# limit = 1000
# offset = 0
# start_date = pd.to_datetime('2016-03-06')
# station_id = la_ds_gdf['id'][0]
#
# while True:
#     url = f'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid={station_id}&units=standard&startdate={start_date.date()}&enddate={end_date.date()}&limit={limit}&offset={offset}'
#     results = get_response(url)
#
#     if not results:
#         break

# %% [markdown]
# mem = get_response(f'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid={la_ds_gdf['id'][0]}&units=standard&startdate={start_date.date()}&enddate={end_date.date()}&limit={1000}&offset={100000}')

# %%
year_delta = timedelta(days=365)

# %%
1/'i'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 1/'i'
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
for i in [1,2,4,'1',2,5]:
    try:
        mem = 1/i
        print(mem)
    except TypeError:
        print("Type error you fuqqin eejit")
    except:
        print('Unknown error')
# Out:
# 1.0
# 0.5
# 0.25
# Type error you fuqqin eejit
# 0.5
# 0.2

# %% [markdown]
# ^ A try/except block won't break the loop

# %% [markdown]
# def get_response(url, headers=headers, retries=3, timeout=60):
#     for attempt in range(retries):
#         try:
#             # I don't want to print my actual token, so I modify the session.headers response
#             print(f"Making request to {url} with headers: {str(session.headers).split(':')[:-2]}")
#             response = requests.get(url, headers=headers, timeout=timeout)
#             response.raise_for_status()
#             data = response.json()
#             time.sleep(3)
#             return data.get('results', [])
#         except requests.exceptions.HTTPError as e:
#             print(f"HTTP error {e} for URL {url}")
#             return None
#         except requests.exceptions.RequestException as e:
#             print(f"Request error {e}, attempt {attempt + 1}/{retries}")
#         except ValueError as e:
#             print(f"JSON decode error for URL {url}: {e}")
#             return None
#     print(f"Failed to get data from {url} after {retries} attempts")
#     return None

# %% [markdown]
# def download_station_data(staion = int, dataset = str):
#
#     all_results = []
#
#     year_delta = timedelta(days = 365)
#
#     start_date = pd.to_datetime("2016-03-06")
#     end_date = start_date + year_delta
#     maxdate = la_ds_gdf['maxdate'][station]
#     limit = 1000
#
#     while start_date < maxdate:
#
#         offset = 0
#         year_has_data = False
#
#         while True:
#             url = f"https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid={dataset}&stationid={la_ds_gdf['id'][station]}&units=standard&startdate={start_date.date()}&enddate={end_date.date()}&limit={limit}&offset={offset}"
#             results = get_response(url)
#
#             if results is None:
#                 print(f"ERROR: request failed for URL:\n{url}")
#                 break
#
#             if not results:
#                 break
#
#             year_has_data = True
#             all_results.extend(results)
#
#             offset += limit
#
#         if not year_has_data:
#             break
#
#         start_date += year_delta
#         end_date += year_delta
#
#     results_df = pd.DataFrame(all_results)
#     results_df['longitude'] = la_ds_gdf.iloc[station]['longitude']
#     results_df['latitude'] = la_ds_gdf.iloc[station]['latitude']
#     results_gdf = gpd.GeoDataFrame(results_df, geometry = gpd.points_from_xy(results_df['longitude'], results_df['latitude']), crs="EPSG:4326")
#
#     return results_gdf

# %% [markdown]
# la_GHCND = gpd.GeoDataFrame(columns = ['data', 'datatype', 'station', 'attributes', 'value', 'longitude', 'latitude', 'geometry'])

# %%
for station in range(len(la_ds_gdf)):
    results_gdf = download_station_data(station, 'GHCND')
    la_GHCND = pd.concat([la_GHCND, results_gdf], ignore_index=True)
# Out:
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# HTTP error 503 Server Error: Service Unavailable for url: https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=2000 for URL https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=2000
# ERROR: request failed for URL:
# https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=2000
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2022-03-05&enddate=2023-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2022-03-05&enddate=2023-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2022-03-05&enddate=2023-03-05&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2023-03-05&enddate=2024-03-04&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2023-03-05&enddate=2024-03-04&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2023-03-05&enddate=2024-03-04&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2024-03-04&enddate=2025-03-04&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0001&units=standard&startdate=2024-03-04&enddate=2025-03-04&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# /tmp/ipykernel_34997/3492136261.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   la_GHCND = pd.concat([la_GHCND, results_gdf], ignore_index=True)
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0002&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0002&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0002&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0003&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0003&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0003&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0003&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0003&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0003&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0003&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# HTTP error 503 Server Error: Service Unavailable for url: https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0003&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0 for URL https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0003&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0
# ERROR: request failed for URL:
# https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0003&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# HTTP error 503 Server Error: Service Unavailable for url: https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000 for URL https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000
# ERROR: request failed for URL:
# https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2022-03-05&enddate=2023-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2022-03-05&enddate=2023-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2023-03-05&enddate=2024-03-04&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2023-03-05&enddate=2024-03-04&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2024-03-04&enddate=2025-03-04&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0005&units=standard&startdate=2024-03-04&enddate=2025-03-04&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0008&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0008&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# HTTP error 503 Server Error: Service Unavailable for url: https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=1000 for URL https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=1000
# ERROR: request failed for URL:
# https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0009&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=1000
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# HTTP error 503 Server Error: Service Unavailable for url: https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=0 for URL https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=0
# ERROR: request failed for URL:
# https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0010&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=0
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0011&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0011&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0011&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0011&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0014&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0014&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0014&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0014&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0014&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0014&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0014&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# HTTP error 503 Server Error: Service Unavailable for url: https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0014&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0 for URL https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0014&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0
# ERROR: request failed for URL:
# https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0014&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0015&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0015&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0015&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0015&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0015&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0015&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2022-03-05&enddate=2023-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2022-03-05&enddate=2023-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2023-03-05&enddate=2024-03-04&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2023-03-05&enddate=2024-03-04&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2024-03-04&enddate=2025-03-04&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2024-03-04&enddate=2025-03-04&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2025-03-04&enddate=2026-03-04&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0021&units=standard&startdate=2025-03-04&enddate=2026-03-04&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0023&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0023&units=standard&startdate=2016-03-06&enddate=2017-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:US1CALA0023&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# ...
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=3000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2017-03-06&enddate=2018-03-06&limit=1000&offset=4000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=3000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2018-03-06&enddate=2019-03-06&limit=1000&offset=4000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=3000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2019-03-06&enddate=2020-03-05&limit=1000&offset=4000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=3000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2020-03-05&enddate=2021-03-05&limit=1000&offset=4000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=3000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2021-03-05&enddate=2022-03-05&limit=1000&offset=4000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2022-03-05&enddate=2023-03-05&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2022-03-05&enddate=2023-03-05&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2022-03-05&enddate=2023-03-05&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2022-03-05&enddate=2023-03-05&limit=1000&offset=3000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2022-03-05&enddate=2023-03-05&limit=1000&offset=4000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2023-03-05&enddate=2024-03-04&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2023-03-05&enddate=2024-03-04&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2023-03-05&enddate=2024-03-04&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2023-03-05&enddate=2024-03-04&limit=1000&offset=3000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2023-03-05&enddate=2024-03-04&limit=1000&offset=4000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2024-03-04&enddate=2025-03-04&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2024-03-04&enddate=2025-03-04&limit=1000&offset=1000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2024-03-04&enddate=2025-03-04&limit=1000&offset=2000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2024-03-04&enddate=2025-03-04&limit=1000&offset=3000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2024-03-04&enddate=2025-03-04&limit=1000&offset=4000 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# Making request to https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2025-03-04&enddate=2026-03-04&limit=1000&offset=0 with headers: {'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'}
# HTTP error 503 Server Error: Service Unavailable for url: https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2025-03-04&enddate=2026-03-04&limit=1000&offset=0 for URL https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2025-03-04&enddate=2026-03-04&limit=1000&offset=0
# ERROR: request failed for URL:
# https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00093197&units=standard&startdate=2025-03-04&enddate=2026-03-04&limit=1000&offset=0

# %% [markdown]
# 1. Handle completely null dataframes:
#
#    ``` Python:
#    /tmp/ipykernel_34997/3492136261.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   la_GHCND = pd.concat([la_GHCND, results_gdf], ignore_index=True)
#   ```
#
# 2. Revise `print(f"Making request to {url} with headers: {session.headers}")` so that we don't print our token

# %%
la_GHCND.head()
# Out:
#   data datatype            station attributes  value  longitude  latitude  \
# 0  NaN     PRCP  GHCND:US1CALA0001   ,,N,0800   1.57  -118.2947   34.1689
# 1  NaN     SNOW  GHCND:US1CALA0001   ,,N,0800   0.00  -118.2947   34.1689
# 2  NaN     SNWD  GHCND:US1CALA0001   ,,N,0800   0.00  -118.2947   34.1689
# 3  NaN     PRCP  GHCND:US1CALA0001   ,,N,0800   0.21  -118.2947   34.1689
# 4  NaN     SNOW  GHCND:US1CALA0001   ,,N,0800   0.00  -118.2947   34.1689
#
#                     geometry                 date
# 0  POINT (-118.2947 34.1689)  2016-03-06T00:00:00
# 1  POINT (-118.2947 34.1689)  2016-03-06T00:00:00
# 2  POINT (-118.2947 34.1689)  2016-03-06T00:00:00
# 3  POINT (-118.2947 34.1689)  2016-03-07T00:00:00
# 4  POINT (-118.2947 34.1689)  2016-03-07T00:00:00

# %%
la_GHCND.to_file("../../Data/Outputs/LA_GHCND.geojson", driver="GeoJSON")

# %% [markdown]
# la_GHCND_backup = la_GHCND

# %% [markdown]
# la_GHCND_backup.to_file("../../Data/Outputs/LA_GHCND_backup.geojson", driver="GeoJSON")

# %%
gpd.read_file("../../Data/Outputs/LA_GHCND.geojson")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gpd.read_file("../../Data/Outputs/LA_GHCND.geojson")
#
# NameError: name 'gpd' is not defined

# %%
la_GHCND.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 561855 entries, 0 to 561854
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   data        0 non-null       object
#  1   datatype    561855 non-null  object
#  2   station     561855 non-null  object
#  3   attributes  561855 non-null  object
#  4   value       561855 non-null  float64
#  5   longitude   561855 non-null  float64
#  6   latitude    561855 non-null  float64
#  7   geometry    561855 non-null  geometry
#  8   date        561855 non-null  object
# dtypes: float64(3), geometry(1), object(5)
# memory usage: 38.6+ MB

# %%
str(session.headers).split(':')[:-2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 str(session.headers).split(':')[:-2].reduce()
#
# AttributeError: 'list' object has no attribute 'reduce'

# %%
print(list(session.headers)[:-1])
# Out:
# ['User-Agent', 'Accept-Encoding', 'Accept', 'Connection']

# %%
print(type(session.headers))
# Out:
# <class 'requests.structures.CaseInsensitiveDict'>

# %%
1/0

# %%
session.headers.keys()
# Out:
# KeysView({'User-Agent': 'python-requests/2.32.5', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'token': 'QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk'})

# %%
list(session.headers)
# Out:
# ['User-Agent', 'Accept-Encoding', 'Accept', 'Connection', 'token']

# %%
list(session.headers.keys())[:-1]
# Out:
# ['User-Agent', 'Accept-Encoding', 'Accept', 'Connection']

# %%
print(session.headers['User-Agent'], session.headers['Accept-Encoding'])
# Out:
#   Cell In[88], line 1
#     print(session.headers['User-Agent')
#                                       ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %% [markdown]
# ----

# %% [markdown]
# ### Attempt at further refining download_station_data()

# %%
def get_response(url, headers=headers, retries=3, timeout=60):
    for attempt in range(retries):
        try:
            # I don't want to print my actual token, so I modify the session.headers response
            # print(f"Making request to {url} with headers: {str(session.headers).split(':')[:-2]}")
            response = requests.get(url, headers=headers, timeout=timeout)
            response.raise_for_status()
            data = response.json()
            time.sleep(3)
            return data.get('results', [])
        except requests.exceptions.HTTPError as e:
            print(f"HTTP error {e} for URL {url}")
            return None
        except requests.exceptions.RequestException as e:
            print(f"Request error {e}, attempt {attempt + 1}/{retries}")
        except ValueError as e:
            print(f"JSON decode error for URL {url}: {e}")
            return None
    print(f"Failed to get data from {url} after {retries} attempts")
    return None

# %%
def download_station_data(staion = int, dataset = str):
    
    all_results = []
    all_messages = []
    
    year_delta = timedelta(days = 365)
    
    start_date = pd.to_datetime("2016-03-06")
    end_date = start_date + year_delta
    maxdate = la_ds_gdf['maxdate'][station]
    limit = 1000
    
    while start_date < maxdate:
    
        offset = 0
        year_has_data = False
    
        # ---------- PAGING LOOP ----------
        while True:
            url = (
                f"https://www.ncei.noaa.gov/cdo-web/api/v2/data?"
                f"datasetid={dataset}&stationid={la_ds_gdf['id'][station]}"
                f"&units=standard&startdate={start_date.date()}"
                f"&enddate={end_date.date()}"
                f"&limit={limit}&offset={offset}"
            )
    
            results = get_response(url)
    
            # --- if get_response failed, STOP with proper error
            if results is None:
                all_messages.extend(f"ERROR: request failed for URL:\n{url}")
                break
    
            # --- if page is empty, stop paging for this year
            if not results:
                break
    
            # add rows
            year_has_data = True
            all_results.extend(results)
    
            # next page
            offset += limit
            time.sleep(2)
    
        # ---------- AFTER PAGING ----------
        if not year_has_data:
            # no data for this year means we are done
            break
    
        # advance to next year
        start_date += year_delta
        end_date += year_delta

    results_df = pd.DataFrame(all_results)
    results_df['longitude'] = la_ds_gdf.iloc[station]['longitude']
    results_df['latitude'] = la_ds_gdf.iloc[station]['latitude']
    results_gdf = gpd.GeoDataFrame(results_df, geometry = gpd.points_from_xy(results_df['longitude'], results_df['latitude']), crs="EPSG:4326")
    messages_df = pd.DataFrame(all_messages)
    
    return results_gdf, messages_df

# %%
for station in range(len(la_ds_gdf)):
    results_gdf, messages = download_station_data(station, 'GHCND')
    la_GHCND = pd.concat([la_GHCND, results_gdf], ignore_index=True)
    all_messages.extend(messages)

# %% [markdown]
# This still:
#
# 1. Doesn't properly handle all nulls
# 2. Still will display api key

# %% [markdown]
# print("API key:", api_key)

# %%
1/0

# %%
test_gdf = gpd.GeoDataFrame(test_df, geometry = gpd.points_from_xy(test_df['longitude'], test_df['latitude']), crs="EPSG:4326")

# %%
test2_gdf = test_gdf

# %%
gdf_combined = pd.concat([test_gdf, gdf_combined], ignore_index=True)

# %%
gdf_combined
# Out:
#                       date datatype            station attributes  value  \
# 0      2016-03-06T00:00:00     PRCP  GHCND:US1CALA0001   ,,N,0800   1.57
# 1      2016-03-06T00:00:00     SNOW  GHCND:US1CALA0001   ,,N,0800   0.00
# 2      2016-03-06T00:00:00     SNWD  GHCND:US1CALA0001   ,,N,0800   0.00
# 3      2016-03-07T00:00:00     PRCP  GHCND:US1CALA0001   ,,N,0800   0.21
# 4      2016-03-07T00:00:00     SNOW  GHCND:US1CALA0001   ,,N,0800   0.00
# ...                    ...      ...                ...        ...    ...
# 40453  2024-05-24T00:00:00     PRCP  GHCND:US1CALA0001  T,,N,0800   0.00
# 40454  2024-05-24T00:00:00     SNOW  GHCND:US1CALA0001   ,,N,0800   0.00
# 40455  2024-05-24T00:00:00     SNWD  GHCND:US1CALA0001   ,,N,0800   0.00
# 40456  2024-05-24T00:00:00     WESD  GHCND:US1CALA0001   ,,N,0800   0.00
# 40457  2024-05-24T00:00:00     WESF  GHCND:US1CALA0001   ,,N,0800   0.00
#
#        longitude  latitude                     geometry
# 0      -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# 1      -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# 2      -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# 3      -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# 4      -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# ...          ...       ...                          ...
# 40453  -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# 40454  -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# 40455  -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# 40456  -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# 40457  -118.2947 -118.2947  POINT (-118.2947 -118.2947)
#
# [40458 rows x 8 columns]

# %%
stations_results_gdf = gpd.GeoDataFrame(columns = test_df.columns)

# %%
stations_results_gdf
# Out:
# Empty GeoDataFrame
# Columns: [date, datatype, station, attributes, value, longitude, latitude]
# Index: []

# %%
results_df['longitude'] = la_ds_gdf.iloc[0]['longitude']
results_df['latitude'] = la_ds_gdf.iloc[0]['latitude']

# %%
len(all_results)
# Out:
# 13486

# %%
all_results[:10]
# Out:
# [{'date': '2016-03-06T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:US1CALA0001',
#   'attributes': ',,N,0800',
#   'value': 1.57},
#  {'date': '2016-03-06T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:US1CALA0001',
#   'attributes': ',,N,0800',
#   'value': 0.0},
#  {'date': '2016-03-06T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:US1CALA0001',
#   'attributes': ',,N,0800',
#   'value': 0.0},
#  {'date': '2016-03-07T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:US1CALA0001',
#   'attributes': ',,N,0800',
#   'value': 0.21},
#  {'date': '2016-03-07T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:US1CALA0001',
#   'attributes': ',,N,0800',
#   'value': 0.0},
#  {'date': '2016-03-07T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:US1CALA0001',
#   'attributes': ',,N,0800',
#   'value': 0.0},
#  {'date': '2016-03-08T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:US1CALA0001',
#   'attributes': 'T,,N,0800',
#   'value': 0.0},
#  {'date': '2016-03-08T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:US1CALA0001',
#   'attributes': ',,N,0800',
#   'value': 0.0},
#  {'date': '2016-03-08T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:US1CALA0001',
#   'attributes': ',,N,0800',
#   'value': 0.0},
#  {'date': '2016-03-09T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:US1CALA0001',
#   'attributes': ',,N,0800',
#   'value': 0.0}]

# %%
all_results = []
offset = 0
limit = 1000
start_date = pd.to_datetime('2016-03-06')
end_date = start_date + year_delta

while start_date < la_ds_gdf['maxdate'][0]:
    offset = 0
    year_has_data = False
    
    while True:
        url = f'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid={la_ds_gdf['id'][0]}&units=standard&startdate={start_date.date()}&enddate={end_date.date()}&limit={limit}&offset={offset}'
        results = get_response(url)
        time.sleep(1)
    
        if not results:
            break
    
        year_has_data = True
        all_results.extend(results)
        offset += 1000

        if not year_has_data:
            break
    
        start_date += year_delta
        end_date += year_delta
# Out:
# 200
# 200
# 200
# 200
# 503

# %%
len(all_results)
# Out:
# 6894

# %% [markdown]
# This may or may not have worked. My error and response code handling is extremely crude because of my get_response() function. I should just re-write that function inside of my while loop with better error handling.

# %%
test_df = pd.DataFrame(all_results)

# %%
test_df['longitude'] = la_ds_gdf.iloc[0]['longitude']
test_df['latitude'] = la_ds_gdf.iloc[0]['longitude']

# %%
test_gdf = gpd.GeoDataFrame(test_df, geometry = gpd.points_from_xy(test_df['longitude'], test_df['latitude']), crs="EPSG:4326")

# %%
test_gdf.head()
# Out:
#                   date datatype            station attributes  value  \
# 0  2016-03-06T00:00:00     PRCP  GHCND:US1CALA0001   ,,N,0800   1.57
# 1  2016-03-06T00:00:00     SNOW  GHCND:US1CALA0001   ,,N,0800   0.00
# 2  2016-03-06T00:00:00     SNWD  GHCND:US1CALA0001   ,,N,0800   0.00
# 3  2016-03-07T00:00:00     PRCP  GHCND:US1CALA0001   ,,N,0800   0.21
# 4  2016-03-07T00:00:00     SNOW  GHCND:US1CALA0001   ,,N,0800   0.00
#
#    longitude  latitude                     geometry
# 0  -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# 1  -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# 2  -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# 3  -118.2947 -118.2947  POINT (-118.2947 -118.2947)
# 4  -118.2947 -118.2947  POINT (-118.2947 -118.2947)

# %%
test_gdf['datatype'].unique()
# Out:
# array(['PRCP', 'SNOW', 'SNWD', 'WESD', 'WESF', 'DAPR', 'MDPR'],
#       dtype=object)

# %%
test_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6894 entries, 0 to 6893
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        6894 non-null   object
#  1   datatype    6894 non-null   object
#  2   station     6894 non-null   object
#  3   attributes  6894 non-null   object
#  4   value       6894 non-null   float64
#  5   longitude   6894 non-null   float64
#  6   latitude    6894 non-null   float64
#  7   geometry    6894 non-null   geometry
# dtypes: float64(3), geometry(1), object(4)
# memory usage: 431.0+ KB

# %% [markdown]
# Once I improve the error and message handling (messages indicating when we're reached the end of paging for a given year, etc.) we can probably fairly easily implement looping through stations. The best option would likely be what I've done above: create a gdf for each station via the lat and long of the station: `la_ds_gdf.iloc[0]['longitude']` . . . since we will already be looping via `la_ds_gdf.iloc[i]['longitude']`

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
all_results = []
offset = 0
limit = 1000

while True:
    url = f'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid={station_id}&units=standard&startdate={start_date.date()}&enddate={end_date.date()}&limit={limit}&offset={offset}'
    results = get_response(url)

    if not results:
        start_date += year_delta
        end_date += year_delta

    all_results.extend(results)
    offset += limit

# %%
la_ds_gdf.iloc[0]['id']

# %%
la_ds_gdf.iloc[0]['maxdate']

# %%
station_id = la_ds_gdf.iloc[0]['id']
start_date = pd.to_datetime('2016-03-06')
end_date = start_date + year_delta

# %%
print(station_id)
print(start_date.date())
print(end_date.date())

# %%
print(start_date.date())

# %%
mem = get_response(f'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid={station_id}&units=standard&startdate={start_date.date()}&enddate={end_date.date()}&limit=1000&offset=0')

# %%
mem_df = pd.DataFrame(mem)

# %%
len(mem_df)

# %% [markdown]
# https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.html

# %%
mem_df.head()

# %%
mem_df['longitude'] = la_ds_gdf.iloc[0]['longitude']
mem_df['latitude'] = la_ds_gdf.iloc[0]['longitude']

# %%
mem_df['latitude'] = la_ds_gdf.iloc[0]['latitude']

# %%
mem_gdf = gpd.GeoDataFrame(mem_df, geometry=gpd.points_from_xy(mem_df['longitude'], mem_df['latitude']), crs="EPSG:4326")

# %%
mem_gdf.head()

# %%
len(la_ds_gdf)

# %%
for i in range(len(la_ds_gdf)):
    station_id = la_ds_gdf.iloc[i]['id']
    start_date = pd.to_datetime('2016-03-06')
    end_date = start_date + year_delta
    print(i)

# %%
for i in range(3):
    station_id = la_ds_gdf.iloc[i]['id']
    start_date = pd.to_datetime('2016-03-06')
    end_date = start_date + year_delta
    print(i)

# %%
mem_df['geometry'] = la_ds_gdf.iloc[1]

# %%
la_ds_gdf.iloc[1]

# %%
mem_gdf = gpd.GeoDataFrame(mem_df, crs="EPSG:4326")

# %%
len(mem_gdf)

# %% [markdown]
# ## Examining the data

# %%
la_GHCND = gpd.read_file('../../Data/Outputs/LA_GHCND.geojson')

# %%
la_GHCND.head()
# Out:
#    data datatype            station attributes  value  longitude  latitude  \
# 0  None     PRCP  GHCND:US1CALA0001   ,,N,0800   1.57  -118.2947   34.1689
# 1  None     SNOW  GHCND:US1CALA0001   ,,N,0800   0.00  -118.2947   34.1689
# 2  None     SNWD  GHCND:US1CALA0001   ,,N,0800   0.00  -118.2947   34.1689
# 3  None     PRCP  GHCND:US1CALA0001   ,,N,0800   0.21  -118.2947   34.1689
# 4  None     SNOW  GHCND:US1CALA0001   ,,N,0800   0.00  -118.2947   34.1689
#
#         date                   geometry
# 0 2016-03-06  POINT (-118.2947 34.1689)
# 1 2016-03-06  POINT (-118.2947 34.1689)
# 2 2016-03-06  POINT (-118.2947 34.1689)
# 3 2016-03-07  POINT (-118.2947 34.1689)
# 4 2016-03-07  POINT (-118.2947 34.1689)

# %%
la_GHCND.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 561855 entries, 0 to 561854
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   data        0 non-null       object
#  1   datatype    561855 non-null  object
#  2   station     561855 non-null  object
#  3   attributes  561855 non-null  object
#  4   value       561855 non-null  float64
#  5   longitude   561855 non-null  float64
#  6   latitude    561855 non-null  float64
#  7   date        561855 non-null  datetime64[ms]
#  8   geometry    561855 non-null  geometry
# dtypes: datetime64[ms](1), float64(3), geometry(1), object(4)
# memory usage: 38.6+ MB

# %%
la_GHCND['datatype'].unique()
# Out:
# array(['PRCP', 'SNOW', 'SNWD', 'WESD', 'WESF', 'DAPR', 'MDPR', 'TMAX',
#        'TMIN', 'TOBS', 'WT03', 'WT06', 'WT01', 'WT11', 'WT05', 'TAVG',
#        'ADPT', 'ASLP', 'ASTP', 'AWBT', 'AWND', 'RHAV', 'RHMN', 'RHMX',
#        'WDF2', 'WDF5', 'WSF2', 'WSF5', 'WT08', 'WT02', 'PGTM', 'WT07'],
#       dtype=object)

# %% [markdown]
# # End of the line

# %% [markdown]
# This marks the end of my current working area. Everything below this is not currently active

# %%
1/0

# %% [markdown]
# ### Making a complete dataset method

# %% [markdown]
# I probably need to implement postGIS. I should also make sure to respect the NOAA servers by
#
# 1. Pagenating API calls (the limit is 1000 responses per call
# 2. Rate limiting myself to 1-5 calls per second
#
# In general, I estimate that I'll be getting back around a million rows, hence postgis

# %% [markdown]
# ### Radar II

# %%
radar_url = 'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=NEXRAD3&units=standard&startdate=2010-05-01&enddate=2010-05-31'

# %%
# radar_url = 'https://www.ncei.noaa.gov/cdo-web/api/v2/stations?datasetid=NEXRAD3&locationid=FIPS:06037&startdate=2016-03-06&extent=33.7046743723892,-118.944703049253,34.823304156602,-117.646385981235&limit=1000'

response = requests.get(radar_url,headers=headers)
radar_response = response.json()

# %%
radar_response

# %%
radar_df = pd.DataFrame(radar_res)
radar_gdf = gpd.GeoDataFrame(
   radar_df, geometry=gpd.points_from_xy(radar_df['longitude'], radar_df['latitude']), crs="EPSG:4326"
)

# %%
radar_gdf

# %%
'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:28801&startdate=2010-05-01&enddate=2010-05-01'

# %%
test = 'https://www.ncei.noaa.gov/cdo-web/api/v2/stations?datasetid=GHCND&'

# %% [markdown]
# At some point I should try to optimize the query using the state location code, but it doesn't seem to take:

# %%
test = 'https://www.ncei.noaa.gov/cdo-web/api/v2/locations?locationcategoryid=FIPS:06&locationcategoryid=CNTY'

# %%
response = requests.get(test,headers=headers)
print(response)
data = response.json()
data

# %%
'https://www.ncei.noaa.gov/cdo-web/api/v2/locations?locationcategoryid=CNTY&limit=1000&sortfield=name&sortorder=asc&offset=1000'

# %%
'https://www.ncei.noaa.gov/cdo-web/api/v2/locations?datasetid=GHCND&locationid=ZIP:28801&startdate=2010-05-01&enddate=2010-05-01'

# %%
loc_cnty_url = 'https://www.ncei.noaa.gov/cdo-web/api/v2/locationcategories/CNTY'

# %%
response = requests.get(loc_cnty_url,headers=headers)
print(response)
data = response.json()
data

# %% [markdown]
# ### Looking for temp:

# %% [markdown]
# For now I will negate this section. Suffice it to say, temperature is present in some but not all stations

# %% [markdown]
# la_ds_gdf.iloc[5]['id']

# %% [markdown]
# la_ds_gdf.iloc[5]

# %% [markdown]
# def station_search(station_id, start_date, end_date):
#     temp = get_response(f'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid={station_id['id']}&units=standard&startdate={start_date}&enddate={end_date}')
#     df = pd.DataFrame(temp)
#     return df

# %% [markdown]
# df = station_search(la_ds_gdf.iloc[100], '2019-01-01', '2020-01-01')
# df['datatype'].unique()

# %% [markdown]
# ### Stations

# %% [markdown]
# ### Daily Summaries

# %% [markdown]
# https://www.ncdc.noaa.gov/cdo-web/webservices/v2#data

# %% [markdown]
# Example URL:
#
# `https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=YOUR_DATASETID`

# %%
url = 'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND'

# %%
1/0

# %%
# Trying one of the default URLs:
url1 = ' https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:28801&startdate=2010-05-01&enddate=2010-05-01'

# %%
response = requests.get(url1,headers=headers)
print(response)
data = response.json()
data

# %%
counties=data['results']

# %%
len(counties)
