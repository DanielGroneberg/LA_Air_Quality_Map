# %% [markdown]
# Attempting to read in .ncf file

# %% [markdown]
# https://www.epa.gov/cmaq

# %%
from netCDF4 import Dataset

# %%
test_file = Dataset('/home/daniel/Downloads/inln_mole_cmv_c3_12_20151222_12US1_cmaq_cb6_2016fh_16j.ncf')

# %%
test_file
# Out:
# <class 'netCDF4.Dataset'>
# root group (NETCDF3_64BIT_OFFSET data model, file format NETCDF3):
#     IOAPI_VERSION: ioapi-3.2: $Id: init3.F90 98 2018-04-05 14:35:07Z coats $
#     EXEC_ID: ????????????????
#     FTYPE: 1
#     CDATE: 2020017
#     CTIME: 14956
#     WDATE: 2020017
#     WTIME: 14956
#     SDATE: 2016357
#     STIME: 0
#     TSTEP: 10000
#     NTHIK: 1
#     NCOLS: 1
#     NROWS: 102283
#     NLAYS: 1
#     NVARS: 54
#     GDTYP: 2
#     P_ALP: 33.0
#     P_BET: 45.0
#     P_GAM: -97.0
#     XCENT: -97.0
#     YCENT: 40.0
#     XORIG: -2556000.0
#     YORIG: -1728000.0
#     XCELL: 12000.0
#     YCELL: 12000.0
#     VGTYP: -9999
#     VGTOP: -9.999e+36
#     VGLVLS: [0. 0.]
#     GDNAM: 12US1_459X299
#     UPNAM: CREATESET
# ...

# %%
test_file.variables.keys()
# Out:
# dict_keys(['TFLAG', 'CO', 'NH3', 'NH3_FERT', 'HONO', 'NO', 'NO2', 'PAL', 'PCA', 'PCL', 'PEC', 'PFE', 'PH2O', 'PK', 'PMG', 'PMN', 'PMOTHR', 'PNA', 'PNCOM', 'PNH4', 'PNO3', 'POC', 'PSI', 'PSO4', 'PTI', 'PMC', 'SO2', 'SULF', 'ACET', 'ALD2', 'ALD2_PRIMARY', 'ALDX', 'BENZ', 'CH4', 'ETH', 'ETHA', 'ETHY', 'ETOH', 'FORM', 'FORM_PRIMARY', 'IOLE', 'ISOP', 'KET', 'MEOH', 'NAPH', 'NVOL', 'OLE', 'PAR', 'PRPA', 'SOAALK', 'TERP', 'TOL', 'UNR', 'XYLMN', 'VOC_INV'])

# %%
test_file.variables['PMN']
# Out:
# <class 'netCDF4.Variable'>
# float32 PMN(TSTEP, LAY, ROW, COL)
#     long_name: PMN
#     units: g/s
#     var_desc: Model species PMN
# unlimited dimensions: TSTEP
# current shape = (25, 1, 102283, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used
