# %%
import pandas as pd
import geopandas as gpd

from pyathena import connect
from pyathena.error import OperationalError
import datetime as dt

import requests

# %% [markdown]
# https://docs.openaq.org/aws/athena-guide

# %% [markdown]
# ```
# s3://openaq-data-archive/records/csv.gz/
# ├─ year=2025/
# │  ├─ month=10/
# │  │  ├─ locationid=2178/
# │  │  ├─ locationid=827/
# │  │  └─ ...
# │  └─ month=11/...
# └─ year=2024/...
# ```

# %% [markdown]
# Example file path:
#
# `/records/csv.gz/locationid=2178/year=2022/month=05/location-2178-20220503.csv.gz`

# %%
la_sensors_gdf = gpd.read_file("../../Data/sensor_data/la_openaq_stations.geojson")

# %%
la_sensors_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
la_sensors_gdf.rename(columns = {'station_id':'location_id'}, inplace=True)

# %%
la_sensors_gdf.head()
# Out:
#    sensors_id  station_id pollutant              name  \
# 0        1502         847     PM2.5  South Long Beach
# 1        1837        1019        O₃          Pasadena
# 2        1866        1036        O₃       Pico Rivera
# 3        1876        1042        O₃    Piru - Pacific
# 4       22301        1042     PM2.5    Piru - Pacific
#
#          datetime_first.utc         datetime_last.utc             timezone  \
# 0 2016-03-06 20:00:00+00:00 2022-05-05 22:00:00+00:00  America/Los_Angeles
# 1 2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00  America/Los_Angeles
# 2 2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00  America/Los_Angeles
# 3 2016-03-06 20:00:00+00:00 2020-06-10 21:00:00+00:00  America/Los_Angeles
# 4 2016-03-06 20:00:00+00:00 2020-06-10 21:00:00+00:00  America/Los_Angeles
#
#    is_mobile  is_monitor                                            bounds  \
# 0      False        True  [-118.175278, 33.792221, -118.175278, 33.792221]
# 1      False        True          [-118.1081, 34.0833, -118.1081, 34.0833]
# 2      False        True      [-118.059196, 34.0131, -118.059196, 34.0131]
# 3      False        True              [-118.81, 34.4044, -118.81, 34.4044]
# 4      False        True              [-118.81, 34.4044, -118.81, 34.4044]
#
#    ...   country.name owner.id                         owner.name  \
# 0  ...  United States        4  Unknown Governmental Organization
# 1  ...  United States        4  Unknown Governmental Organization
# 2  ...  United States        4  Unknown Governmental Organization
# 3  ...  United States        4  Unknown Governmental Organization
# 4  ...  United States        4  Unknown Governmental Organization
#
#    provider.id provider.name  coordinates.latitude coordinates.longitude  \
# 0          119        AirNow             33.792221           -118.175278
# 1          119        AirNow             34.083300           -118.108100
# 2          119        AirNow             34.013100           -118.059196
# 3          119        AirNow             34.404400           -118.810000
# 4          119        AirNow             34.404400           -118.810000
#
#       instrument_name  instrument_id                     geometry
# 0  Government Monitor              2  POINT (-118.17528 33.79222)
# 1  Government Monitor              2    POINT (-118.1081 34.0833)
# 2  Government Monitor              2    POINT (-118.0592 34.0131)
# 3  Government Monitor              2      POINT (-118.81 34.4044)
# 4  Government Monitor              2      POINT (-118.81 34.4044)
#
# [5 rows x 22 columns]

# %% [markdown]
# la_sensors_gdf.set_index('sensors_id',inplace=True)

# %%
la_sensors_gdf.head()
# Out:
#             station_id pollutant              name        datetime_first.utc  \
# sensors_id
# 1502               847     PM2.5  South Long Beach 2016-03-06 20:00:00+00:00
# 1837              1019        O₃          Pasadena 2016-03-06 20:00:00+00:00
# 1866              1036        O₃       Pico Rivera 2016-03-06 20:00:00+00:00
# 1876              1042        O₃    Piru - Pacific 2016-03-06 20:00:00+00:00
# 22301             1042     PM2.5    Piru - Pacific 2016-03-06 20:00:00+00:00
#
#                    datetime_last.utc             timezone  is_mobile  \
# sensors_id
# 1502       2022-05-05 22:00:00+00:00  America/Los_Angeles      False
# 1837       2016-11-09 21:00:00+00:00  America/Los_Angeles      False
# 1866       2016-11-09 21:00:00+00:00  America/Los_Angeles      False
# 1876       2020-06-10 21:00:00+00:00  America/Los_Angeles      False
# 22301      2020-06-10 21:00:00+00:00  America/Los_Angeles      False
#
#             is_monitor                                            bounds  \
# sensors_id
# 1502              True  [-118.175278, 33.792221, -118.175278, 33.792221]
# 1837              True          [-118.1081, 34.0833, -118.1081, 34.0833]
# 1866              True      [-118.059196, 34.0131, -118.059196, 34.0131]
# 1876              True              [-118.81, 34.4044, -118.81, 34.4044]
# 22301             True              [-118.81, 34.4044, -118.81, 34.4044]
#
#             country.id  ...   country.name owner.id  \
# sensors_id              ...
# 1502               155  ...  United States        4
# 1837               155  ...  United States        4
# 1866               155  ...  United States        4
# 1876               155  ...  United States        4
# 22301              155  ...  United States        4
#
#                                    owner.name provider.id  provider.name  \
# sensors_id
# 1502        Unknown Governmental Organization         119         AirNow
# 1837        Unknown Governmental Organization         119         AirNow
# 1866        Unknown Governmental Organization         119         AirNow
# 1876        Unknown Governmental Organization         119         AirNow
# 22301       Unknown Governmental Organization         119         AirNow
#
#            coordinates.latitude  coordinates.longitude     instrument_name  \
# sensors_id
# 1502                  33.792221            -118.175278  Government Monitor
# 1837                  34.083300            -118.108100  Government Monitor
# 1866                  34.013100            -118.059196  Government Monitor
# 1876                  34.404400            -118.810000  Government Monitor
# 22301                 34.404400            -118.810000  Government Monitor
#
#            instrument_id                     geometry
# sensors_id
# 1502                   2  POINT (-118.17528 33.79222)
# 1837                   2    POINT (-118.1081 34.0833)
# 1866                   2    POINT (-118.0592 34.0131)
# 1876                   2      POINT (-118.81 34.4044)
# 22301                  2      POINT (-118.81 34.4044)
#
# [5 rows x 21 columns]

# %%
la_sensors_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 1971 entries, 1502 to 14877261
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   station_id             1971 non-null   int32
#  1   pollutant              1971 non-null   object
#  2   name                   1971 non-null   object
#  3   datetime_first.utc     1971 non-null   datetime64[ms, UTC]
#  4   datetime_last.utc      1971 non-null   datetime64[ms, UTC]
#  5   timezone               1971 non-null   object
#  6   is_mobile              1971 non-null   bool
#  7   is_monitor             1971 non-null   bool
#  8   bounds                 1971 non-null   object
#  9   country.id             1971 non-null   int32
#  10  country.code           1971 non-null   object
#  11  country.name           1971 non-null   object
#  12  owner.id               1971 non-null   int32
#  13  owner.name             1971 non-null   object
#  14  provider.id            1971 non-null   int32
#  15  provider.name          1971 non-null   object
#  16  coordinates.latitude   1971 non-null   float64
#  17  coordinates.longitude  1971 non-null   float64
#  18  instrument_name        1971 non-null   object
#  19  instrument_id          1971 non-null   int32
#  20  geometry               1971 non-null   geometry
# dtypes: bool(2), datetime64[ms, UTC](2), float64(2), geometry(1), int32(5), object(9)
# memory usage: 265.6+ KB

# %% [markdown]
# ### Manually pulling from S3

# %%
def download_file(url, save_path):
    response = requests.get(url, stream=True)
    
    if response.status_code == 200:
        with open(save_path, 'wb') as file:
            file.write(response.content)
        print(f'{url} downloaded')
    else:
        print(f'{url} failed')

# %%
url = "https://openaq-data-archive.s3.amazonaws.com/records/csv.gz/locationid=1200/year=2025/month=10/location-1200-20251010.csv.gz"

# %%
download_file(url,"../../Data/sensor_data/station_1200.csv.gz")
# Out:
# https://openaq-data-archive.s3.amazonaws.com/records/csv.gz/locationid=1200/year=2025/month=10/location-1200-20251010.csv.gz downloaded

# %%
station_1200 = pd.read_csv('../../Data/sensor_data/station_1200.csv.gz')

# %%
station_1200.head()
# Out:
#    location_id  sensors_id                location                   datetime  \
# 0         1200        2152  Glendora - Laurel-1200  2025-10-10T01:00:00-07:00
# 1         1200        2152  Glendora - Laurel-1200  2025-10-10T02:00:00-07:00
# 2         1200        2152  Glendora - Laurel-1200  2025-10-10T03:00:00-07:00
# 3         1200        2152  Glendora - Laurel-1200  2025-10-10T04:00:00-07:00
# 4         1200        2152  Glendora - Laurel-1200  2025-10-10T05:00:00-07:00
#
#        lat       lon parameter  units  value
# 0  34.1439 -117.8508      pm10  µg/m³   17.0
# 1  34.1439 -117.8508      pm10  µg/m³   26.0
# 2  34.1439 -117.8508      pm10  µg/m³   19.0
# 3  34.1439 -117.8508      pm10  µg/m³   24.0
# 4  34.1439 -117.8508      pm10  µg/m³   23.0

# %%
station_1200.columns

# %%
athena_cols = station_1200.columns

# %%
len(athena_cols)

# %% [markdown]
# ### Setting up Athena

# %%
cursor = connect(
    s3_staging_dir="s3://la-openaq-athena-results-us-east-1/temp/",
    region_name="us-east-1"
).cursor()

# %%
cursor.execute("DROP TABLE openaq_db.openaqMeasurements;")

# %%
create_table = """
CREATE EXTERNAL TABLE IF NOT EXISTS openaq_db.openaqMeasurements (
  location_id INT,
  sensors_id INT,
  location STRING,
  datetime STRING,
  lat DOUBLE,
  lon DOUBLE,
  parameter STRING,
  units STRING,
  value DOUBLE
)
PARTITIONED BY (locationid STRING, year STRING, month STRING)
ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
WITH SERDEPROPERTIES ('serialization.format'=',','field.delim'=',')
LOCATION 's3://openaq-data-archive/records/csv.gz/'
TBLPROPERTIES ('skip.header.line.count'='1');
"""
cursor.execute(create_table)

# %%
cursor.execute("SHOW PARTITIONS openaq_db.openaqMeasurements;")
print(cursor.fetchall())

# %%
station_IDs = la_sensors_gdf['station_id']

# %%
list(la_sensors_gdf['station_id'])[0]

# %%
str(dt.datetime.today().month).zfill(2)

# %%
dt.datetime.today().year

# %% [markdown]
# I need to fix this logic: it technically works, but returns a "not defined" error, ironically because the partitioning produced no errors.

# %% [markdown]
# ### Partitioning

# %%
def add_station_partitions(station, = list(la_sensors_gdf['station_id'])[0], year=dt.datetime.today().year, month=str(dt.datetime.today().month)):
    errors = []
    month = month.zfill(2)
    for location in list(la_sensors_gdf['station_id']):
        try:
            cursor.execute(f"""
            ALTER TABLE openaq_db.openaqMeasurements ADD
            PARTITION (year='{year}', month='{month}', locationid='{location}')
            LOCATION 's3://openaq-data-archive/records/csv.gz/locationid={location}/year={year}/month={month}/';
            """)
        except OperationalError as e:
            errors.extend(f'OperationalError {e} for year: {year}, month: {month}')
            continue
    return errors

# %%
station_partitions_error_log = add_station_partitions(year='2025',month='12')

# %%
station_partition_error_log[:10]

# %%
cursor.execute("SHOW PARTITIONS openaq_db.openaqMeasurements;")
openaq_partitons = cursor.fetchall()

# %%
openaq_partitons[:20]

# %%
openaq_partitons[-20:]

# %% [markdown]
# ### Query practice

# %%
cols = ['location_id','sensors_id','location','datetime','lat','lon','parameter','units','value']

# %%
cursor.execute("""
SELECT * 
FROM openaq_db.openaqMeasurements 
WHERE location_id = 1200
ORDER BY datetime DESC;
""")
station_1200 = cursor.fetchall()

# %%
station_1200[0]

# %%
station_1200_athena_df = pd.DataFrame(data=station_1200,columns=athena_cols)

# %%
station_1200_athena_df.head()

# %%
station_1200_athena_df.info()

# %% [markdown]
# Since we queried a single day, we have 24 (hourly) entries - for each pollutant

# %%
station_1200_athena_df['parameter'].value_counts()

# %% [markdown]
# ### Querying PM2.5

# %% [markdown]
# I can't directly query the entire S3 bucket for PM2.5 - only where partitions are already present.

# %%
cursor.execute("""
SELECT * 
FROM openaq_db.openaqMeasurements 
WHERE parameter = 'pm25'
ORDER BY datetime DESC
LIMIT 10;
""")
pm25_practice = cursor.fetchall()

# %%
pm25_practice[0]
# Out:
# (3312559,
#  11626125,
#  'San Gabriel-3282501',
#  '2025-12-12T00:00:00-08:00',
#  34.099201,
#  -118.107231,
#  'pm25',
#  'µg/m³',
#  15.989500013987223,
#  '3312559',
#  '2025',
#  '12')

# %%
len(pm25_practice[0])
# Out:
# 12

# %%
len(athena_cols)
# Out:
# 9

# %%
pm25_practice[0][:-3]
# Out:
# (3312559,
#  11626125,
#  'San Gabriel-3282501',
#  '2025-12-12T00:00:00-08:00',
#  34.099201,
#  -118.107231,
#  'pm25',
#  'µg/m³',
#  15.989500013987223)

# %% [markdown]
# The final 3 items here are not helpful - it's the location_id, year and month, which are already present in location_id and datetime

# %%
pm25_practice = [pm25_practice[i][:-3] for i in range(len(pm25_practice))]

# %%
pm25_practice_df = pd.DataFrame(data=pm25_practice,columns=athena_cols)

# %%
pm25_practice_df.head()
# Out:
#    location_id  sensors_id                                         location  \
# 0      1716811     7217298  Marco Triangle Park, Venice, California-1686784
# 1      2905670     9660619                               Story Park-2875630
# 2        26780     9636796                     Thousand Oaks - Moor-2872352
# 3      1519816     6876410                  East Irvine - Northwood-1489792
# 4         2138        3842                                      Reseda-2138
#
#                     datetime        lat         lon parameter  units  \
# 0  2025-12-12T00:00:00-08:00  33.991524 -118.459939      pm25  µg/m³
# 1  2025-12-12T00:00:00-08:00  34.100018 -118.125515      pm25  µg/m³
# 2  2025-12-12T00:00:00-08:00  34.210170 -118.870510      pm25  µg/m³
# 3  2025-12-12T00:00:00-08:00  33.716054 -117.749260      pm25  µg/m³
# 4  2025-12-12T00:00:00-08:00  34.199200 -118.533100      pm25  µg/m³
#
#        value
# 0  36.112500
# 1  21.775000
# 2   4.000000
# 3  12.260417
# 4  14.800000

# %%
pm25_practice_df.info()

# %%
pm25_practice_df.sort_values(by = 'datetime',ascending=True).head()

# %%
pm25_practice_df.sort_values(by = 'datetime',ascending=False).head()

# %% [markdown]
# There's only 9 days present here and we already have 380,000 rows

# %% [markdown]
# cursor.execute(f"""
# SELECT *
# FROM (
#     SELECT *,
#            ROW_NUMBER() OVER (
#                PARTITION BY sensors_id
#                ORDER BY datetime DESC
#            ) AS rn
#     FROM openaq_db.openaqMeasurements
#     WHERE year = '{dt.datetime.today().year}'
#       AND month = '{str(dt.datetime.today().month).zfill(2)}'
#       AND sensors_id IN {tuple(sensor_IDs)}
# ) sub
# WHERE rn = 1
# ORDER BY datetime DESC;
# """
# )
# records = cursor.fetchall()

# %%
records

# %% [markdown]
# ### Partitioning All Pm2.5

# %% [markdown]
# I need to modify this below: and look at the existing or intended partition scheme (url layout). I can iterate either through month or station (depending on the layout). I'll then need to make another function to iterate through e.g. each station in each month in each year . . . to complete my partitioning scheme.

# %%
station_ids = list(set(la_sensors_gdf['station_id']))

# %%
def add_station_partitions(stations, year, month):
    for location in stations:
        try:
            cursor.execute(f"""
            ALTER TABLE openaq_db.openaqMeasurements ADD
            PARTITION (year='{year}', month='{month}', locationid='{location}')
            LOCATION 's3://openaq-data-archive/records/csv.gz/locationid={location}/year={year}/month={month}/';
            """)
        except OperationalError as e:
            print(f'OperationalError {e} for year: {year}, month: {month}, station: {location}')
            pass

# %%
def add_month_partitions(stations, year):
    errors = []
    for month in range(1,13):
        month = str(month).zfill(2)
        try: 
            add_station_partitions(stations = stations, year = year, month = month)
        except OperationalError as e:
            print(f'OperationalError {e} for year: {year}, month: {month}, station: {station}')
            continue

# %%
def add_year_partitions(stations):
    errors = []
    for year in range(2016,2027):
        try: 
            add_month_partitions(stations = stations, year = year)
        except OperationalError as e:
            print(f'OperationalError {e} for year: {year}')
            pass

# %%
add_month_partitions(station_ids, 2024)

# %% [markdown]
# add_month_partitions(station_ids, 2024)

# %%
cursor.execute("SHOW PARTITIONS openaq_db.openaqMeasurements;")
partitions = cursor.fetchall()

# %%
len(partitions)

# %%
cursor.close()

# %% [markdown]
# I need to better research and understand the consequences of costs with Athena before running this:

# %% [markdown]
# Running for just 2025 should be a less-drastic test case. We can examine the costs and data usage there and extrapolate.

# %%
add_year_partitions(station_ids)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 add_year_partitions(station_ids)
#
# Cell In[15], line 4, in add_year_partitions(stations)
#       2 for year in range(2016,2027):
#       3     try:
# ----> 4         add_month_partitions(stations = stations, year = year)
#       5     except OperationalError as e:
#       6         print(f'OperationalError {e} for year: {year}')
#
# Cell In[14], line 5, in add_month_partitions(stations, year)
#       3 month = str(month).zfill(2)
#       4 try:
# ----> 5     add_station_partitions(stations = stations, year = year, month = month)
#       6 except OperationalError as e:
#       7     print(f'OperationalError {e} for year: {year}, month: {month}')
#
# Cell In[13], line 4, in add_station_partitions(stations, year, month)
#       2 for location in stations:
#       3     try:
# ----> 4         cursor.execute(f"""
#       5         ALTER TABLE openaq_db.openaqMeasurements ADD
#       6         PARTITION (year='{year}', month='{month}', locationid='{location}')
#       7         LOCATION 's3://openaq-data-archive/records/csv.gz/locationid={location}/year={year}/month={month}/';
#       8         """)
#       9     except OperationalError as e:
#      10         print(f'OperationalError {e} for year: {year}, month: {month}')
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/cursor.py:190, in Cursor.execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle, on_start_query_execution, **kwargs)
#     164 """Execute a SQL query.
#     165
#     166 Args:
#    (...)    187                  on_start_query_execution=on_execution_started)
#     188 """
#     189 self._reset_state()
# --> 190 self.query_id = self._execute(
#     191     operation,
#     192     parameters=parameters,
#     193     work_group=work_group,
#     194     s3_staging_dir=s3_staging_dir,
#     195     cache_size=cache_size,
#     196     cache_expiration_time=cache_expiration_time,
#     197     result_reuse_enable=result_reuse_enable,
#     198     result_reuse_minutes=result_reuse_minutes,
#     199     paramstyle=paramstyle,
#     200 )
#     202 # Call user callbacks immediately after start_query_execution
#     203 # Both connection-level and execute-level callbacks are invoked if set
#     204 if self._on_start_query_execution:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py:645, in BaseCursor._execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle)
#     643 if query_id is None:
#     644     try:
# --> 645         query_id = retry_api_call(
#     646             self._connection.client.start_query_execution,
#     647             config=self._retry_config,
#     648             logger=_logger,
#     649             **request,
#     650         ).get("QueryExecutionId")
#     651     except Exception as e:
#     652         _logger.exception("Failed to execute query.")
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/util.py:196, in retry_api_call(func, config, logger, *args, **kwargs)
#     183     return code is not None and code in config.exceptions
#     185 retry = tenacity.Retrying(
#     186     retry=retry_if_exception(_is_retryable),
#     187     stop=stop_after_attempt(config.attempt),
#    (...)    194     reraise=True,
#     195 )
# --> 196 return retry(func, *args, **kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py:1060, in BaseClient._make_api_call(self, operation_name, api_params)
#    1056     maybe_compress_request(
#    1057         self.meta.config, request_dict, operation_model
#    1058     )
#    1059     apply_request_checksum(request_dict)
# -> 1060     http, parsed_response = self._make_request(
#    1061         operation_model, request_dict, request_context
#    1062     )
#    1064 self.meta.events.emit(
#    1065     f'after-call.{service_id}.{operation_name}',
#    1066     http_response=http,
#    (...)   1069     context=request_context,
#    1070 )
#    1072 if http.status_code >= 300:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py:1084, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1082 def _make_request(self, operation_model, request_dict, request_context):
#    1083     try:
# -> 1084         return self._endpoint.make_request(operation_model, request_dict)
#    1085     except Exception as e:
#    1086         self.meta.events.emit(
#    1087             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#    1088             exception=e,
#    1089             context=request_context,
#    1090         )
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/endpoint.py:197, in Endpoint._send_request(self, request_dict, operation_model)
#     195 self._update_retries_context(context, attempts)
#     196 request = self.create_request(request_dict, operation_model)
# --> 197 success_response, exception = self._get_response(
#     198     request, operation_model, context
#     199 )
#     200 while self._needs_retry(
#     201     attempts,
#     202     operation_model,
#    (...)    205     exception,
#     206 ):
#     207     attempts += 1
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/endpoint.py:239, in Endpoint._get_response(self, request, operation_model, context)
#     233 def _get_response(self, request, operation_model, context):
#     234     # This will return a tuple of (success_response, exception)
#     235     # and success_response is itself a tuple of
#     236     # (http_response, parsed_dict).
#     237     # If an exception occurs then the success_response is None.
#     238     # If no exception occurs then exception is None.
# --> 239     success_response, exception = self._do_get_response(
#     240         request, operation_model, context
#     241     )
#     242     kwargs_to_emit = {
#     243         'response_dict': None,
#     244         'parsed_response': None,
#     245         'context': context,
#     246         'exception': exception,
#     247     }
#     248     if success_response is not None:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/endpoint.py:279, in Endpoint._do_get_response(self, request, operation_model, context)
#     277     http_response = first_non_none_response(responses)
#     278     if http_response is None:
# --> 279         http_response = self._send(request)
#     280 except HTTPClientError as e:
#     281     return (None, e)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/endpoint.py:383, in Endpoint._send(self, request)
#     382 def _send(self, request):
# --> 383     return self.http_session.send(request)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/httpsession.py:465, in URLLib3Session.send(self, request)
#     462     conn.proxy_headers['host'] = host
#     464 request_target = self._get_request_target(request.url, proxy_url)
# --> 465 urllib_response = conn.urlopen(
#     466     method=request.method,
#     467     url=request_target,
#     468     body=request.body,
#     469     headers=request.headers,
#     470     retries=Retry(False),
#     471     assert_same_host=False,
#     472     preload_content=False,
#     473     decode_content=False,
#     474     chunked=self._chunked(request.headers),
#     475 )
#     477 http_response = botocore.awsrequest.AWSResponse(
#     478     request.url,
#     479     urllib_response.status,
#     480     urllib_response.headers,
#     481     urllib_response,
#     482 )
#     484 if not request.stream_output:
#     485     # Cause the raw stream to be exhausted immediately. We do it
#     486     # this way instead of using preload_content because
#     487     # preload_content will never buffer chunked responses
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~/miniforge3/envs/la_env/lib/python3.14/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/miniforge3/envs/la_env/lib/python3.14/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/miniforge3/envs/la_env/lib/python3.14/socket.py:725, in SocketIO.readinto(self, b)
#     723     raise OSError("cannot read from timed out object")
#     724 try:
# --> 725     return self._sock.recv_into(b)
#     726 except timeout:
#     727     self._timeout_occurred = True
#
# File ~/miniforge3/envs/la_env/lib/python3.14/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
cursor.execute("SHOW PARTITIONS openaq_db.openaqMeasurements;")
partitions = cursor.fetchall()

# %%
len(partitions)

# %% [markdown]
# A possibly mildly improved version:

# %%
def add_year_partitions(stations=station_ids,start_year=2016,end_year=2027):
    start_year = int(start_year)
    # because this is a range, we need to add an extra year
    end_year = int(end_year) + 1
    for year in range(start_year,end_year):
        try: 
            add_month_partitions(stations = stations, year = year)
        except OperationalError as e:
            print(f'OperationalError {e} for year: {year}')
            pass

# %%
print(range(1,12))

# %%
len(range(1,13))

# %% [markdown]
# ### Query optimizing

# %%
la_sensors_gdf.head()
# Out:
#             station_id pollutant              name        datetime_first.utc  \
# sensors_id
# 1502               847     PM2.5  South Long Beach 2016-03-06 20:00:00+00:00
# 1837              1019        O₃          Pasadena 2016-03-06 20:00:00+00:00
# 1866              1036        O₃       Pico Rivera 2016-03-06 20:00:00+00:00
# 1876              1042        O₃    Piru - Pacific 2016-03-06 20:00:00+00:00
# 22301             1042     PM2.5    Piru - Pacific 2016-03-06 20:00:00+00:00
#
#                    datetime_last.utc             timezone  is_mobile  \
# sensors_id
# 1502       2022-05-05 22:00:00+00:00  America/Los_Angeles      False
# 1837       2016-11-09 21:00:00+00:00  America/Los_Angeles      False
# 1866       2016-11-09 21:00:00+00:00  America/Los_Angeles      False
# 1876       2020-06-10 21:00:00+00:00  America/Los_Angeles      False
# 22301      2020-06-10 21:00:00+00:00  America/Los_Angeles      False
#
#             is_monitor                                            bounds  \
# sensors_id
# 1502              True  [-118.175278, 33.792221, -118.175278, 33.792221]
# 1837              True          [-118.1081, 34.0833, -118.1081, 34.0833]
# 1866              True      [-118.059196, 34.0131, -118.059196, 34.0131]
# 1876              True              [-118.81, 34.4044, -118.81, 34.4044]
# 22301             True              [-118.81, 34.4044, -118.81, 34.4044]
#
#             country.id  ...   country.name owner.id  \
# sensors_id              ...
# 1502               155  ...  United States        4
# 1837               155  ...  United States        4
# 1866               155  ...  United States        4
# 1876               155  ...  United States        4
# 22301              155  ...  United States        4
#
#                                    owner.name provider.id  provider.name  \
# sensors_id
# 1502        Unknown Governmental Organization         119         AirNow
# 1837        Unknown Governmental Organization         119         AirNow
# 1866        Unknown Governmental Organization         119         AirNow
# 1876        Unknown Governmental Organization         119         AirNow
# 22301       Unknown Governmental Organization         119         AirNow
#
#            coordinates.latitude  coordinates.longitude     instrument_name  \
# sensors_id
# 1502                  33.792221            -118.175278  Government Monitor
# 1837                  34.083300            -118.108100  Government Monitor
# 1866                  34.013100            -118.059196  Government Monitor
# 1876                  34.404400            -118.810000  Government Monitor
# 22301                 34.404400            -118.810000  Government Monitor
#
#            instrument_id                     geometry
# sensors_id
# 1502                   2  POINT (-118.17528 33.79222)
# 1837                   2    POINT (-118.1081 34.0833)
# 1866                   2    POINT (-118.0592 34.0131)
# 1876                   2      POINT (-118.81 34.4044)
# 22301                  2      POINT (-118.81 34.4044)
#
# [5 rows x 21 columns]

# %%
pm25_practice_df.head()
# Out:
#    location_id  sensors_id                                         location  \
# 0      1716811     7217298  Marco Triangle Park, Venice, California-1686784
# 1      2905670     9660619                               Story Park-2875630
# 2        26780     9636796                     Thousand Oaks - Moor-2872352
# 3      1519816     6876410                  East Irvine - Northwood-1489792
# 4         2138        3842                                      Reseda-2138
#
#                     datetime        lat         lon parameter  units  \
# 0  2025-12-12T00:00:00-08:00  33.991524 -118.459939      pm25  µg/m³
# 1  2025-12-12T00:00:00-08:00  34.100018 -118.125515      pm25  µg/m³
# 2  2025-12-12T00:00:00-08:00  34.210170 -118.870510      pm25  µg/m³
# 3  2025-12-12T00:00:00-08:00  33.716054 -117.749260      pm25  µg/m³
# 4  2025-12-12T00:00:00-08:00  34.199200 -118.533100      pm25  µg/m³
#
#        value
# 0  36.112500
# 1  21.775000
# 2   4.000000
# 3  12.260417
# 4  14.800000

# %%
sensor_ids = la_sensors_gdf.index

# %%
sensor_ids = list(la_sensors_gdf['sensors_id'])

# %%
sensor_ids[:20]
# Out:
# [1502,
#  1837,
#  1866,
#  1876,
#  22301,
#  25500,
#  4272146,
#  25501,
#  4272073,
#  1888,
#  24900,
#  4272387,
#  24901,
#  4272396,
#  2154,
#  2152,
#  2150,
#  2244,
#  2274,
#  2554]

# %%
len(set(la_sensors_gdf['location_id']))
# Out:
# 432

# %%
len(sensor_ids)
# Out:
# 1971

# %%
sensor_ids[:10]
# Out:
# [1502, 1837, 1866, 1876, 22301, 25500, 4272146, 25501, 4272073, 1888]

# %%
ids_sql = ",".join(str(i) for i in sensor_ids)

# %%
ids_sql[:20]
# Out:
# '1502,1837,1866,1876,'

# %% [markdown]
# len(la_sensors_gdf['location_id'])

# %%
cursor.execute(f"""
SELECT * 
FROM openaq_db.openaqMeasurements 
WHERE sensors_id IN ({ids_sql})
ORDER BY datetime DESC
LIMIT 100;
""")
query_practice2 = cursor.fetchall()

# %%
query_practice2 = [query_practice2[i][:-3] for i in range(len(query_practice2))]
query_practice2_df = pd.DataFrame(data=query_practice2,columns=athena_cols)

# %%
query_practice2_df.head()
# Out:
#    location_id  sensors_id                          location  \
# 0      3293942    11489156               Yorba Linda-3263887
# 1      3293942    11489160               Yorba Linda-3263887
# 2      3293942    11489166               Yorba Linda-3263887
# 3      3293942    11489150               Yorba Linda-3263887
# 4      3273175    11333890  Yorba Linda Lakebed Park-3243120
#
#                     datetime       lat        lon         parameter  \
# 0  2025-12-12T00:00:00-08:00  33.88674 -117.70468              pm25
# 1  2025-12-12T00:00:00-08:00  33.88674 -117.70468               pm1
# 2  2025-12-12T00:00:00-08:00  33.88674 -117.70468       temperature
# 3  2025-12-12T00:00:00-08:00  33.88674 -117.70468  relativehumidity
# 4  2025-12-12T00:00:00-08:00  33.87807 -117.81213             um003
#
#            units       value
# 0          µg/m³   34.560500
# 1          µg/m³   22.955167
# 2              c   18.553833
# 3              %   46.891500
# 4  particles/cm³  762.502336

# %% [markdown]
# I expected this to only return PM2.5 readings. I think I didn't trim the dataset in the first place.

# %% [markdown]
# ### New

# %%
cursor.execute(f"""
SELECT * 
FROM openaq_db.openaqMeasurements 
ORDER BY datetime DESC
LIMIT 5;
""")
query_practice = cursor.fetchall()

# %%
query_practice = [query_practice[i][:-3] for i in range(len(query_practice))]
query_practice_df = pd.DataFrame(data=query_practice,columns=athena_cols)

# %%
query_practice_df.head()
# Out:
#    location_id  sensors_id     location                   datetime      lat  \
# 0         1052       25500  Pomona-1052  2025-12-12T00:00:00-08:00  34.0667
# 1         1052       25501  Pomona-1052  2025-12-12T00:00:00-08:00  34.0667
# 2         1052        1888  Pomona-1052  2025-12-12T00:00:00-08:00  34.0667
# 3         1052     4272146  Pomona-1052  2025-12-12T00:00:00-08:00  34.0667
# 4         1052     4272073  Pomona-1052  2025-12-12T00:00:00-08:00  34.0667
#
#         lon parameter units   value
# 0 -117.7506        co   ppm  0.7000
# 1 -117.7506       no2   ppm  0.0354
# 2 -117.7506        o3   ppm  0.0010
# 3 -117.7506        no   ppm  0.0289
# 4 -117.7506       nox   ppm  0.0643
