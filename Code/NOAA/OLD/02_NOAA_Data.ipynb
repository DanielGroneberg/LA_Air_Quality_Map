# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

import requests
import json

# %%
headers = {
    "token": "QBzqRxBKUHUOpoLVBhEeXsYmSsRciZwk"
}

# %%
url = "https://www.ncei.noaa.gov/cdo-web/api/v2/datasets"
response = requests.get(url,headers=headers)
data = response.json()
data
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 11, 'limit': 25}},
#  'results': [{'uid': 'gov.noaa.ncdc:C00861',
#    'mindate': '1763-01-01',
#    'maxdate': '2025-11-03',
#    'name': 'Daily Summaries',
#    'datacoverage': 1,
#    'id': 'GHCND'},
#   {'uid': 'gov.noaa.ncdc:C00946',
#    'mindate': '1763-01-01',
#    'maxdate': '2025-09-01',
#    'name': 'Global Summary of the Month',
#    'datacoverage': 1,
#    'id': 'GSOM'},
#   {'uid': 'gov.noaa.ncdc:C00947',
#    'mindate': '1763-01-01',
#    'maxdate': '2025-01-01',
#    'name': 'Global Summary of the Year',
#    'datacoverage': 1,
#    'id': 'GSOY'},
#   {'uid': 'gov.noaa.ncdc:C00345',
#    'mindate': '1991-06-05',
#    'maxdate': '2025-10-12',
#    'name': 'Weather Radar (Level II)',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD2'},
#   {'uid': 'gov.noaa.ncdc:C00708',
#    'mindate': '1994-05-20',
#    'maxdate': '2025-11-06',
#    'name': 'Weather Radar (Level III)',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD3'},
# ...

# %% [markdown]
# Looking into:
#
# ```
#  {'uid': 'gov.noaa.ncdc:C00824',
#    'mindate': '2010-01-01',
#    'maxdate': '2010-12-31',
#    'name': 'Normals Hourly',
#    'datacoverage': 1,
#    'id': 'NORMAL_HLY'},
# ```

# %% [markdown]
# ### Normals Hourly

# %% [markdown]
# https://www.ncdc.noaa.gov/cdo-web/webservices/v2#data

# %% [markdown]
# The `noaa_stations_gdf` dataset has an `id` feature which can be used to query stations which are within the LA County bounding box

# %%
noaa_stations_gdf = gpd.read_file(r'../../Data/Outputs/noaa_stations_gdf.geojson')

# %%
noaa_stations_gdf.head()
# Out:
#    elevation    mindate    maxdate  latitude  \
# 0      863.5 1931-01-01 2013-12-01  34.49380
# 1      721.5 1939-09-01 1992-10-30  34.31667
# 2      343.5 1931-01-01 2015-11-01  34.18211
# 3       70.7 1989-08-01 2015-11-01  33.86470
# 4      371.9 1931-01-01 1974-06-01  34.21667
#
#                                       name  datacoverage           id  \
# 0            ACTON ESCONDIDO CANYON, CA US        0.8986  COOP:040014
# 1               ALISO CANYON FC 446, CA US        0.9711  COOP:040115
# 2                          ALTADENA, CA US        0.9362  COOP:040144
# 3                           ANAHEIM, CA US        0.9684  COOP:040192
# 4  ARROYO SECO RANGER STATION FC508, CA US        0.9962  COOP:040327
#
#   elevationUnit  longitude                     geometry
# 0        METERS -118.27130    POINT (-118.2713 34.4938)
# 1        METERS -118.55000     POINT (-118.55 34.31667)
# 2        METERS -118.13827  POINT (-118.13827 34.18211)
# ...

# %%
datasetid = 'NORMAL_HLY'

# %%
stationids = noaa_stations_gdf['id']

# %%
stationids[:5]
# Out:
# 0    COOP:040014
# 1    COOP:040115
# 2    COOP:040144
# 3    COOP:040192
# 4    COOP:040327
# Name: id, dtype: object

# %%
datasetid
# Out:
# 'NORMAL_HLY'

# %%
url = f"https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND2&stationid=COOP:040144&startdate=2010-05-01&enddate=2011-05-31"
response = requests.get(url,headers=headers)
print(response)
data = response.json()
data
# Out:
# <Response [500]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/requests/models.py:965, in Response.json(self, **kwargs)
#     964 try:
# --> 965     return complexjson.loads(self.content.decode(encoding), **kwargs)
#     966 except UnicodeDecodeError:
#     967     # Wrong UTF codec detected; usually because it's not UTF-8
#     968     # but some other 8-bit codec.  This is an RFC violation,
#     969     # and the server didn't bother to tell us what codec *was*
#     970     # used.
#
# File ~/miniforge3/envs/la_env/lib/python3.14/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
# ...
