# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# import json
# from pandas import json_normalize

import datetime as dt

import geopandas as gpd
# from geopandas import GeoDataFrame

# from shapely.geometry import Point

# from openaq import OpenAQ

# from pyathena import connect

# from dotenv import load_dotenv 
# import os

# %%
la_bounds_gdf = gpd.read_file("../../Data/Inputs/Boundary_Shapefile/la_mainland.geojson")

# %%
sensors_gdf = gpd.read_file('../../Data/Outputs/sensors.geojson')

# %%
sensors_gdf.set_index('sensors_id',inplace=True)

# %%
sensors_gdf.head()
# Out:
#             station_id pollutant              name        datetime_first.utc  \
# sensors_id
# 1502               847     PM2.5  South Long Beach 2016-03-06 20:00:00+00:00
# 1837              1019        O₃          Pasadena 2016-03-06 20:00:00+00:00
# 1866              1036        O₃       Pico Rivera 2016-03-06 20:00:00+00:00
# 1876              1042        O₃    Piru - Pacific 2016-03-06 20:00:00+00:00
# 22301             1042     PM2.5    Piru - Pacific 2016-03-06 20:00:00+00:00
#
#                    datetime_last.utc             timezone  is_mobile  \
# sensors_id
# 1502       2022-05-05 22:00:00+00:00  America/Los_Angeles      False
# 1837       2016-11-09 21:00:00+00:00  America/Los_Angeles      False
# 1866       2016-11-09 21:00:00+00:00  America/Los_Angeles      False
# 1876       2020-06-10 21:00:00+00:00  America/Los_Angeles      False
# 22301      2020-06-10 21:00:00+00:00  America/Los_Angeles      False
#
#             is_monitor                                            bounds  \
# sensors_id
# 1502              True  [-118.175278, 33.792221, -118.175278, 33.792221]
# 1837              True          [-118.1081, 34.0833, -118.1081, 34.0833]
# 1866              True      [-118.059196, 34.0131, -118.059196, 34.0131]
# 1876              True              [-118.81, 34.4044, -118.81, 34.4044]
# 22301             True              [-118.81, 34.4044, -118.81, 34.4044]
#
#             country.id  ...   country.name owner.id  \
# sensors_id              ...
# 1502               155  ...  United States        4
# 1837               155  ...  United States        4
# 1866               155  ...  United States        4
# 1876               155  ...  United States        4
# 22301              155  ...  United States        4
#
#                                    owner.name provider.id  provider.name  \
# sensors_id
# 1502        Unknown Governmental Organization         119         AirNow
# 1837        Unknown Governmental Organization         119         AirNow
# 1866        Unknown Governmental Organization         119         AirNow
# 1876        Unknown Governmental Organization         119         AirNow
# 22301       Unknown Governmental Organization         119         AirNow
#
#            coordinates.latitude  coordinates.longitude     instrument_name  \
# sensors_id
# 1502                  33.792221            -118.175278  Government Monitor
# 1837                  34.083300            -118.108100  Government Monitor
# 1866                  34.013100            -118.059196  Government Monitor
# 1876                  34.404400            -118.810000  Government Monitor
# 22301                 34.404400            -118.810000  Government Monitor
#
#            instrument_id                     geometry
# sensors_id
# 1502                   2  POINT (-118.17528 33.79222)
# 1837                   2    POINT (-118.1081 34.0833)
# 1866                   2    POINT (-118.0592 34.0131)
# 1876                   2      POINT (-118.81 34.4044)
# 22301                  2      POINT (-118.81 34.4044)
#
# [5 rows x 21 columns]

# %%
sensors_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 1966 entries, 1502 to 14679598
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   station_id             1966 non-null   int32
#  1   pollutant              1966 non-null   object
#  2   name                   1966 non-null   object
#  3   datetime_first.utc     1966 non-null   datetime64[ms, UTC]
#  4   datetime_last.utc      1966 non-null   datetime64[ms, UTC]
#  5   timezone               1966 non-null   object
#  6   is_mobile              1966 non-null   bool
#  7   is_monitor             1966 non-null   bool
#  8   bounds                 1966 non-null   object
#  9   country.id             1966 non-null   int32
#  10  country.code           1966 non-null   object
#  11  country.name           1966 non-null   object
#  12  owner.id               1966 non-null   int32
#  13  owner.name             1966 non-null   object
#  14  provider.id            1966 non-null   int32
#  15  provider.name          1966 non-null   object
#  16  coordinates.latitude   1966 non-null   float64
#  17  coordinates.longitude  1966 non-null   float64
#  18  instrument_name        1966 non-null   object
#  19  instrument_id          1966 non-null   int32
#  20  geometry               1966 non-null   geometry
# dtypes: bool(2), datetime64[ms, UTC](2), float64(2), geometry(1), int32(5), object(9)
# memory usage: 264.9+ KB

# %%
sensors_gdf['pollutant'].unique()
# Out:
# 13

# %% [markdown]
# ### Oldest entries

# %% [markdown]
# The oldest data is from 2016

# %%
sensors_gdf.sort_values(by=['datetime_first.utc']).head()
# Out:
#             station_id pollutant                  name  \
# sensors_id
# 1502               847     PM2.5      South Long Beach
# 8683              1575       SO₂  Los Angeles - N. Mai
# 2794              1585        O₃                Upland
# 2793              1585      PM10                Upland
# 2792              1585     PM2.5                Upland
#
#                   datetime_first.utc         datetime_last.utc  \
# sensors_id
# 1502       2016-03-06 20:00:00+00:00 2022-05-05 22:00:00+00:00
# 8683       2016-03-06 20:00:00+00:00 2017-06-07 21:00:00+00:00
# 2794       2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00
# 2793       2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00
# 2792       2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00
#
#                        timezone  is_mobile  is_monitor  \
# sensors_id
# 1502        America/Los_Angeles      False        True
# 8683        America/Los_Angeles      False        True
# 2794        America/Los_Angeles      False        True
# 2793        America/Los_Angeles      False        True
# 2792        America/Los_Angeles      False        True
#
#                                                       bounds  country.id  ...  \
# sensors_id                                                                ...
# 1502        [-118.175278, 33.792221, -118.175278, 33.792221]         155  ...
# 8683                [-118.2417, 34.0669, -118.2417, 34.0669]         155  ...
# 2794                [-117.6733, 34.0986, -117.6733, 34.0986]         155  ...
# 2793                [-117.6733, 34.0986, -117.6733, 34.0986]         155  ...
# 2792                [-117.6733, 34.0986, -117.6733, 34.0986]         155  ...
#
#              country.name owner.id                         owner.name  \
# sensors_id
# 1502        United States        4  Unknown Governmental Organization
# 8683        United States        4  Unknown Governmental Organization
# 2794        United States        4  Unknown Governmental Organization
# 2793        United States        4  Unknown Governmental Organization
# 2792        United States        4  Unknown Governmental Organization
#
#            provider.id  provider.name coordinates.latitude  \
# sensors_id
# 1502               119         AirNow            33.792221
# 8683               119         AirNow            34.066900
# 2794               119         AirNow            34.098600
# 2793               119         AirNow            34.098600
# 2792               119         AirNow            34.098600
#
#             coordinates.longitude     instrument_name instrument_id  \
# sensors_id
# 1502                  -118.175278  Government Monitor             2
# 8683                  -118.241700  Government Monitor             2
# 2794                  -117.673300  Government Monitor             2
# 2793                  -117.673300  Government Monitor             2
# 2792                  -117.673300  Government Monitor             2
#
#                                geometry
# sensors_id
# 1502        POINT (-118.17528 33.79222)
# 8683          POINT (-118.2417 34.0669)
# 2794          POINT (-117.6733 34.0986)
# 2793          POINT (-117.6733 34.0986)
# 2792          POINT (-117.6733 34.0986)
#
# [5 rows x 21 columns]

# %%
len(sensors_gdf.sort_values(by=['datetime_first.utc']))
# Out:
# 1966

# %% [markdown]
# The oldest `PM2.5` entries are also from 2016

# %%
sensors_gdf[sensors_gdf['pollutant'] == 'PM2.5'].sort_values(by=['datetime_first.utc']).head()
# Out:
#             station_id pollutant                  name  \
# sensors_id
# 1502               847     PM2.5      South Long Beach
# 22301             1042     PM2.5        Piru - Pacific
# 2150              1200     PM2.5     Glendora - Laurel
# 2775              1575     PM2.5  Los Angeles - N. Mai
# 2792              1585     PM2.5                Upland
#
#                   datetime_first.utc         datetime_last.utc  \
# sensors_id
# 1502       2016-03-06 20:00:00+00:00 2022-05-05 22:00:00+00:00
# 22301      2016-03-06 20:00:00+00:00 2020-06-10 21:00:00+00:00
# 2150       2016-03-06 20:00:00+00:00 2025-12-10 01:00:00+00:00
# 2775       2016-03-06 20:00:00+00:00 2017-06-07 21:00:00+00:00
# 2792       2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00
#
#                        timezone  is_mobile  is_monitor  \
# sensors_id
# 1502        America/Los_Angeles      False        True
# 22301       America/Los_Angeles      False        True
# 2150        America/Los_Angeles      False        True
# 2775        America/Los_Angeles      False        True
# 2792        America/Los_Angeles      False        True
#
#                                                        bounds  country.id  \
# sensors_id
# 1502         [-118.175278, 33.792221, -118.175278, 33.792221]         155
# 22301                    [-118.81, 34.4044, -118.81, 34.4044]         155
# 2150        [-117.85080000000002, 34.1439, -117.8508000000...         155
# 2775                 [-118.2417, 34.0669, -118.2417, 34.0669]         155
# 2792                 [-117.6733, 34.0986, -117.6733, 34.0986]         155
#
#             ...   country.name owner.id                         owner.name  \
# sensors_id  ...
# 1502        ...  United States        4  Unknown Governmental Organization
# 22301       ...  United States        4  Unknown Governmental Organization
# 2150        ...  United States        4  Unknown Governmental Organization
# 2775        ...  United States        4  Unknown Governmental Organization
# 2792        ...  United States        4  Unknown Governmental Organization
#
#            provider.id  provider.name coordinates.latitude  \
# sensors_id
# 1502               119         AirNow            33.792221
# 22301              119         AirNow            34.404400
# 2150               119         AirNow            34.143900
# 2775               119         AirNow            34.066900
# 2792               119         AirNow            34.098600
#
#             coordinates.longitude     instrument_name instrument_id  \
# sensors_id
# 1502                  -118.175278  Government Monitor             2
# 22301                 -118.810000  Government Monitor             2
# 2150                  -117.850800  Government Monitor             2
# 2775                  -118.241700  Government Monitor             2
# 2792                  -117.673300  Government Monitor             2
#
#                                geometry
# sensors_id
# 1502        POINT (-118.17528 33.79222)
# 22301           POINT (-118.81 34.4044)
# 2150          POINT (-117.8508 34.1439)
# 2775          POINT (-118.2417 34.0669)
# 2792          POINT (-117.6733 34.0986)
#
# [5 rows x 21 columns]

# %%
sensors_gdf = sensors_gdf

# %% [markdown]
# ## Complete temporal coverage

# %% [markdown]
# For the sake of simplicity, I will use "complete temporal coverage" to mean stations or sensors with a first entry in 2016 and a latest entry in the current year.
#
# Even though I'm calling this complete temporal coverage, this alone doesn't show whether the station has an entry in 2017, 2018 . . . and in the case of `sensors_all_years_gdf`, it's only showing that there has been **any** entry in 2016 and 2025 - of any pollutant class. One Relative Humidity reading in 2016 and one PM1 reading in 2025 would show up as complete temporal coverage according to this initial check.

# %% [markdown]
# I want to map the distribution of stations which have a starting entry in 2016 and a most recent entry in the current year.

# %%
sensors_all_years_gdf = sensors_gdf[(sensors_gdf['datetime_first.utc'] > '2016') & (sensors_gdf['datetime_last.utc'] > str(dt.datetime.today().year))]

# %%
sensors_all_years_gdf.head(3)
# Out:
#             station_id pollutant    name        datetime_first.utc  \
# sensors_id
# 25500             1052        CO  Pomona 2016-03-06 20:00:00+00:00
# 4272146           1052        NO  Pomona 2016-03-06 20:00:00+00:00
# 25501             1052       NO₂  Pomona 2016-03-06 20:00:00+00:00
#
#                    datetime_last.utc             timezone  is_mobile  \
# sensors_id
# 25500      2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 4272146    2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 25501      2025-12-10 01:00:00+00:00  America/Los_Angeles      False
#
#             is_monitor                                    bounds  country.id  \
# sensors_id
# 25500             True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
# 4272146           True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
# 25501             True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
#
#             ...   country.name owner.id                         owner.name  \
# sensors_id  ...
# 25500       ...  United States        4  Unknown Governmental Organization
# 4272146     ...  United States        4  Unknown Governmental Organization
# 25501       ...  United States        4  Unknown Governmental Organization
#
#            provider.id  provider.name coordinates.latitude  \
# sensors_id
# 25500              119         AirNow              34.0667
# 4272146            119         AirNow              34.0667
# 25501              119         AirNow              34.0667
#
#             coordinates.longitude     instrument_name instrument_id  \
# sensors_id
# 25500                   -117.7506  Government Monitor             2
# 4272146                 -117.7506  Government Monitor             2
# 25501                   -117.7506  Government Monitor             2
#
#                              geometry
# sensors_id
# 25500       POINT (-117.7506 34.0667)
# 4272146     POINT (-117.7506 34.0667)
# 25501       POINT (-117.7506 34.0667)
#
# [3 rows x 21 columns]

# %%
len(sensors_all_years_gdf)
# Out:
# 1665

# %%
fig, ax = plt.subplots(figsize=(10, 10), label='Inline label');
sensors_all_years_gdf.plot(ax=ax, color='none', edgecolor='red',label='All pollutants');
la_bounds_gdf.plot(ax=ax, color='none', edgecolor='black');
ax.set_title(f"Stations with Entries in 2016 and {str(dt.datetime.today().year)}");
ax.legend(loc='best');

# %% [markdown]
# This map shows stations where the oldest entry is from 2016 and the most recent is from 2025 (or the notebook was ran) - these stations are good candidates for strong data coverage.
#
# I will look at which pollutant classes have the most entries:

# %%
sensors_all_years_gdf['pollutant'].value_counts()
# Out:
# pollutant
# PM2.5              341
# PM1                278
# Temperature (C)    273
# PM10               237
# Temperature (F)    194
# RH                 150
# PM0.3 count         79
# NO₂                 45
# NOx                 18
# NO                  18
# O₃                  17
# CO                  13
# SO₂                  2
# Name: count, dtype: int64

# %% [markdown]
# ## Spatial distribution of PM2.5

# %% [markdown]
# Since `PM2.5` has a strong presence, I will look into its spatial distribution, for stations with entries in 2016 and 2025:

# %%
sensors_all_years_pm25_gdf = sensors_gdf[(sensors_gdf['pollutant'] == 'PM2.5') & (sensors_gdf['datetime_first.utc'] > '2016') & (sensors_gdf['datetime_last.utc'] > str(dt.datetime.today().year))]

# %%
sensors_all_years_pm25_gdf.head(3)
# Out:
#             station_id pollutant               name        datetime_first.utc  \
# sensors_id
# 2150              1200     PM2.5  Glendora - Laurel 2016-03-06 20:00:00+00:00
# 25551             1948     PM2.5            EBAM 11 2016-03-06 20:00:00+00:00
# 3523              1989     PM2.5      Santa Clarita 2016-03-06 20:00:00+00:00
#
#                    datetime_last.utc             timezone  is_mobile  \
# sensors_id
# 2150       2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 25551      2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 3523       2025-12-10 01:00:00+00:00  America/Los_Angeles      False
#
#             is_monitor                                             bounds  \
# sensors_id
# 2150              True  [-117.85080000000002, 34.1439, -117.8508000000...
# 25551             True       [-118.20502, 33.90144, -118.20502, 33.90144]
# 3523              True  [-118.52829999999999, 34.3833, -118.5282999999...
#
#             country.id  ...   country.name owner.id  \
# sensors_id              ...
# 2150               155  ...  United States        4
# 25551              155  ...  United States        4
# 3523               155  ...  United States        4
#
#                                    owner.name provider.id  provider.name  \
# sensors_id
# 2150        Unknown Governmental Organization         119         AirNow
# 25551       Unknown Governmental Organization         119         AirNow
# 3523        Unknown Governmental Organization         119         AirNow
#
#            coordinates.latitude  coordinates.longitude     instrument_name  \
# sensors_id
# 2150                   34.14390             -117.85080  Government Monitor
# 25551                  33.90144             -118.20502  Government Monitor
# 3523                   34.38330             -118.52830  Government Monitor
#
#            instrument_id                     geometry
# sensors_id
# 2150                   2    POINT (-117.8508 34.1439)
# 25551                  2  POINT (-118.20502 33.90144)
# 3523                   2    POINT (-118.5283 34.3833)
#
# [3 rows x 21 columns]

# %% [markdown]
# To clarify, the length of this `PM2.5` dataframe being much smaller is not a cause for concern - because the original `sensors_all_years_gdf` has entries for each pollutant class, it will be far larger:

# %%
print(len(sensors_all_years_gdf))
print(len(sensors_all_years_pm25_gdf))
# Out:
# 1665
# 341

# %%
fig, ax = plt.subplots(figsize=(10,10), label='Inline label',dpi=200);
sensors_all_years_pm25_gdf.plot(ax=ax, color='none', edgecolor='blue',label='PM2.5');
la_bounds_gdf.plot(ax=ax, color='none', edgecolor='black');
ax.set_title("PM2.5 Sensors with Complete Temporal Coverage");
ax.legend(loc='best');

# %% [markdown]
# On a brief look, the coverage for just `PM2.5` is about as strong as the coverage for pollutants in general.

# %%
fig, ax = plt.subplots(figsize=(10,10), label='Inline label',dpi=200);
sensors_all_years_gdf.plot(ax=ax, color='none', edgecolor='red',label="All other pollutants");
sensors_all_years_pm25_gdf.plot(ax=ax, color='none', edgecolor='blue',label="PM2.5");
la_bounds_gdf.plot(ax=ax, color='none', edgecolor='black');
ax.set_title(f"PM2.5 vs All Other Sensor Types, With Complete Temporal Coverage (2016 - {str(dt.datetime.today().year)})");
ax.legend(loc='best');

# %% [markdown]
# Because `PM2.5` is plotted second, it is sitting on top. Stations in red have any entry in 2016 and 2025 - except `PM2.5`. Basically, we are losing out on these stations by specifically picking `PM2.5`.
#
# The loss looks fairly minor. It is especially important that the two stations in the far North (Lancaster) are still here - we are keeping as much spatial coverage as possible.

# %%
sensors_all_years_gdf['pollutant'].value_counts()
# Out:
# pollutant
# PM2.5              341
# PM1                278
# Temperature (C)    273
# PM10               237
# Temperature (F)    194
# RH                 150
# PM0.3 count         79
# NO₂                 45
# NOx                 18
# NO                  18
# O₃                  17
# CO                  13
# SO₂                  2
# Name: count, dtype: int64

# %% [markdown]
# The next most popular class has significantly less data:

# %%
278/341
# Out:
# 0.8152492668621701

# %% [markdown]
# `PM1` is only 80% as populated. In general, my plan is to use `PM2.5` as the target variable and only keep non-pollutant data types as predictors: `Temperature (C)` with temperature data converted from F, and `RH` (relative humidity)

# %%
def f_to_c(f):
    return (f - 32) * 5.0 / 9.0

# %%
sensors_all_years_gdf.to_file(r"../../Data/Outputs/sensors_all_years.geojson",driver="GeoJSON")

# %% [markdown]
# ### Visualizing spatial/temporal coverage by pollutant class

# %% [markdown]
# I want to plot the spatial coverage of sensors with complete temporal coverage (entries from 2016 to present) to see whether one pollutant class has uniquely good coverage across LA county

# %%
sensors_all_years_gdf.head(2)
# Out:
#             station_id pollutant    name        datetime_first.utc  \
# sensors_id
# 25500             1052        CO  Pomona 2016-03-06 20:00:00+00:00
# 4272146           1052        NO  Pomona 2016-03-06 20:00:00+00:00
#
#                    datetime_last.utc             timezone  is_mobile  \
# sensors_id
# 25500      2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 4272146    2025-12-10 01:00:00+00:00  America/Los_Angeles      False
#
#             is_monitor                                    bounds  country.id  \
# sensors_id
# 25500             True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
# 4272146           True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
#
#             ...   country.name owner.id                         owner.name  \
# sensors_id  ...
# 25500       ...  United States        4  Unknown Governmental Organization
# 4272146     ...  United States        4  Unknown Governmental Organization
#
#            provider.id  provider.name coordinates.latitude  \
# sensors_id
# 25500              119         AirNow              34.0667
# 4272146            119         AirNow              34.0667
#
#             coordinates.longitude     instrument_name instrument_id  \
# sensors_id
# 25500                   -117.7506  Government Monitor             2
# 4272146                 -117.7506  Government Monitor             2
#
#                              geometry
# sensors_id
# 25500       POINT (-117.7506 34.0667)
# 4272146     POINT (-117.7506 34.0667)
#
# [2 rows x 21 columns]

# %%
pollutant_classes = sensors_all_years_gdf['pollutant'].unique()

# %%
pollutant_classes
# Out:
# array(['CO', 'NO', 'NO₂', 'NOx', 'O₃', 'PM10', 'PM2.5', 'SO₂', 'PM1',
#        'Temperature (C)', 'Temperature (F)', 'RH', 'PM0.3 count'],
#       dtype=object)

# %%
len(pollutant_classes)
# Out:
# 13

# %% [markdown]
# https://matplotlib.org/stable/gallery/color/named_colors.html
#
# https://xkcd.com/color/rgb/

# %%
len(list(mcolors.TABLEAU_COLORS))
# Out:
# 10

# %%
int(np.random.randint(0,len(list(mcolors.TABLEAU_COLORS))))
# Out:
# 0

# %%
list(mcolors.TABLEAU_COLORS)[int(np.random.randint(0,len(list(mcolors.TABLEAU_COLORS))))]
# Out:
# 'tab:green'

# %%
np.random.seed(42)
np.random.randint(0,2000)
# Out:
# 1126

# %%
np.random.seed(6)
fig, ax = plt.subplots(figsize=(10, 10), label='Inline label');

for pollutant in list(pollutant_classes):
    la_bounds_gdf.plot(ax=ax, color='none', edgecolor='black');
    sensors_all_years_gdf[sensors_all_years_gdf['pollutant'] == pollutant].plot(ax=ax, color=list(mcolors.TABLEAU_COLORS)[int(np.random.randint(0,len(list(mcolors.TABLEAU_COLORS))))], 
                                                                                edgecolor=list(mcolors.TABLEAU_COLORS)[int(np.random.randint(0,len(list(mcolors.TABLEAU_COLORS))))], 
                                                                                label=pollutant);
ax.set_title('Spatial coverage by sensor type for sensors with full temporal coverage (2016-2025)');
ax.legend();

# %% [markdown]
# This plot shows the spatial coverage of sensors which have oldest readings starting in 2016 and latest readings in 2025, divided by sensor type (pollutant class being measured). The plotted points will be overlapped, but it's been plotted sequentially, i.e. a `PM2.5` point indicates that no subsequent pollutant types: `SO2`, `PM1` . . . are present. I will plot this again in ArcGIS and get something easier to interpret.

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
sensors_gdf['datetime_last.utc'] = pd.to_datetime(sensors_gdf['datetime_last.utc'])

# %%
sensors_gdf.info()

# %%
sensors_gdf['pollutant'] = [sensors_gdf.iloc[i]['sensors']['parameter']['display_name'] for i in range(len(sensors_gdf))]

# %%
sensors_gdf['sensor_id'] = [sensors_gdf.iloc[i]['sensors']['id'] for i in range(len(sensors_gdf))]

# %%
sensors_gdf.drop(columns=['sensors'],inplace=True)

# %%
sensors_gdf.info()

# %%
sensors_gdf = sensors_gdf.sort_values(by='datetime_last.utc')

# %%
sensors_gdf.head()

# %%
sensors_gdf[(sensors_gdf['pollutant'] == 'PM2.5') & (sensors_gdf['datetime_last.utc'] > '2025-01-01')]

# %% [markdown]
# https://docs.python.org/3/library/datetime.html#datetime.datetime.now

# %%
today = dt.datetime.now(dt.timezone.utc)

# %%
one_week_ago = today - dt.timedelta(weeks=1)

# %%
active_pm2_5 = sensors_gdf[(sensors_gdf['pollutant'] == 'PM2.5') & (sensors_gdf['datetime_last.utc'] > one_week_ago)]

# %%
active_pm2_5 = active_pm2_5.sort_values(by='datetime_last.utc')

# %%
active_pm2_5.head()

# %%
sensors_gdf[sensors_gdf['id'] == 3778909]

# %%
active_pm2_5[active_pm2_5['sensor_id'] == 14152560]

# %%
active_pm2_5[active_pm2_5['id'] == 3778909]

# %%
active_pm2_5.info()

# %% [markdown]
# The `id` column can now be passed in to an Athena query

# %%
station_IDs = list(active_pm2_5['id'])

# %%
station_IDs[:10]

# %%
sensor_IDs = list(active_pm2_5['sensor_id'])
print(sensor_IDs[:5])

# %%
1/0
