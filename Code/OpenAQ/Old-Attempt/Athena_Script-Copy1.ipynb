# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

import json
from pandas import json_normalize

import datetime as dt

import geopandas as gpd
from geopandas import GeoDataFrame

from shapely.geometry import Point

from openaq import OpenAQ

from pyathena import connect

from dotenv import load_dotenv 
import os

# %% [markdown]
# https://www.codecademy.com/article/python-environment-variables

# %%
load_dotenv()

api_key = os.getenv("openaq_key") 
debug = os.getenv("DEBUG", "False")

# %%
la_bounds_gdf = gpd.read_file("../../Data/Inputs/Boundary_Shapefile/la_mainland.geojson")

# %%
la_bounds_gdf.plot();

# %%
# The bounding box for LA County
bbox = [-118.944703049253,
        33.7046743723892,
        -117.646385981235,
        34.823304156602]

# %%
client = OpenAQ(api_key)
response = client.locations.list(
    bbox=bbox,
    limit=1000
)
data = response.dict()
stations_df = json_normalize(data['results'])

# %%
stations_df.head(3)
# Out:
#      id              name locality             timezone  is_mobile  \
# 0   847  South Long Beach     None  America/Los_Angeles      False
# 1  1019          Pasadena     None  America/Los_Angeles      False
# 2  1036       Pico Rivera     None  America/Los_Angeles      False
#
#    is_monitor                                instruments  \
# 0        True  [{'id': 2, 'name': 'Government Monitor'}]
# 1        True  [{'id': 2, 'name': 'Government Monitor'}]
# 2        True  [{'id': 2, 'name': 'Government Monitor'}]
#
#                                              sensors  \
# 0  [{'id': 1502, 'name': 'pm25 µg/m³', 'parameter...
# 1  [{'id': 1837, 'name': 'o3 ppm', 'parameter': {...
# 2  [{'id': 1866, 'name': 'o3 ppm', 'parameter': {...
#
#                                              bounds distance  ...  \
# 0  [-118.175278, 33.792221, -118.175278, 33.792221]     None  ...
# 1          [-118.1081, 34.0833, -118.1081, 34.0833]     None  ...
# 2      [-118.059196, 34.0131, -118.059196, 34.0131]     None  ...
#
#    provider.id provider.name coordinates.latitude  coordinates.longitude  \
# 0          119        AirNow            33.792221            -118.175278
# 1          119        AirNow            34.083300            -118.108100
# 2          119        AirNow            34.013100            -118.059196
#
#      datetime_first.utc       datetime_first.local     datetime_last.utc  \
# 0  2016-03-06T20:00:00Z  2016-03-06T12:00:00-08:00  2022-05-05T22:00:00Z
# 1  2016-03-06T20:00:00Z  2016-03-06T12:00:00-08:00  2016-11-09T21:00:00Z
# 2  2016-03-06T20:00:00Z  2016-03-06T12:00:00-08:00  2016-11-09T21:00:00Z
#
#          datetime_last.local  datetime_first datetime_last
# 0  2022-05-05T15:00:00-07:00             NaN           NaN
# 1  2016-11-09T13:00:00-08:00             NaN           NaN
# 2  2016-11-09T13:00:00-08:00             NaN           NaN
#
# [3 rows x 25 columns]

# %%
stations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     435 non-null    int64
#  1   name                   435 non-null    object
#  2   locality               39 non-null     object
#  3   timezone               435 non-null    object
#  4   is_mobile              435 non-null    bool
#  5   is_monitor             435 non-null    bool
#  6   instruments            435 non-null    object
#  7   sensors                435 non-null    object
#  8   bounds                 435 non-null    object
#  9   distance               0 non-null      object
#  10  country.id             435 non-null    int64
#  11  country.code           435 non-null    object
#  12  country.name           435 non-null    object
#  13  owner.id               435 non-null    int64
#  14  owner.name             435 non-null    object
#  15  provider.id            435 non-null    int64
#  16  provider.name          435 non-null    object
#  17  coordinates.latitude   435 non-null    float64
#  18  coordinates.longitude  435 non-null    float64
#  19  datetime_first.utc     431 non-null    object
#  20  datetime_first.local   431 non-null    object
#  21  datetime_last.utc      431 non-null    object
#  22  datetime_last.local    431 non-null    object
#  23  datetime_first         0 non-null      float64
#  24  datetime_last          0 non-null      float64
# dtypes: bool(2), float64(4), int64(4), object(15)
# memory usage: 79.1+ KB

# %% [markdown]
# I will convert this to a geodataframe using the lat and long columns:

# %% [markdown]
# https://geopandas.org/en/stable/gallery/create_geopandas_from_pandas.html

# %%
stations_gdf = gpd.GeoDataFrame(
    stations_df, geometry=gpd.points_from_xy(stations_df['coordinates.longitude'], stations_df['coordinates.latitude']), crs="EPSG:4326"
)

# %%
stations_gdf.to_file("../../Data/Outputs/stations_gdf.geojson", driver="GeoJSON")

# %% [markdown]
# There are several columns which have large amounts of null entries and don't add much to the dataset, so I will drop them. I will also drop the local datetime features and only use the `UTC` ones:

# %%
stations_gdf.drop(columns=['locality','distance','datetime_first','datetime_last','datetime_first.local', 'datetime_first.local'],inplace=True)

# %%
dt_cols = stations_gdf.columns[17:19]

# %%
for col in dt_cols:
    stations_gdf[col] = pd.to_datetime(stations_gdf[col])

# %%
stations_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     435 non-null    int64
#  1   name                   435 non-null    object
#  2   timezone               435 non-null    object
#  3   is_mobile              435 non-null    bool
#  4   is_monitor             435 non-null    bool
#  5   instruments            435 non-null    object
#  6   sensors                435 non-null    object
#  7   bounds                 435 non-null    object
#  8   country.id             435 non-null    int64
#  9   country.code           435 non-null    object
#  10  country.name           435 non-null    object
#  11  owner.id               435 non-null    int64
#  12  owner.name             435 non-null    object
#  13  provider.id            435 non-null    int64
#  14  provider.name          435 non-null    object
#  15  coordinates.latitude   435 non-null    float64
#  16  coordinates.longitude  435 non-null    float64
#  17  datetime_first.utc     431 non-null    datetime64[ns, UTC]
#  18  datetime_last.utc      431 non-null    datetime64[ns, UTC]
#  19  datetime_last.local    431 non-null    object
#  20  geometry               435 non-null    geometry
# dtypes: bool(2), datetime64[ns, UTC](2), float64(2), geometry(1), int64(4), object(10)
# memory usage: 65.5+ KB

# %% [markdown]
# The datetime features have some missing rows - any readings without a timestamp will be useless to me, so I will drop these:

# %%
stations_gdf.dropna(inplace=True)

# %%
stations_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 431 entries, 0 to 434
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     431 non-null    int64
#  1   name                   431 non-null    object
#  2   timezone               431 non-null    object
#  3   is_mobile              431 non-null    bool
#  4   is_monitor             431 non-null    bool
#  5   instruments            431 non-null    object
#  6   sensors                431 non-null    object
#  7   bounds                 431 non-null    object
#  8   country.id             431 non-null    int64
#  9   country.code           431 non-null    object
#  10  country.name           431 non-null    object
#  11  owner.id               431 non-null    int64
#  12  owner.name             431 non-null    object
#  13  provider.id            431 non-null    int64
#  14  provider.name          431 non-null    object
#  15  coordinates.latitude   431 non-null    float64
#  16  coordinates.longitude  431 non-null    float64
#  17  datetime_first.utc     431 non-null    datetime64[ns, UTC]
#  18  datetime_last.utc      431 non-null    datetime64[ns, UTC]
#  19  datetime_last.local    431 non-null    object
#  20  geometry               431 non-null    geometry
# dtypes: bool(2), datetime64[ns, UTC](2), float64(2), geometry(1), int64(4), object(10)
# memory usage: 68.2+ KB

# %%
stations_gdf.head()
# Out:
#      id              name             timezone  is_mobile  is_monitor  \
# 0   847  South Long Beach  America/Los_Angeles      False        True
# 1  1019          Pasadena  America/Los_Angeles      False        True
# 2  1036       Pico Rivera  America/Los_Angeles      False        True
# 3  1042    Piru - Pacific  America/Los_Angeles      False        True
# 4  1052            Pomona  America/Los_Angeles      False        True
#
#                                  instruments  \
# 0  [{'id': 2, 'name': 'Government Monitor'}]
# 1  [{'id': 2, 'name': 'Government Monitor'}]
# 2  [{'id': 2, 'name': 'Government Monitor'}]
# 3  [{'id': 2, 'name': 'Government Monitor'}]
# 4  [{'id': 2, 'name': 'Government Monitor'}]
#
#                                              sensors  \
# 0  [{'id': 1502, 'name': 'pm25 µg/m³', 'parameter...
# 1  [{'id': 1837, 'name': 'o3 ppm', 'parameter': {...
# 2  [{'id': 1866, 'name': 'o3 ppm', 'parameter': {...
# 3  [{'id': 1876, 'name': 'o3 ppm', 'parameter': {...
# 4  [{'id': 25500, 'name': 'co ppm', 'parameter': ...
#
#                                              bounds  country.id country.code  \
# 0  [-118.175278, 33.792221, -118.175278, 33.792221]         155           US
# 1          [-118.1081, 34.0833, -118.1081, 34.0833]         155           US
# 2      [-118.059196, 34.0131, -118.059196, 34.0131]         155           US
# 3              [-118.81, 34.4044, -118.81, 34.4044]         155           US
# 4          [-117.7506, 34.0667, -117.7506, 34.0667]         155           US
#
#    ... owner.id                         owner.name provider.id  provider.name  \
# 0  ...        4  Unknown Governmental Organization         119         AirNow
# 1  ...        4  Unknown Governmental Organization         119         AirNow
# 2  ...        4  Unknown Governmental Organization         119         AirNow
# 3  ...        4  Unknown Governmental Organization         119         AirNow
# 4  ...        4  Unknown Governmental Organization         119         AirNow
#
#   coordinates.latitude  coordinates.longitude        datetime_first.utc  \
# 0            33.792221            -118.175278 2016-03-06 20:00:00+00:00
# 1            34.083300            -118.108100 2016-03-06 20:00:00+00:00
# 2            34.013100            -118.059196 2016-03-06 20:00:00+00:00
# 3            34.404400            -118.810000 2016-03-06 20:00:00+00:00
# 4            34.066700            -117.750600 2016-03-06 20:00:00+00:00
#
#           datetime_last.utc        datetime_last.local  \
# 0 2022-05-05 22:00:00+00:00  2022-05-05T15:00:00-07:00
# 1 2016-11-09 21:00:00+00:00  2016-11-09T13:00:00-08:00
# 2 2016-11-09 21:00:00+00:00  2016-11-09T13:00:00-08:00
# 3 2020-06-10 21:00:00+00:00  2020-06-10T14:00:00-07:00
# 4 2025-12-10 01:00:00+00:00  2025-12-09T17:00:00-08:00
#
#                       geometry
# 0  POINT (-118.17528 33.79222)
# 1    POINT (-118.1081 34.0833)
# 2    POINT (-118.0592 34.0131)
# 3      POINT (-118.81 34.4044)
# 4    POINT (-117.7506 34.0667)
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Sensors feature

# %% [markdown]
# Currently, each station has a nested `sensors` feature which can contain multiple sensor readings corresponding to multiple pollutant types:

# %%
stations_gdf[stations_gdf['id'] == 1042]
# Out:
#      id            name             timezone  is_mobile  is_monitor  \
# 3  1042  Piru - Pacific  America/Los_Angeles      False        True
#
#                                  instruments  \
# 3  [{'id': 2, 'name': 'Government Monitor'}]
#
#                                              sensors  \
# 3  [{'id': 1876, 'name': 'o3 ppm', 'parameter': {...
#
#                                  bounds  country.id country.code  ...  \
# 3  [-118.81, 34.4044, -118.81, 34.4044]         155           US  ...
#
#   owner.id                         owner.name provider.id  provider.name  \
# 3        4  Unknown Governmental Organization         119         AirNow
#
#   coordinates.latitude  coordinates.longitude        datetime_first.utc  \
# 3              34.4044                -118.81 2016-03-06 20:00:00+00:00
#
#           datetime_last.utc        datetime_last.local  \
# 3 2020-06-10 21:00:00+00:00  2020-06-10T14:00:00-07:00
#
#                   geometry
# 3  POINT (-118.81 34.4044)
#
# [1 rows x 21 columns]

# %%
stations_gdf[stations_gdf['id'] == 1042]['sensors'][3]
# Out:
# [{'id': 1876,
#   'name': 'o3 ppm',
#   'parameter': {'id': 10, 'name': 'o3', 'units': 'ppm', 'display_name': 'O₃'}},
#  {'id': 22301,
#   'name': 'pm25 µg/m³',
#   'parameter': {'id': 2,
#    'name': 'pm25',
#    'units': 'µg/m³',
#    'display_name': 'PM2.5'}}]

# %% [markdown]
# Exploding the `sensors` feature will give each sensor type its own separate row:

# %%
stations_gdf.explode('sensors').head()
# Out:
#      id              name             timezone  is_mobile  is_monitor  \
# 0   847  South Long Beach  America/Los_Angeles      False        True
# 1  1019          Pasadena  America/Los_Angeles      False        True
# 2  1036       Pico Rivera  America/Los_Angeles      False        True
# 3  1042    Piru - Pacific  America/Los_Angeles      False        True
# 3  1042    Piru - Pacific  America/Los_Angeles      False        True
#
#                                  instruments  \
# 0  [{'id': 2, 'name': 'Government Monitor'}]
# 1  [{'id': 2, 'name': 'Government Monitor'}]
# 2  [{'id': 2, 'name': 'Government Monitor'}]
# 3  [{'id': 2, 'name': 'Government Monitor'}]
# 3  [{'id': 2, 'name': 'Government Monitor'}]
#
#                                              sensors  \
# 0  {'id': 1502, 'name': 'pm25 µg/m³', 'parameter'...
# 1  {'id': 1837, 'name': 'o3 ppm', 'parameter': {'...
# 2  {'id': 1866, 'name': 'o3 ppm', 'parameter': {'...
# 3  {'id': 1876, 'name': 'o3 ppm', 'parameter': {'...
# 3  {'id': 22301, 'name': 'pm25 µg/m³', 'parameter...
#
#                                              bounds  country.id country.code  \
# 0  [-118.175278, 33.792221, -118.175278, 33.792221]         155           US
# 1          [-118.1081, 34.0833, -118.1081, 34.0833]         155           US
# 2      [-118.059196, 34.0131, -118.059196, 34.0131]         155           US
# 3              [-118.81, 34.4044, -118.81, 34.4044]         155           US
# 3              [-118.81, 34.4044, -118.81, 34.4044]         155           US
#
#    ... owner.id                         owner.name provider.id  provider.name  \
# 0  ...        4  Unknown Governmental Organization         119         AirNow
# 1  ...        4  Unknown Governmental Organization         119         AirNow
# 2  ...        4  Unknown Governmental Organization         119         AirNow
# 3  ...        4  Unknown Governmental Organization         119         AirNow
# 3  ...        4  Unknown Governmental Organization         119         AirNow
#
#   coordinates.latitude  coordinates.longitude        datetime_first.utc  \
# 0            33.792221            -118.175278 2016-03-06 20:00:00+00:00
# 1            34.083300            -118.108100 2016-03-06 20:00:00+00:00
# 2            34.013100            -118.059196 2016-03-06 20:00:00+00:00
# 3            34.404400            -118.810000 2016-03-06 20:00:00+00:00
# 3            34.404400            -118.810000 2016-03-06 20:00:00+00:00
#
#           datetime_last.utc        datetime_last.local  \
# 0 2022-05-05 22:00:00+00:00  2022-05-05T15:00:00-07:00
# 1 2016-11-09 21:00:00+00:00  2016-11-09T13:00:00-08:00
# 2 2016-11-09 21:00:00+00:00  2016-11-09T13:00:00-08:00
# 3 2020-06-10 21:00:00+00:00  2020-06-10T14:00:00-07:00
# 3 2020-06-10 21:00:00+00:00  2020-06-10T14:00:00-07:00
#
#                       geometry
# 0  POINT (-118.17528 33.79222)
# 1    POINT (-118.1081 34.0833)
# 2    POINT (-118.0592 34.0131)
# 3      POINT (-118.81 34.4044)
# 3      POINT (-118.81 34.4044)
#
# [5 rows x 21 columns]

# %%
stations_explode = stations_gdf.explode('sensors')

# %% [markdown]
# I will also rename the existing `id` feature to make this more clear:

# %%
stations_explode.rename(columns={'id':'station_id'},inplace=True)

# %%
stations_explode.head()
# Out:
#    station_id              name             timezone  is_mobile  is_monitor  \
# 0         847  South Long Beach  America/Los_Angeles      False        True
# 1        1019          Pasadena  America/Los_Angeles      False        True
# 2        1036       Pico Rivera  America/Los_Angeles      False        True
# 3        1042    Piru - Pacific  America/Los_Angeles      False        True
# 3        1042    Piru - Pacific  America/Los_Angeles      False        True
#
#                                  instruments  \
# 0  [{'id': 2, 'name': 'Government Monitor'}]
# 1  [{'id': 2, 'name': 'Government Monitor'}]
# 2  [{'id': 2, 'name': 'Government Monitor'}]
# 3  [{'id': 2, 'name': 'Government Monitor'}]
# 3  [{'id': 2, 'name': 'Government Monitor'}]
#
#                                              sensors  \
# 0  {'id': 1502, 'name': 'pm25 µg/m³', 'parameter'...
# 1  {'id': 1837, 'name': 'o3 ppm', 'parameter': {'...
# 2  {'id': 1866, 'name': 'o3 ppm', 'parameter': {'...
# 3  {'id': 1876, 'name': 'o3 ppm', 'parameter': {'...
# 3  {'id': 22301, 'name': 'pm25 µg/m³', 'parameter...
#
#                                              bounds  country.id country.code  \
# 0  [-118.175278, 33.792221, -118.175278, 33.792221]         155           US
# 1          [-118.1081, 34.0833, -118.1081, 34.0833]         155           US
# 2      [-118.059196, 34.0131, -118.059196, 34.0131]         155           US
# 3              [-118.81, 34.4044, -118.81, 34.4044]         155           US
# 3              [-118.81, 34.4044, -118.81, 34.4044]         155           US
#
#    ... owner.id                         owner.name provider.id  provider.name  \
# 0  ...        4  Unknown Governmental Organization         119         AirNow
# 1  ...        4  Unknown Governmental Organization         119         AirNow
# 2  ...        4  Unknown Governmental Organization         119         AirNow
# 3  ...        4  Unknown Governmental Organization         119         AirNow
# 3  ...        4  Unknown Governmental Organization         119         AirNow
#
#   coordinates.latitude  coordinates.longitude        datetime_first.utc  \
# 0            33.792221            -118.175278 2016-03-06 20:00:00+00:00
# 1            34.083300            -118.108100 2016-03-06 20:00:00+00:00
# 2            34.013100            -118.059196 2016-03-06 20:00:00+00:00
# 3            34.404400            -118.810000 2016-03-06 20:00:00+00:00
# 3            34.404400            -118.810000 2016-03-06 20:00:00+00:00
#
#           datetime_last.utc        datetime_last.local  \
# 0 2022-05-05 22:00:00+00:00  2022-05-05T15:00:00-07:00
# 1 2016-11-09 21:00:00+00:00  2016-11-09T13:00:00-08:00
# 2 2016-11-09 21:00:00+00:00  2016-11-09T13:00:00-08:00
# 3 2020-06-10 21:00:00+00:00  2020-06-10T14:00:00-07:00
# 3 2020-06-10 21:00:00+00:00  2020-06-10T14:00:00-07:00
#
#                       geometry
# 0  POINT (-118.17528 33.79222)
# 1    POINT (-118.1081 34.0833)
# 2    POINT (-118.0592 34.0131)
# 3      POINT (-118.81 34.4044)
# 3      POINT (-118.81 34.4044)
#
# [5 rows x 21 columns]

# %% [markdown]
# I will add a separate feature for the pollutant type represented by each sensor entry:

# %%
stations_explode['pollutant'] = [stations_explode.iloc[i]['sensors']['parameter']['display_name'] for i in range(len(stations_explode))]

# %% [markdown]
# And an id feature for each sensor, which I will set as the index:

# %%
stations_explode['sensors_id'] = [stations_explode.iloc[i]['sensors']['id'] for i in range(len(stations_explode))]

# %%
stations_explode.set_index(keys=['sensors_id'],inplace=True)

# %% [markdown]
# https://stackoverflow.com/questions/53141240/pandas-how-to-swap-or-reorder-columns

# %% [markdown]
# I will also reorder the columns:

# %%
cols = ['station_id','pollutant','name','datetime_first.utc','datetime_last.utc']
stations_explode = stations_explode[cols + [c for c in stations_explode.columns if c not in cols]]

# %% [markdown]
# I will also drop the old `sensors` feature:

# %%
stations_explode.drop(columns=['sensors'],inplace=True)

# %%
stations_explode.head(3)
# Out:
#             station_id pollutant              name        datetime_first.utc  \
# sensors_id
# 1502               847     PM2.5  South Long Beach 2016-03-06 20:00:00+00:00
# 1837              1019        O₃          Pasadena 2016-03-06 20:00:00+00:00
# 1866              1036        O₃       Pico Rivera 2016-03-06 20:00:00+00:00
#
#                    datetime_last.utc             timezone  is_mobile  \
# sensors_id
# 1502       2022-05-05 22:00:00+00:00  America/Los_Angeles      False
# 1837       2016-11-09 21:00:00+00:00  America/Los_Angeles      False
# 1866       2016-11-09 21:00:00+00:00  America/Los_Angeles      False
#
#             is_monitor                                instruments  \
# sensors_id
# 1502              True  [{'id': 2, 'name': 'Government Monitor'}]
# 1837              True  [{'id': 2, 'name': 'Government Monitor'}]
# 1866              True  [{'id': 2, 'name': 'Government Monitor'}]
#
#                                                       bounds  ...  \
# sensors_id                                                    ...
# 1502        [-118.175278, 33.792221, -118.175278, 33.792221]  ...
# 1837                [-118.1081, 34.0833, -118.1081, 34.0833]  ...
# 1866            [-118.059196, 34.0131, -118.059196, 34.0131]  ...
#
#             country.code   country.name owner.id  \
# sensors_id
# 1502                  US  United States        4
# 1837                  US  United States        4
# 1866                  US  United States        4
#
#                                    owner.name provider.id  provider.name  \
# sensors_id
# 1502        Unknown Governmental Organization         119         AirNow
# 1837        Unknown Governmental Organization         119         AirNow
# 1866        Unknown Governmental Organization         119         AirNow
#
#            coordinates.latitude  coordinates.longitude  \
# sensors_id
# 1502                  33.792221            -118.175278
# 1837                  34.083300            -118.108100
# 1866                  34.013100            -118.059196
#
#                   datetime_last.local                     geometry
# sensors_id
# 1502        2022-05-05T15:00:00-07:00  POINT (-118.17528 33.79222)
# 1837        2016-11-09T13:00:00-08:00    POINT (-118.1081 34.0833)
# 1866        2016-11-09T13:00:00-08:00    POINT (-118.0592 34.0131)
#
# [3 rows x 21 columns]

# %%
stations_explode['pollutant'].unique()
# Out:
# array(['PM2.5', 'O₃', 'CO', 'NO', 'NO₂', 'NOx', 'PM10', 'SO₂', 'PM1',
#        'Temperature (C)', 'Temperature (F)', 'RH', 'PM0.3 count'],
#       dtype=object)

# %%
fig, ax = plt.subplots(figsize=(10, 10), label='Inline label');
stations_explode.plot(ax=ax, color='none', edgecolor='red');
la_bounds_gdf.plot(ax=ax, color='none', edgecolor='black');

# %% [markdown]
# ### Instruments

# %% [markdown]
# This is another nested feature:

# %%
stations_explode['instruments'][:2]
# Out:
# sensors_id
# 1502    [{'id': 2, 'name': 'Government Monitor'}]
# 1837    [{'id': 2, 'name': 'Government Monitor'}]
# Name: instruments, dtype: object

# %%
list(stations_explode['instruments'])[0][0]['name']
# Out:
# 'Government Monitor'

# %% [markdown]
# These are all the names of instrument types in the dataset:

# %%
set([list(stations_explode['instruments'])[i][0]['name'] for i in range(len(list(stations_explode['instruments'])))])
# Out:
# {'Aerosol Black Carbon Detector (ABCD)',
#  'AirGradient ONE Generation 9 (I-9PSL-DE)',
#  'AirGradient Open Air Generation 1 (O-1PST)',
#  'Clarity Sensor',
#  'Government Monitor',
#  'N/A',
#  'Unknown AirGradient Sensor'}

# %% [markdown]
# Each row now corresponds to one sensor and therefore one instrument, so I don't need to explode it again.

# %% [markdown]
# I will create new features for `instrument_id` and `instrument_name` on the off chance they become relevant:

# %%
stations_explode['instrument_name'] = [list(stations_explode['instruments'])[i][0]['name'] for i in range(len(list(stations_explode['instruments'])))]

# %%
stations_explode['instrument_id'] = [list(stations_explode['instruments'])[i][0]['id'] for i in range(len(list(stations_explode['instruments'])))]

# %%
stations_explode[['station_id','name','instrument_name','instrument_id']]
# Out:
#             station_id              name  \
# sensors_id
# 1502               847  South Long Beach
# 1837              1019          Pasadena
# 1866              1036       Pico Rivera
# 1876              1042    Piru - Pacific
# 22301             1042    Piru - Pacific
# ...                ...               ...
# 14628910       6129575      La Verne, CA
# 14628911       6129575      La Verne, CA
# 14628912       6129575      La Verne, CA
# 14628913       6129575      La Verne, CA
# 14679598       6136584            EBAM-2
#
#                                        instrument_name  instrument_id
# sensors_id
# 1502                                Government Monitor              2
# 1837                                Government Monitor              2
# 1866                                Government Monitor              2
# 1876                                Government Monitor              2
# 22301                               Government Monitor              2
# ...                                                ...            ...
# 14628910    AirGradient Open Air Generation 1 (O-1PST)             24
# 14628911    AirGradient Open Air Generation 1 (O-1PST)             24
# 14628912    AirGradient Open Air Generation 1 (O-1PST)             24
# 14628913    AirGradient Open Air Generation 1 (O-1PST)             24
# 14679598                            Government Monitor              2
#
# [1966 rows x 4 columns]

# %% [markdown]
# I can now drop the old `instruments` feature so it's not nested anymore:

# %%
stations_explode.drop(columns=['instruments'],inplace=True)

# %% [markdown]
# ### Oldest entries

# %% [markdown]
# The oldest data is from 2016

# %%
stations_explode.sort_values(by=['datetime_first.utc']).head()
# Out:
#             station_id pollutant                  name  \
# sensors_id
# 1502               847     PM2.5      South Long Beach
# 8683              1575       SO₂  Los Angeles - N. Mai
# 2794              1585        O₃                Upland
# 2793              1585      PM10                Upland
# 2792              1585     PM2.5                Upland
#
#                   datetime_first.utc         datetime_last.utc  \
# sensors_id
# 1502       2016-03-06 20:00:00+00:00 2022-05-05 22:00:00+00:00
# 8683       2016-03-06 20:00:00+00:00 2017-06-07 21:00:00+00:00
# 2794       2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00
# 2793       2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00
# 2792       2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00
#
#                        timezone  is_mobile  is_monitor  \
# sensors_id
# 1502        America/Los_Angeles      False        True
# 8683        America/Los_Angeles      False        True
# 2794        America/Los_Angeles      False        True
# 2793        America/Los_Angeles      False        True
# 2792        America/Los_Angeles      False        True
#
#                                                       bounds  country.id  ...  \
# sensors_id                                                                ...
# 1502        [-118.175278, 33.792221, -118.175278, 33.792221]         155  ...
# 8683                [-118.2417, 34.0669, -118.2417, 34.0669]         155  ...
# 2794                [-117.6733, 34.0986, -117.6733, 34.0986]         155  ...
# 2793                [-117.6733, 34.0986, -117.6733, 34.0986]         155  ...
# 2792                [-117.6733, 34.0986, -117.6733, 34.0986]         155  ...
#
#            owner.id                         owner.name  provider.id  \
# sensors_id
# 1502              4  Unknown Governmental Organization          119
# 8683              4  Unknown Governmental Organization          119
# 2794              4  Unknown Governmental Organization          119
# 2793              4  Unknown Governmental Organization          119
# 2792              4  Unknown Governmental Organization          119
#
#            provider.name  coordinates.latitude coordinates.longitude  \
# sensors_id
# 1502              AirNow             33.792221           -118.175278
# 8683              AirNow             34.066900           -118.241700
# 2794              AirNow             34.098600           -117.673300
# 2793              AirNow             34.098600           -117.673300
# 2792              AirNow             34.098600           -117.673300
#
#                   datetime_last.local                     geometry  \
# sensors_id
# 1502        2022-05-05T15:00:00-07:00  POINT (-118.17528 33.79222)
# 8683        2017-06-07T14:00:00-07:00    POINT (-118.2417 34.0669)
# 2794        2016-11-09T13:00:00-08:00    POINT (-117.6733 34.0986)
# 2793        2016-11-09T13:00:00-08:00    POINT (-117.6733 34.0986)
# 2792        2016-11-09T13:00:00-08:00    POINT (-117.6733 34.0986)
#
#                instrument_name instrument_id
# sensors_id
# 1502        Government Monitor             2
# 8683        Government Monitor             2
# 2794        Government Monitor             2
# 2793        Government Monitor             2
# 2792        Government Monitor             2
#
# [5 rows x 22 columns]

# %%
len(stations_explode.sort_values(by=['datetime_first.utc']))
# Out:
# 1966

# %% [markdown]
# The oldest `PM2.5` entries are also from 2016

# %%
stations_explode[stations_explode['pollutant'] == 'PM2.5'].sort_values(by=['datetime_first.utc']).head()
# Out:
#             station_id pollutant                  name  \
# sensors_id
# 1502               847     PM2.5      South Long Beach
# 22301             1042     PM2.5        Piru - Pacific
# 2150              1200     PM2.5     Glendora - Laurel
# 2775              1575     PM2.5  Los Angeles - N. Mai
# 2792              1585     PM2.5                Upland
#
#                   datetime_first.utc         datetime_last.utc  \
# sensors_id
# 1502       2016-03-06 20:00:00+00:00 2022-05-05 22:00:00+00:00
# 22301      2016-03-06 20:00:00+00:00 2020-06-10 21:00:00+00:00
# 2150       2016-03-06 20:00:00+00:00 2025-12-10 01:00:00+00:00
# 2775       2016-03-06 20:00:00+00:00 2017-06-07 21:00:00+00:00
# 2792       2016-03-06 20:00:00+00:00 2016-11-09 21:00:00+00:00
#
#                        timezone  is_mobile  is_monitor  \
# sensors_id
# 1502        America/Los_Angeles      False        True
# 22301       America/Los_Angeles      False        True
# 2150        America/Los_Angeles      False        True
# 2775        America/Los_Angeles      False        True
# 2792        America/Los_Angeles      False        True
#
#                                                        bounds  country.id  \
# sensors_id
# 1502         [-118.175278, 33.792221, -118.175278, 33.792221]         155
# 22301                    [-118.81, 34.4044, -118.81, 34.4044]         155
# 2150        [-117.85080000000002, 34.1439, -117.8508000000...         155
# 2775                 [-118.2417, 34.0669, -118.2417, 34.0669]         155
# 2792                 [-117.6733, 34.0986, -117.6733, 34.0986]         155
#
#             ... owner.id                         owner.name  provider.id  \
# sensors_id  ...
# 1502        ...        4  Unknown Governmental Organization          119
# 22301       ...        4  Unknown Governmental Organization          119
# 2150        ...        4  Unknown Governmental Organization          119
# 2775        ...        4  Unknown Governmental Organization          119
# 2792        ...        4  Unknown Governmental Organization          119
#
#            provider.name  coordinates.latitude coordinates.longitude  \
# sensors_id
# 1502              AirNow             33.792221           -118.175278
# 22301             AirNow             34.404400           -118.810000
# 2150              AirNow             34.143900           -117.850800
# 2775              AirNow             34.066900           -118.241700
# 2792              AirNow             34.098600           -117.673300
#
#                   datetime_last.local                     geometry  \
# sensors_id
# 1502        2022-05-05T15:00:00-07:00  POINT (-118.17528 33.79222)
# 22301       2020-06-10T14:00:00-07:00      POINT (-118.81 34.4044)
# 2150        2025-12-09T17:00:00-08:00    POINT (-117.8508 34.1439)
# 2775        2017-06-07T14:00:00-07:00    POINT (-118.2417 34.0669)
# 2792        2016-11-09T13:00:00-08:00    POINT (-117.6733 34.0986)
#
#                instrument_name instrument_id
# sensors_id
# 1502        Government Monitor             2
# 22301       Government Monitor             2
# 2150        Government Monitor             2
# 2775        Government Monitor             2
# 2792        Government Monitor             2
#
# [5 rows x 22 columns]

# %%
sensors_gdf = stations_explode

# %% [markdown]
# #### Complete coverage

# %%
len(stations_explode[stations_explode['pollutant'] == 'PM2.5'].sort_values(by=['datetime_first.utc']))
# Out:
# 413

# %% [markdown]
# I want to map the distribution of stations which have a starting entry in 2016 and a most recent entry in the current year.

# %%
sensors_all_years_gdf = stations_explode[(stations_explode['datetime_first.utc'] > '2016') & (stations_explode['datetime_last.utc'] > str(dt.datetime.today().year))]

# %%
sensors_all_years_gdf.head()
# Out:
#             station_id pollutant    name        datetime_first.utc  \
# sensors_id
# 25500             1052        CO  Pomona 2016-03-06 20:00:00+00:00
# 4272146           1052        NO  Pomona 2016-03-06 20:00:00+00:00
# 25501             1052       NO₂  Pomona 2016-03-06 20:00:00+00:00
# 4272073           1052       NOx  Pomona 2016-03-06 20:00:00+00:00
# 1888              1052        O₃  Pomona 2016-03-06 20:00:00+00:00
#
#                    datetime_last.utc             timezone  is_mobile  \
# sensors_id
# 25500      2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 4272146    2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 25501      2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 4272073    2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 1888       2025-12-10 01:00:00+00:00  America/Los_Angeles      False
#
#             is_monitor                                    bounds  country.id  \
# sensors_id
# 25500             True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
# 4272146           True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
# 25501             True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
# 4272073           True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
# 1888              True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
#
#             ... owner.id                         owner.name  provider.id  \
# sensors_id  ...
# 25500       ...        4  Unknown Governmental Organization          119
# 4272146     ...        4  Unknown Governmental Organization          119
# 25501       ...        4  Unknown Governmental Organization          119
# 4272073     ...        4  Unknown Governmental Organization          119
# 1888        ...        4  Unknown Governmental Organization          119
#
#            provider.name  coordinates.latitude coordinates.longitude  \
# sensors_id
# 25500             AirNow               34.0667             -117.7506
# 4272146           AirNow               34.0667             -117.7506
# 25501             AirNow               34.0667             -117.7506
# 4272073           AirNow               34.0667             -117.7506
# 1888              AirNow               34.0667             -117.7506
#
#                   datetime_last.local                   geometry  \
# sensors_id
# 25500       2025-12-09T17:00:00-08:00  POINT (-117.7506 34.0667)
# 4272146     2025-12-09T17:00:00-08:00  POINT (-117.7506 34.0667)
# 25501       2025-12-09T17:00:00-08:00  POINT (-117.7506 34.0667)
# 4272073     2025-12-09T17:00:00-08:00  POINT (-117.7506 34.0667)
# 1888        2025-12-09T17:00:00-08:00  POINT (-117.7506 34.0667)
#
#                instrument_name instrument_id
# sensors_id
# 25500       Government Monitor             2
# 4272146     Government Monitor             2
# 25501       Government Monitor             2
# 4272073     Government Monitor             2
# 1888        Government Monitor             2
#
# [5 rows x 22 columns]

# %%
len(sensors_all_years_gdf)
# Out:
# 1665

# %%
fig, ax = plt.subplots(figsize=(10, 10), label='Inline label');
sensors_all_years_gdf.plot(ax=ax, color='none', edgecolor='red');
la_bounds_gdf.plot(ax=ax, color='none', edgecolor='black');

# %% [markdown]
# I will repeat this, but only looking at `PM2.5`

# %%
sensors_all_years_pm25_gdf = stations_explode[(stations_explode['pollutant'] == 'PM2.5') & (stations_explode['datetime_first.utc'] > '2016') & (stations_explode['datetime_last.utc'] > str(dt.datetime.today().year))]

# %%
sensors_all_years_pm25_gdf.head()
# Out:
#             station_id pollutant               name        datetime_first.utc  \
# sensors_id
# 2150              1200     PM2.5  Glendora - Laurel 2016-03-06 20:00:00+00:00
# 25551             1948     PM2.5            Compton 2016-03-06 20:00:00+00:00
# 3523              1989     PM2.5      Santa Clarita 2016-03-06 20:00:00+00:00
# 3842              2138     PM2.5             Reseda 2016-03-06 20:00:00+00:00
# 15731             5791     PM2.5      710 Near Road 2016-11-15 21:00:00+00:00
#
#                    datetime_last.utc             timezone  is_mobile  \
# sensors_id
# 2150       2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 25551      2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 3523       2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 3842       2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 15731      2025-12-10 00:00:00+00:00  America/Los_Angeles      False
#
#             is_monitor                                             bounds  \
# sensors_id
# 2150              True  [-117.85080000000002, 34.1439, -117.8508000000...
# 25551             True             [-118.205, 33.9014, -118.205, 33.9014]
# 3523              True  [-118.52829999999999, 34.3833, -118.5282999999...
# 3842              True           [-118.5331, 34.1992, -118.5331, 34.1992]
# 15731             True  [-118.20070700000001, 33.859662, -118.20070700...
#
#             country.id  ... owner.id                         owner.name  \
# sensors_id              ...
# 2150               155  ...        4  Unknown Governmental Organization
# 25551              155  ...        4  Unknown Governmental Organization
# 3523               155  ...        4  Unknown Governmental Organization
# 3842               155  ...        4  Unknown Governmental Organization
# 15731              155  ...        4  Unknown Governmental Organization
#
#             provider.id provider.name  coordinates.latitude  \
# sensors_id
# 2150                119        AirNow             34.143900
# 25551               119        AirNow             33.901400
# 3523                119        AirNow             34.383300
# 3842                119        AirNow             34.199200
# 15731               119        AirNow             33.859662
#
#            coordinates.longitude        datetime_last.local  \
# sensors_id
# 2150                 -117.850800  2025-12-09T17:00:00-08:00
# 25551                -118.205000  2025-12-09T17:00:00-08:00
# 3523                 -118.528300  2025-12-09T17:00:00-08:00
# 3842                 -118.533100  2025-12-09T17:00:00-08:00
# 15731                -118.200707  2025-12-09T16:00:00-08:00
#
#                                geometry     instrument_name instrument_id
# sensors_id
# 2150          POINT (-117.8508 34.1439)  Government Monitor             2
# 25551          POINT (-118.205 33.9014)  Government Monitor             2
# 3523          POINT (-118.5283 34.3833)  Government Monitor             2
# 3842          POINT (-118.5331 34.1992)  Government Monitor             2
# 15731       POINT (-118.20071 33.85966)  Government Monitor             2
#
# [5 rows x 22 columns]

# %%
len(sensors_all_years_pm25_gdf)
# Out:
# 341

# %%
fig, ax = plt.subplots(figsize=(10, 10), label='Inline label');
sensors_all_years_pm25_gdf.plot(ax=ax, color='none', edgecolor='red');
la_bounds_gdf.plot(ax=ax, color='none', edgecolor='black');

# %%
sensors_all_years_gdf.head()
# Out:
#             station_id pollutant    name        datetime_first.utc  \
# sensors_id
# 25500             1052        CO  Pomona 2016-03-06 20:00:00+00:00
# 4272146           1052        NO  Pomona 2016-03-06 20:00:00+00:00
# 25501             1052       NO₂  Pomona 2016-03-06 20:00:00+00:00
# 4272073           1052       NOx  Pomona 2016-03-06 20:00:00+00:00
# 1888              1052        O₃  Pomona 2016-03-06 20:00:00+00:00
#
#                    datetime_last.utc             timezone  is_mobile  \
# sensors_id
# 25500      2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 4272146    2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 25501      2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 4272073    2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 1888       2025-12-10 01:00:00+00:00  America/Los_Angeles      False
#
#             is_monitor                                    bounds  country.id  \
# sensors_id
# 25500             True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
# 4272146           True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
# 25501             True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
# 4272073           True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
# 1888              True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
#
#             ... owner.id                         owner.name  provider.id  \
# sensors_id  ...
# 25500       ...        4  Unknown Governmental Organization          119
# 4272146     ...        4  Unknown Governmental Organization          119
# 25501       ...        4  Unknown Governmental Organization          119
# 4272073     ...        4  Unknown Governmental Organization          119
# 1888        ...        4  Unknown Governmental Organization          119
#
#            provider.name  coordinates.latitude coordinates.longitude  \
# sensors_id
# 25500             AirNow               34.0667             -117.7506
# 4272146           AirNow               34.0667             -117.7506
# 25501             AirNow               34.0667             -117.7506
# 4272073           AirNow               34.0667             -117.7506
# 1888              AirNow               34.0667             -117.7506
#
#                   datetime_last.local                   geometry  \
# sensors_id
# 25500       2025-12-09T17:00:00-08:00  POINT (-117.7506 34.0667)
# 4272146     2025-12-09T17:00:00-08:00  POINT (-117.7506 34.0667)
# 25501       2025-12-09T17:00:00-08:00  POINT (-117.7506 34.0667)
# 4272073     2025-12-09T17:00:00-08:00  POINT (-117.7506 34.0667)
# 1888        2025-12-09T17:00:00-08:00  POINT (-117.7506 34.0667)
#
#                instrument_name instrument_id
# sensors_id
# 25500       Government Monitor             2
# 4272146     Government Monitor             2
# 25501       Government Monitor             2
# 4272073     Government Monitor             2
# 1888        Government Monitor             2
#
# [5 rows x 22 columns]

# %%
sensors_all_years_gdf.to_file(r"../../Data/Outputs/sensors_all_years.geojson",driver="GeoJSON")

# %% [markdown]
# ### Visualizing spatial/temporal coverage by pollutant class

# %% [markdown]
# I want to plot the spatial coverage of sensors with complete temporal coverage (entries from 2016 to present) to see whether one pollutant class has uniquely good coverage across LA county

# %%
sensors_all_years_gdf.head(2)
# Out:
#             station_id pollutant    name        datetime_first.utc  \
# sensors_id
# 25500             1052        CO  Pomona 2016-03-06 20:00:00+00:00
# 4272146           1052        NO  Pomona 2016-03-06 20:00:00+00:00
#
#                    datetime_last.utc             timezone  is_mobile  \
# sensors_id
# 25500      2025-12-10 01:00:00+00:00  America/Los_Angeles      False
# 4272146    2025-12-10 01:00:00+00:00  America/Los_Angeles      False
#
#             is_monitor                                    bounds  country.id  \
# sensors_id
# 25500             True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
# 4272146           True  [-117.7506, 34.0667, -117.7506, 34.0667]         155
#
#             ... owner.id                         owner.name  provider.id  \
# sensors_id  ...
# 25500       ...        4  Unknown Governmental Organization          119
# 4272146     ...        4  Unknown Governmental Organization          119
#
#            provider.name  coordinates.latitude coordinates.longitude  \
# sensors_id
# 25500             AirNow               34.0667             -117.7506
# 4272146           AirNow               34.0667             -117.7506
#
#                   datetime_last.local                   geometry  \
# sensors_id
# 25500       2025-12-09T17:00:00-08:00  POINT (-117.7506 34.0667)
# 4272146     2025-12-09T17:00:00-08:00  POINT (-117.7506 34.0667)
#
#                instrument_name instrument_id
# sensors_id
# 25500       Government Monitor             2
# 4272146     Government Monitor             2
#
# [2 rows x 22 columns]

# %%
pollutant_classes = sensors_all_years_gdf['pollutant'].unique()

# %%
pollutant_classes
# Out:
# array(['CO', 'NO', 'NO₂', 'NOx', 'O₃', 'PM10', 'PM2.5', 'SO₂', 'PM1',
#        'Temperature (C)', 'Temperature (F)', 'RH', 'PM0.3 count'],
#       dtype=object)

# %%
len(pollutant_classes)
# Out:
# 13

# %% [markdown]
# https://matplotlib.org/stable/gallery/color/named_colors.html
#
# https://xkcd.com/color/rgb/

# %%
len(list(mcolors.TABLEAU_COLORS))
# Out:
# 10

# %%
int(np.random.randint(0,len(list(mcolors.TABLEAU_COLORS))))
# Out:
# 0

# %%
list(mcolors.TABLEAU_COLORS)[int(np.random.randint(0,len(list(mcolors.TABLEAU_COLORS))))]
# Out:
# 'tab:brown'

# %%
np.random.seed(42)
np.random.randint(0,2000)
# Out:
# 1126

# %%
np.random.seed(6)
fig, ax = plt.subplots(figsize=(10, 10), label='Inline label');

for pollutant in list(pollutant_classes):
    la_bounds_gdf.plot(ax=ax, color='none', edgecolor='black');
    sensors_all_years_gdf[sensors_all_years_gdf['pollutant'] == pollutant].plot(ax=ax, color=list(mcolors.TABLEAU_COLORS)[int(np.random.randint(0,len(list(mcolors.TABLEAU_COLORS))))], 
                                                                                edgecolor=list(mcolors.TABLEAU_COLORS)[int(np.random.randint(0,len(list(mcolors.TABLEAU_COLORS))))], 
                                                                                label=pollutant);
ax.set_title('Spatial coverage by sensor type for sensors with full temporal coverage (2016-2025)');
ax.legend();

# %% [markdown]
# This plot shows the spatial coverage of sensors which have oldest readings starting in 2016 and latest readings in 2025, divided by sensor type (pollutant class being measured). The plotted points will be overlapped, but it's been plotted sequentially, i.e. a `PM2.5` point indicates that no subsequent pollutant types: `SO2`, `PM1` . . . are present. I will plot this again in ArcGIS and get something easier to interpret.

# %%
sensors_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 1966 entries, 1502 to 14679598
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   station_id             1966 non-null   int64
#  1   pollutant              1966 non-null   object
#  2   name                   1966 non-null   object
#  3   datetime_first.utc     1966 non-null   datetime64[ns, UTC]
#  4   datetime_last.utc      1966 non-null   datetime64[ns, UTC]
#  5   timezone               1966 non-null   object
#  6   is_mobile              1966 non-null   bool
#  7   is_monitor             1966 non-null   bool
#  8   bounds                 1966 non-null   object
#  9   country.id             1966 non-null   int64
#  10  country.code           1966 non-null   object
#  11  country.name           1966 non-null   object
#  12  owner.id               1966 non-null   int64
#  13  owner.name             1966 non-null   object
#  14  provider.id            1966 non-null   int64
#  15  provider.name          1966 non-null   object
#  16  coordinates.latitude   1966 non-null   float64
#  17  coordinates.longitude  1966 non-null   float64
#  18  datetime_last.local    1966 non-null   object
#  19  geometry               1966 non-null   geometry
#  20  instrument_name        1966 non-null   object
#  21  instrument_id          1966 non-null   int64
# dtypes: bool(2), datetime64[ns, UTC](2), float64(2), geometry(1), int64(5), object(10)
# memory usage: 326.4+ KB

# %%
sensors_gdf.to_file("../../Data/Outputs/sensors_gdf.geojson", driver="GeoJSON")

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
sensors_gdf['datetime_last.utc'] = pd.to_datetime(sensors_gdf['datetime_last.utc'])

# %%
sensors_gdf.info()

# %%
sensors_gdf['pollutant'] = [sensors_gdf.iloc[i]['sensors']['parameter']['display_name'] for i in range(len(sensors_gdf))]

# %%
sensors_gdf['sensor_id'] = [sensors_gdf.iloc[i]['sensors']['id'] for i in range(len(sensors_gdf))]

# %%
sensors_gdf.drop(columns=['sensors'],inplace=True)

# %%
sensors_gdf.info()

# %%
sensors_gdf = sensors_gdf.sort_values(by='datetime_last.utc')

# %%
sensors_gdf.head()

# %%
sensors_gdf[(sensors_gdf['pollutant'] == 'PM2.5') & (sensors_gdf['datetime_last.utc'] > '2025-01-01')]

# %% [markdown]
# https://docs.python.org/3/library/datetime.html#datetime.datetime.now

# %%
today = dt.datetime.now(dt.timezone.utc)

# %%
one_week_ago = today - dt.timedelta(weeks=1)

# %%
active_pm2_5 = sensors_gdf[(sensors_gdf['pollutant'] == 'PM2.5') & (sensors_gdf['datetime_last.utc'] > one_week_ago)]

# %%
active_pm2_5 = active_pm2_5.sort_values(by='datetime_last.utc')

# %%
active_pm2_5.head()

# %%
sensors_gdf[sensors_gdf['id'] == 3778909]

# %%
active_pm2_5[active_pm2_5['sensor_id'] == 14152560]

# %%
active_pm2_5[active_pm2_5['id'] == 3778909]

# %%
active_pm2_5.info()

# %% [markdown]
# The `id` column can now be passed in to an Athena query

# %%
station_IDs = list(active_pm2_5['id'])

# %%
station_IDs[:10]

# %%
sensor_IDs = list(active_pm2_5['sensor_id'])
print(sensor_IDs[:5])

# %%
1/0

# %% [markdown]
# ## Athena

# %%
cursor = connect(
    s3_staging_dir="s3://la-openaq-athena-results-us-east-1/temp/",
    region_name="us-east-1"
).cursor()

# %% [markdown]
# cursor.execute("DROP TABLE openaq_db.openaqMeasurements;")

# %%
create_table = """
CREATE EXTERNAL TABLE IF NOT EXISTS openaq_db.openaqMeasurements (
  location_id INT,
  sensors_id INT,
  location STRING,
  datetime STRING,
  lat DOUBLE,
  lon DOUBLE,
  parameter STRING,
  units STRING,
  value DOUBLE
)
PARTITIONED BY (locationid STRING, year STRING, month STRING)
ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
WITH SERDEPROPERTIES ('serialization.format'=',','field.delim'=',')
LOCATION 's3://openaq-data-archive/records/csv.gz/'
TBLPROPERTIES ('skip.header.line.count'='1');
"""
cursor.execute(create_table)

# %% [markdown]
# month is handled as `str(today.month).zfill(2)` to ensure March -> 04

# %%
for location in station_IDs:
    cursor.execute(f"""
    ALTER TABLE openaq_db.openaqMeasurements ADD
    PARTITION (year='{today.year}', month='{str(today.month).zfill(2)}', locationid='{location}')
    LOCATION 's3://openaq-data-archive/records/csv.gz/locationid={location}/year={today.year}/month={str(today.month).zfill(2)}/';
    """)

# %%
cursor.execute(f"""
SELECT *
FROM (
    SELECT *,
           ROW_NUMBER() OVER (
               PARTITION BY sensors_id
               ORDER BY datetime DESC
           ) AS rn
    FROM openaq_db.openaqMeasurements
    WHERE year = '{today.year}'
      AND month = '{str(today.month).zfill(2)}'
      AND sensors_id IN {tuple(sensor_IDs)}
) sub
WHERE rn = 1
ORDER BY datetime DESC;
"""
)
records = cursor.fetchall()

# %%
records[3]

# %%
la_df = pd.DataFrame(data = records, columns=[
    "location_id", "sensors_id", "location", "datetime",
    "lat", "lon", "parameter", "units", "value",
    "partition_locationid", "year", "month", "day"
])
la_gdf = gpd.GeoDataFrame(
    la_df,
    geometry=[Point(xy) for xy in zip(la_df.lon, la_df.lat)],
    crs="EPSG:4326"
)

# %%
la_gdf.head()

# %%
la_gdf['datetime_utc'] = pd.to_datetime(la_gdf['datetime'])

# %%
la_gdf.drop(columns=['partition_locationid','year','month','day','datetime','lat','lon'],inplace=True)

# %%
la_gdf.info()

# %%
la_gdf.columns[:-2]

# %%
la_gdf.head()

# %%
gdf.to_file('../Data/Outputs/la_gdf.gpkg', driver='GPKG', layer='outliers_la_gdf')

# %%
la_gdf = gpd.read_file("../Data/Outputs/la_gdf.gpkg", layer='la_gdf')

# %%
la_gdf['value'].mean()

# %% [markdown]
# Physically, it is impossible for us to have a valid reading with `>1000 µg/m³`. Regardless, we can use the inter-quartile range of the data, and clip anything beyond 1.5x of this middle 50%.

# %%
la_gdf['value'].sort_values()

# %%
Q1 = la_gdf['value'].quantile(0.25)
Q3 = la_gdf['value'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

la_gdf_filtered = la_gdf[
    (la_gdf['value'] >= lower_bound) &
    (la_gdf['value'] <= upper_bound)
]

# %%
la_gdf_filtered['value'].sort_values()

# %%
la_gdf_filtered.to_file('../Data/Outputs/la_gdf.gpkg', driver='GPKG', layer='la_gdf_filtered')

# %%
np.random.seed(3)
fig, ax = plt.subplots(figsize=(10, 10), label='Inline label');

for pollutant in list(pollutant_classes):
    la_bounds_gdf.plot(ax=ax, color='none', edgecolor='black');
    sensors_all_years_gdf[sensors_all_years_gdf['pollutant'] == pollutant].plot(ax=ax, color=list(mcolors.TABLEAU_COLORS)[int(np.random.randint(0,len(list(mcolors.TABLEAU_COLORS))))], 
                                                                                edgecolor=list(mcolors.TABLEAU_COLORS)[int(np.random.randint(0,len(list(mcolors.TABLEAU_COLORS))))], 
                                                                                label=pollutant);
ax.set_title('Spatial coverage by sensor type for sensors with full temporal coverage (2016-2025)');
ax.legend();
