# %%
import pandas as pd

import geopandas as gpd

import requests

import datetime as dt
from pyathena import connect

# %%
recents_pm25 = gpd.read_file(r'../Data/Outputs/recents_pm25.geojson')

# %%
recents_pm25.head(3)
# Out:
#    station_id               name  sensor_id sensor_display_name  \
# 0        1200  Glendora - Laurel       2150               PM2.5
# 1        1948            EBAM 11      25551               PM2.5
# 2        1989      Santa Clarita       3523               PM2.5
#
#               timezone  is_mobile  is_monitor  owner.id  \
# 0  America/Los_Angeles      False        True         4
# 1  America/Los_Angeles      False        True         4
# 2  America/Los_Angeles      False        True         4
#
#                           owner.name  provider.id provider.name  \
# 0  Unknown Governmental Organization          119        AirNow
# 1  Unknown Governmental Organization          119        AirNow
# 2  Unknown Governmental Organization          119        AirNow
#
#    coordinates.latitude  coordinates.longitude        datetime_first.utc  \
# 0              34.14390             -117.85080 2016-03-06 20:00:00+00:00
# 1              33.90144             -118.20502 2016-03-06 20:00:00+00:00
# 2              34.38330             -118.52830 2016-03-06 20:00:00+00:00
#
#           datetime_last.utc sensor_type                     geometry
# 0 2025-10-24 19:00:00+00:00  pm25 µg/m³    POINT (34.1439 -117.8508)
# 1 2025-10-24 19:00:00+00:00  pm25 µg/m³  POINT (33.90144 -118.20502)
# 2 2025-10-24 19:00:00+00:00  pm25 µg/m³    POINT (34.3833 -118.5283)

# %%
recents_pm25.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   station_id             310 non-null    int32
#  1   name                   310 non-null    object
#  2   sensor_id              310 non-null    int32
#  3   sensor_display_name    310 non-null    object
#  4   timezone               310 non-null    object
#  5   is_mobile              310 non-null    bool
#  6   is_monitor             310 non-null    bool
#  7   owner.id               310 non-null    int32
#  8   owner.name             310 non-null    object
#  9   provider.id            310 non-null    int32
#  10  provider.name          310 non-null    object
#  11  coordinates.latitude   310 non-null    float64
#  12  coordinates.longitude  310 non-null    float64
#  13  datetime_first.utc     310 non-null    datetime64[ms, UTC]
#  14  datetime_last.utc      310 non-null    datetime64[ms, UTC]
#  15  sensor_type            310 non-null    object
#  16  geometry               310 non-null    geometry
# dtypes: bool(2), datetime64[ms, UTC](2), float64(2), geometry(1), int32(4), object(6)
# memory usage: 32.2+ KB

# %% [markdown]
# ```
# s3://openaq-data-archive/records/csv.gz/
# ├─ year=2025/
# │  ├─ month=10/
# │  │  ├─ locationid=2178/
# │  │  ├─ locationid=827/
# │  │  └─ ...
# │  └─ month=11/...
# └─ year=2024/...
# ```
#
# Example file path:
#
# ` /records/csv.gz/locationid=2178/year=2022/month=05/location-2178-20220503.csv.gz `

# %%
cursor = connect(
    s3_staging_dir="s3://la-openaq-athena-results-us-east-1/temp/",
    region_name="us-east-1"
).cursor()

# %% [markdown]
# cursor.execute("DROP TABLE openaq_db.openaqMeasurements")

# %%
cursor.execute("CREATE DATABASE IF NOT EXISTS openaq_db;")

# %%
create_table_query = """
CREATE EXTERNAL TABLE IF NOT EXISTS openaq_db.openaqMeasurements (
  location_id INT,
  sensors_id INT,
  location STRING,
  datetime STRING,
  lat DOUBLE,
  lon DOUBLE,
  parameter STRING,
  units STRING,
  value DOUBLE
)
PARTITIONED BY (locationid STRING, year STRING, month STRING)
ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe'
WITH SERDEPROPERTIES ('serialization.format'=',','field.delim'=',')
LOCATION 's3://openaq-data-archive/records/csv.gz/'
TBLPROPERTIES ('skip.header.line.count'='1');
"""

# %%
cursor.execute(create_table_query)

# %%
cursor.execute("""
SELECT lat, lon, value, typeof(lat), typeof(lon), typeof(value)
FROM openaq_db.openaqMeasurements
WHERE locationid = '1989'
LIMIT 3;
"""
)
print(cursor.fetchall())
# Out:
# [(None, None, None, 'double', 'double', 'double'), (None, None, None, 'double', 'double', 'double'), (None, None, None, 'double', 'double', 'double')]

# %%
cursor.execute("SHOW PARTITIONS openaq_db.openaqMeasurements;")
print(cursor.fetchall())
# Out:
# []

# %%
cursor.execute("""
SELECT *
FROM openaq_db.openaqMeasurements
WHERE locationid = '1989'
LIMIT 1;
"""
)
print(cursor.fetchall())
# Out:
# [(1989, 3523, '"Santa Clarita-1989"', '"2025-10-02T01:00:00-07:00"', None, None, '"pm25"', '"µg/m³"', None, '1989', '2025', '10')]

# %%
test_IDs = list(recents_pm25['station_id'][:3])
test_IDs
# Out:
# [1200, 1948, 1989]

# %%
now = pd.Timestamp(dt.datetime.now(), tz='UTC')

# %%
year = 2025
month = 10

# %%
for location in test_IDs:
    cursor.execute(f"""
    ALTER TABLE openaq_db.openaqMeasurements ADD
    PARTITION (year='{year}', month='{month}', locationid='{location}')
    LOCATION 's3://openaq-data-archive/records/csv.gz/locationid={location}/year={year}/month={month}/';
    """)

# %%
cursor.execute("SHOW PARTITIONS openaq_db.openaqMeasurements;")
print(cursor.fetchall())
# Out:
# [('locationid=1989/year=2025/month=10',), ('locationid=1948/year=2025/month=10',), ('locationid=1200/year=2025/month=10',)]

# %% [markdown]
# As expected, we see 3 partitions, each in October, 2025, corresponding to the three stations given

# %%
cursor.execute("SELECT * FROM openaq_db.openaqMeasurements LIMIT 1;")
print(cursor.fetchall())
# Out:
# [(1948, 13574377, '"EBAM 11-1948"', '"2025-10-07T01:00:00-07:00"', None, None, '"pm10"', '"µg/m³"', None, '1948', '2025', '10')]

# %% [markdown]
# This conforms to the expected units:
#
#     location_id INT,
#     sensors_id INT,
#     location STRING,
#     datetime STRING,
#     lat DOUBLE,
#     lon DOUBLE,
#     parameter STRING,
#     units STRING,
#     value DOUBLE
#
# And also appends the `locationid` (redundant), `year` and `month`

# %% [markdown]
# The data is `None`

# %% [markdown]
# Finding non-null (`None`) data:

# %%
cursor.execute("""
SELECT * 
FROM openaq_db.openaqMeasurements 
WHERE value IS NOT NULL
LIMIT 5;
""")
print(cursor.fetchall())
# Out:
# []

# %% [markdown]
# Out of the three locations, all readings are null within the month of October

# %% [markdown]
# ### Trying again with 50 stations:

# %% [markdown]
# cursor.execute("DROP TABLE openaq_db.openaqMeasurements")

# %%
cursor.execute(create_table_query)

# %%
test_IDs_50 = list(recents_pm25['station_id'][:50])
test_IDs_50[:5]
# Out:
# [1200, 1948, 1989, 2138, 5791]

# %%
for location in test_IDs_50:
    cursor.execute(f"""
    ALTER TABLE openaq_db.openaqMeasurements ADD
    PARTITION (year='{year}', month='{month}', locationid='{location}')
    LOCATION 's3://openaq-data-archive/records/csv.gz/locationid={location}/year={year}/month={month}/';
    """)

# %%
cursor.execute("""
SELECT * 
FROM openaq_db.openaqMeasurements 
WHERE value IS NOT NULL
LIMIT 5;
""")
print(cursor.fetchall())
# Out:
# []

# %% [markdown]
# Again, all data is null for all 50 stations. I will try to pull the same data

# %%
recents_pm25['sensor_id'][0]
# Out:
# np.int32(2150)

# %%
def download_file(url, save_path):
    response = requests.get(url, stream=True)
    
    if response.status_code == 200:
        with open(save_path, 'wb') as file:
            file.write(response.content)
        print(f'{url} downloaded')
    else:
        print(f'{url} failed')

# %%
def pull_records(location_id, year, month, day):
    day = float(str(day).zfill(2))
    url = f"https://openaq-data-archive.s3.amazonaws.com/records/csv.gz/locationid={location_id}/year={year}/month={month}/location-{location_id}-{year}{month}{day}.csv.gz"
    download_file(url,f"../Data/Outputs/station_{location_id}.csv.gz")
    
    return pd.read_csv(f"../Data/Outputs/station_{location_id}.csv.gz")

# %%
cursor.execute("SHOW PARTITIONS openaq_db.openaqMeasurements;")
print(cursor.fetchall()[0])
# Out:
# ('locationid=947177/year=2025/month=10',)

# %%
cursor.execute("""
SELECT * 
FROM openaq_db.openaqMeasurements 
WHERE locationid = '947177'
LIMIT 1;
""")
print(cursor.fetchall())
# Out:
# [(947177, 2000565, '"Oxnard ES (5918)-958227"', '"2025-10-19T00:00:51-07:00"', None, None, '"pm25"', '"µg/m³"', None, '947177', '2025', '10')]

# %%
url = f"https://openaq-data-archive.s3.amazonaws.com/records/csv.gz/locationid=947177/year=2025/month=10/location-947177-20251019.csv.gz"

# %%
download_file(url,f"../Data/Outputs/station_947177.csv.gz")
# Out:
# https://openaq-data-archive.s3.amazonaws.com/records/csv.gz/locationid=947177/year=2025/month=10/location-947177-20251019.csv.gz downloaded

# %%
station_947177 = pd.read_csv(r'../Data/Outputs/station_947177.csv.gz')
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
station_947177.head()
# Out:
#    location_id  sensors_id                 location  \
# 0       947177     2000565  Oxnard ES (5918)-958227
# 1       947177     2000565  Oxnard ES (5918)-958227
# 2       947177     2000565  Oxnard ES (5918)-958227
# 3       947177     2000565  Oxnard ES (5918)-958227
# 4       947177     2000565  Oxnard ES (5918)-958227
#
#                     datetime      lat        lon parameter  units  value
# 0  2025-10-19T00:00:51-07:00  34.1785 -118.36865      pm25  µg/m³  14.04
# 1  2025-10-19T00:06:24-07:00  34.1785 -118.36865      pm25  µg/m³  15.24
# 2  2025-10-19T01:01:49-07:00  34.1785 -118.36865      pm25  µg/m³  11.74
# 3  2025-10-19T01:07:22-07:00  34.1785 -118.36865      pm25  µg/m³  12.38
# 4  2025-10-19T01:12:55-07:00  34.1785 -118.36865      pm25  µg/m³  11.89

# %%
station_947177.iloc[0]
# Out:
# location_id                       947177
# sensors_id                       2000565
# location         Oxnard ES (5918)-958227
# datetime       2025-10-19T00:00:51-07:00
# lat                              34.1785
# lon                           -118.36865
# parameter                           pm25
# units                              µg/m³
# value                              14.04
# Name: 0, dtype: object

# %%
cursor.execute("""
SELECT * 
FROM openaq_db.openaqMeasurements 
WHERE locationid = '947177'
LIMIT 1;
""")
print(cursor.fetchall())
# Out:
# [(947177, 2000565, '"Oxnard ES (5918)-958227"', '"2025-10-05T00:05:30-07:00"', None, None, '"pm25"', '"µg/m³"', None, '947177', '2025', '10')]

# %% [markdown]
# Attempting to download data from `2025-10-05` to check whether it is also null when pulling directly from S3

# %%
url = f"https://openaq-data-archive.s3.amazonaws.com/records/csv.gz/locationid=947177/year=2025/month=10/location-947177-20251005.csv.gz"

# %%
download_file(url,f"../Data/Outputs/station_947177_05.csv.gz")
# Out:
# https://openaq-data-archive.s3.amazonaws.com/records/csv.gz/locationid=947177/year=2025/month=10/location-947177-20251005.csv.gz downloaded

# %%
station_947177_05 = pd.read_csv(r'../Data/Outputs/station_947177_05.csv.gz')

# %%
but
# Out:
#    location_id  sensors_id                 location  \
# 0       947177     2000565  Oxnard ES (5918)-958227
#
#                     datetime      lat        lon parameter  units  value
# 0  2025-10-05T00:05:30-07:00  34.1785 -118.36865      pm25  µg/m³   11.6

# %% [markdown]
# Via Athena, we got `[(947177, 2000565, '"Oxnard ES (5918)-958227"', '"2025-10-05T00:05:30-07:00"', None, None, '"pm25"', '"µg/m³"', None, '947177', '2025', '10')]` i.e. a `None`, but via S3 we see the value is `11.6`

# %% [markdown]
# The data via Athena doesn't even have `lat` or `long`, which are also supposed to be "double" data types:
#
# ```
#  location_id INT,
#     sensors_id INT,
#     location STRING,
#     datetime STRING,
#     lat DOUBLE,
#     lon DOUBLE,
#     parameter STRING,
#     units STRING,
#     value DOUBLE
# ```

# %% [markdown]
# There is likely an issue reading this type

# %% [markdown]
# #### I will try again but setting the dtype to FLOAT

# %% [markdown]
# cursor.execute("DROP TABLE openaq_db.openaqMeasurements")

# %%
create_table_query = """
CREATE EXTERNAL TABLE IF NOT EXISTS openaq_db.openaqMeasurements (
  location_id INT,
  sensors_id INT,
  location STRING,
  datetime STRING,
  lat FLOAT,
  lon FLOAT,
  parameter STRING,
  units STRING,
  value FLOAT
)
PARTITIONED BY (locationid STRING, year STRING, month STRING)
ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe'
WITH SERDEPROPERTIES ('serialization.format'=',','field.delim'=',')
LOCATION 's3://openaq-data-archive/records/csv.gz/'
TBLPROPERTIES ('skip.header.line.count'='1');
"""

# %%
cursor.execute(create_table_query)

# %%
for location in test_IDs_50:
    cursor.execute(f"""
    ALTER TABLE openaq_db.openaqMeasurements ADD
    PARTITION (year='{year}', month='{month}', locationid='{location}')
    LOCATION 's3://openaq-data-archive/records/csv.gz/locationid={location}/year={year}/month={month}/';
    """)

# %%
cursor.execute("""
SELECT * 
FROM openaq_db.openaqMeasurements 
WHERE locationid = '947177'
LIMIT 1;
""")
print(cursor.fetchall())
# Out:
# [(947177, 2000565, '"Oxnard ES (5918)-958227"', '"2025-10-08T00:02:01-07:00"', None, None, '"pm25"', '"µg/m³"', None, '947177', '2025', '10')]

# %%
station_947177_05[station_947177_05['datetime'] == '2025-10-05T00:05:30-07:00']
# Out:
#    location_id  sensors_id                 location  \
# 0       947177     2000565  Oxnard ES (5918)-958227
#
#                     datetime      lat        lon parameter  units  value
# 0  2025-10-05T00:05:30-07:00  34.1785 -118.36865      pm25  µg/m³   11.6

# %% [markdown]
# ### Another attempt

# %%
cursor.execute("DROP TABLE openaq_db.openaqMeasurements")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 cursor.execute("DROP TABLE openaq_db.openaqMeasurements")
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/cursor.py:219, in Cursor.execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle, on_start_query_execution, **kwargs)
#     211     self.result_set = self._result_set_class(
#     212         self._connection,
#     213         self._converter,
#    (...)    216         self._retry_config,
#     217     )
#     218 else:
# --> 219     raise OperationalError(query_execution.state_change_reason)
#     220 return self
#
# OperationalError: FAILED: SemanticException [Error 10001]: Table not found openaq_db.openaqMeasurements

# %%
template_create_table_query = """
CREATE EXTERNAL TABLE `openaqMeasurements`(
  `location_id` INT,
  `sensors_id` INT,
  `location` STRING,
  `datetime` STRING,
  `lat` float,
  `lon` float,
  `parameter` STRING,
  `units` STRING,
  `value` float
)
PARTITIONED BY (locationid string, year string, month string)
ROW FORMAT DELIMITED
  FIELDS TERMINATED BY ','
  ESCAPED BY '\\'
  LINES TERMINATED BY '\n'
LOCATION
  's3://openaq-data-archive/records/csv.gz/'
  TBLPROPERTIES ('skip.header.line.count'='1')
"""

# %%
cursor.execute(template_create_table_query)
# Out:
# Failed to execute query.
# Traceback (most recent call last):
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py", line 645, in _execute
#     query_id = retry_api_call(
#                ~~~~~~~~~~~~~~^
#         self._connection.client.start_query_execution,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<2 lines>...
#         **request,
#         ^^^^^^^^^^
#     ).get("QueryExecutionId")
#     ^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/util.py", line 196, in retry_api_call
#     return retry(func, *args, **kwargs)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 477, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 378, in iter
#     result = action(retry_state)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 400, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ~~~~~~~~~~~~~~~~~^^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py", line 443, in result
#     return self.__get_result()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py", line 395, in __get_result
#     raise self._exception
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 480, in __call__
#     result = fn(*args, **kwargs)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 1:8: mismatched input 'EXTERNAL'. Expecting: 'MATERIALIZED', 'MULTI', 'OR', 'PROTECTED', 'ROLE', 'SCHEMA', 'TABLE', 'VIEW'
# ---------------------------------------------------------------------------
# InvalidRequestException                   Traceback (most recent call last)
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py:645, in BaseCursor._execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle)
#     644 try:
# --> 645     query_id = retry_api_call(
#     646         self._connection.client.start_query_execution,
#     647         config=self._retry_config,
#     648         logger=_logger,
#     649         **request,
#     650     ).get("QueryExecutionId")
#     651 except Exception as e:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/util.py:196, in retry_api_call(func, config, logger, *args, **kwargs)
#     185 retry = tenacity.Retrying(
#     186     retry=retry_if_exception(_is_retryable),
#     187     stop=stop_after_attempt(config.attempt),
#    (...)    194     reraise=True,
#     195 )
# --> 196 return retry(func, *args, **kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     399 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400     self._add_action_func(lambda rs: rs.outcome.result())
#     401     return
#
# File ~/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     394 try:
# --> 395     raise self._exception
#     396 finally:
#     397     # Break a reference cycle with the exception in self._exception
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#
# InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 1:8: mismatched input 'EXTERNAL'. Expecting: 'MATERIALIZED', 'MULTI', 'OR', 'PROTECTED', 'ROLE', 'SCHEMA', 'TABLE', 'VIEW'
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 cursor.execute(template_create_table_query)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/cursor.py:190, in Cursor.execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle, on_start_query_execution, **kwargs)
#     164 """Execute a SQL query.
#     165
#     166 Args:
#    (...)    187                  on_start_query_execution=on_execution_started)
#     188 """
#     189 self._reset_state()
# --> 190 self.query_id = self._execute(
#     191     operation,
#     192     parameters=parameters,
#     193     work_group=work_group,
#     194     s3_staging_dir=s3_staging_dir,
#     195     cache_size=cache_size,
#     196     cache_expiration_time=cache_expiration_time,
#     197     result_reuse_enable=result_reuse_enable,
#     198     result_reuse_minutes=result_reuse_minutes,
#     199     paramstyle=paramstyle,
#     200 )
#     202 # Call user callbacks immediately after start_query_execution
#     203 # Both connection-level and execute-level callbacks are invoked if set
#     204 if self._on_start_query_execution:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py:653, in BaseCursor._execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle)
#     651     except Exception as e:
#     652         _logger.exception("Failed to execute query.")
# --> 653         raise DatabaseError(*e.args) from e
#     654 return query_id
#
# DatabaseError: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 1:8: mismatched input 'EXTERNAL'. Expecting: 'MATERIALIZED', 'MULTI', 'OR', 'PROTECTED', 'ROLE', 'SCHEMA', 'TABLE', 'VIEW'

# %% [markdown]
# create_table_query = """
# CREATE TABLE openaq_db.openaqMeasurements(
#   "location_id" INT,
#   "sensors_id" INT,
#   "location" STRING,
#   "datetime" STRING,
#   "lat" float,
#   "lon" float,
#   "parameter" STRING,
#   "units" STRING,
#   "value" float
# )
# PARTITIONED BY (locationid string, year string, month string)
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
#   'separatorChar' = ',',
#   'quoteChar' = '"',
#   'escapeChar' = '\\'
# )
# LOCATION 's3://openaq-data-archive/records/csv.gz/'
# TBLPROPERTIES ('skip.header.line.count'='1');
# """

# %%
cursor.execute(create_table_query)
# Out:
# Failed to execute query.
# Traceback (most recent call last):
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py", line 645, in _execute
#     query_id = retry_api_call(
#                ~~~~~~~~~~~~~~^
#         self._connection.client.start_query_execution,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<2 lines>...
#         **request,
#         ^^^^^^^^^^
#     ).get("QueryExecutionId")
#     ^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/util.py", line 196, in retry_api_call
#     return retry(func, *args, **kwargs)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 477, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 378, in iter
#     result = action(retry_state)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 400, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ~~~~~~~~~~~~~~~~~^^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py", line 443, in result
#     return self.__get_result()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py", line 395, in __get_result
#     raise self._exception
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 480, in __call__
#     result = fn(*args, **kwargs)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 12:1: mismatched input 'PARTITIONED'. Expecting: 'COMMENT', 'WITH', <EOF>
# ---------------------------------------------------------------------------
# InvalidRequestException                   Traceback (most recent call last)
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py:645, in BaseCursor._execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle)
#     644 try:
# --> 645     query_id = retry_api_call(
#     646         self._connection.client.start_query_execution,
#     647         config=self._retry_config,
#     648         logger=_logger,
#     649         **request,
#     650     ).get("QueryExecutionId")
#     651 except Exception as e:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/util.py:196, in retry_api_call(func, config, logger, *args, **kwargs)
#     185 retry = tenacity.Retrying(
#     186     retry=retry_if_exception(_is_retryable),
#     187     stop=stop_after_attempt(config.attempt),
#    (...)    194     reraise=True,
#     195 )
# --> 196 return retry(func, *args, **kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     399 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400     self._add_action_func(lambda rs: rs.outcome.result())
#     401     return
#
# File ~/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     394 try:
# --> 395     raise self._exception
#     396 finally:
#     397     # Break a reference cycle with the exception in self._exception
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#
# InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 12:1: mismatched input 'PARTITIONED'. Expecting: 'COMMENT', 'WITH', <EOF>
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 cursor.execute(create_table_query)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/cursor.py:190, in Cursor.execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle, on_start_query_execution, **kwargs)
#     164 """Execute a SQL query.
#     165
#     166 Args:
#    (...)    187                  on_start_query_execution=on_execution_started)
#     188 """
#     189 self._reset_state()
# --> 190 self.query_id = self._execute(
#     191     operation,
#     192     parameters=parameters,
#     193     work_group=work_group,
#     194     s3_staging_dir=s3_staging_dir,
#     195     cache_size=cache_size,
#     196     cache_expiration_time=cache_expiration_time,
#     197     result_reuse_enable=result_reuse_enable,
#     198     result_reuse_minutes=result_reuse_minutes,
#     199     paramstyle=paramstyle,
#     200 )
#     202 # Call user callbacks immediately after start_query_execution
#     203 # Both connection-level and execute-level callbacks are invoked if set
#     204 if self._on_start_query_execution:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py:653, in BaseCursor._execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle)
#     651     except Exception as e:
#     652         _logger.exception("Failed to execute query.")
# --> 653         raise DatabaseError(*e.args) from e
#     654 return query_id
#
# DatabaseError: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 12:1: mismatched input 'PARTITIONED'. Expecting: 'COMMENT', 'WITH', <EOF>

# %%
station_947177[station_947177['datetime'] == "2025-10-05"]
# Out:
# Empty DataFrame
# Columns: [location_id, sensors_id, location, datetime, lat, lon, parameter, units, value]
# Index: []

# %%
cursor.execute("""
SELECT * 
FROM openaq_db.openaqMeasurements 
WHERE locationid = '947177' AND datetime = '2025-10-19'
LIMIT 1;
""")
print(cursor.fetchall())
# Out:
# []

# %%
cursor.execute("""
SELECT * 
FROM openaq_db.openaqMeasurements 
WHERE locationid = '947177' AND value IS NOT NULL
LIMIT 1;
""")
print(cursor.fetchall())
# Out:
# []

# %%
station_947177.iloc[0]['value']
# Out:
# np.float64(14.04)

# %%
create_table_query = """
CREATE EXTERNAL TABLE IF NOT EXISTS openaq_db.openaqMeasurements (
  location_id INT,
  sensors_id INT,
  location STRING,
  datetime STRING,
  lat FLOAT,
  lon FLOAT,
  parameter STRING,
  units STRING,
  value FLOAT
)
PARTITIONED BY (locationid STRING, year STRING, month STRING)
ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe'
WITH SERDEPROPERTIES ('serialization.format'=',','field.delim'=',')
LOCATION 's3://openaq-data-archive/records/csv.gz/'
TBLPROPERTIES ('skip.header.line.count'='1');
"""

# %%
another_create_table_query = """
CREATE TABLE myopencsvtable (
  location_id INT,
  sensors_id INT,
  location STRING,
  datetime STRING,
  lat FLOAT,
  lon FLOAT,
  parameter STRING,
  units STRING,
  value FLOAT
)
ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
WITH SERDEPROPERTIES (
   'separatorChar' = ',',
   'quoteChar' = '"',
   'escapeChar' = '\\'
   )
STORED AS TEXTFILE
LOCATION 's3://openaq-data-archive/records/csv.gz/';
"""

cursor.execute(another_create_table_query)
# Out:
# Failed to execute query.
# Traceback (most recent call last):
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py", line 645, in _execute
#     query_id = retry_api_call(
#                ~~~~~~~~~~~~~~^
#         self._connection.client.start_query_execution,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<2 lines>...
#         **request,
#         ^^^^^^^^^^
#     ).get("QueryExecutionId")
#     ^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/util.py", line 196, in retry_api_call
#     return retry(func, *args, **kwargs)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 477, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 378, in iter
#     result = action(retry_state)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 400, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ~~~~~~~~~~~~~~~~~^^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py", line 443, in result
#     return self.__get_result()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py", line 395, in __get_result
#     raise self._exception
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 480, in __call__
#     result = fn(*args, **kwargs)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 12:1: mismatched input 'ROW'. Expecting: 'COMMENT', 'WITH', <EOF>
# ---------------------------------------------------------------------------
# InvalidRequestException                   Traceback (most recent call last)
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py:645, in BaseCursor._execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle)
#     644 try:
# --> 645     query_id = retry_api_call(
#     646         self._connection.client.start_query_execution,
#     647         config=self._retry_config,
#     648         logger=_logger,
#     649         **request,
#     650     ).get("QueryExecutionId")
#     651 except Exception as e:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/util.py:196, in retry_api_call(func, config, logger, *args, **kwargs)
#     185 retry = tenacity.Retrying(
#     186     retry=retry_if_exception(_is_retryable),
#     187     stop=stop_after_attempt(config.attempt),
#    (...)    194     reraise=True,
#     195 )
# --> 196 return retry(func, *args, **kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     399 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400     self._add_action_func(lambda rs: rs.outcome.result())
#     401     return
#
# File ~/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     394 try:
# --> 395     raise self._exception
#     396 finally:
#     397     # Break a reference cycle with the exception in self._exception
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#
# InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 12:1: mismatched input 'ROW'. Expecting: 'COMMENT', 'WITH', <EOF>
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[179], line 23
#       1 another_create_table_query = """
#       2 CREATE TABLE myopencsvtable (
#       3   location_id INT,
#    (...)     20 LOCATION 's3://openaq-data-archive/records/csv.gz/';
#      21 """
# ---> 23 cursor.execute(another_create_table_query)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/cursor.py:190, in Cursor.execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle, on_start_query_execution, **kwargs)
#     164 """Execute a SQL query.
#     165
#     166 Args:
#    (...)    187                  on_start_query_execution=on_execution_started)
#     188 """
#     189 self._reset_state()
# --> 190 self.query_id = self._execute(
#     191     operation,
#     192     parameters=parameters,
#     193     work_group=work_group,
#     194     s3_staging_dir=s3_staging_dir,
#     195     cache_size=cache_size,
#     196     cache_expiration_time=cache_expiration_time,
#     197     result_reuse_enable=result_reuse_enable,
#     198     result_reuse_minutes=result_reuse_minutes,
#     199     paramstyle=paramstyle,
#     200 )
#     202 # Call user callbacks immediately after start_query_execution
#     203 # Both connection-level and execute-level callbacks are invoked if set
#     204 if self._on_start_query_execution:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py:653, in BaseCursor._execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle)
#     651     except Exception as e:
#     652         _logger.exception("Failed to execute query.")
# --> 653         raise DatabaseError(*e.args) from e
#     654 return query_id
#
# DatabaseError: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 12:1: mismatched input 'ROW'. Expecting: 'COMMENT', 'WITH', <EOF>

# %% [markdown]
# cursor.execute("DROP TABLE openaq_db.openaqMeasurements")

# %%
cursor.execute(another_create_table_query)
# Out:
# Failed to execute query.
# Traceback (most recent call last):
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py", line 645, in _execute
#     query_id = retry_api_call(
#                ~~~~~~~~~~~~~~^
#         self._connection.client.start_query_execution,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<2 lines>...
#         **request,
#         ^^^^^^^^^^
#     ).get("QueryExecutionId")
#     ^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/util.py", line 196, in retry_api_call
#     return retry(func, *args, **kwargs)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 477, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 378, in iter
#     result = action(retry_state)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 400, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ~~~~~~~~~~~~~~~~~^^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py", line 443, in result
#     return self.__get_result()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py", line 395, in __get_result
#     raise self._exception
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py", line 480, in __call__
#     result = fn(*args, **kwargs)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "/home/daniel/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 12:1: mismatched input 'ROW'. Expecting: 'COMMENT', 'WITH', <EOF>
# ---------------------------------------------------------------------------
# InvalidRequestException                   Traceback (most recent call last)
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py:645, in BaseCursor._execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle)
#     644 try:
# --> 645     query_id = retry_api_call(
#     646         self._connection.client.start_query_execution,
#     647         config=self._retry_config,
#     648         logger=_logger,
#     649         **request,
#     650     ).get("QueryExecutionId")
#     651 except Exception as e:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/util.py:196, in retry_api_call(func, config, logger, *args, **kwargs)
#     185 retry = tenacity.Retrying(
#     186     retry=retry_if_exception(_is_retryable),
#     187     stop=stop_after_attempt(config.attempt),
#    (...)    194     reraise=True,
#     195 )
# --> 196 return retry(func, *args, **kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     399 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400     self._add_action_func(lambda rs: rs.outcome.result())
#     401     return
#
# File ~/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     394 try:
# --> 395     raise self._exception
#     396 finally:
#     397     # Break a reference cycle with the exception in self._exception
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/botocore/client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#
# InvalidRequestException: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 12:1: mismatched input 'ROW'. Expecting: 'COMMENT', 'WITH', <EOF>
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 cursor.execute(another_create_table_query)
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/cursor.py:190, in Cursor.execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle, on_start_query_execution, **kwargs)
#     164 """Execute a SQL query.
#     165
#     166 Args:
#    (...)    187                  on_start_query_execution=on_execution_started)
#     188 """
#     189 self._reset_state()
# --> 190 self.query_id = self._execute(
#     191     operation,
#     192     parameters=parameters,
#     193     work_group=work_group,
#     194     s3_staging_dir=s3_staging_dir,
#     195     cache_size=cache_size,
#     196     cache_expiration_time=cache_expiration_time,
#     197     result_reuse_enable=result_reuse_enable,
#     198     result_reuse_minutes=result_reuse_minutes,
#     199     paramstyle=paramstyle,
#     200 )
#     202 # Call user callbacks immediately after start_query_execution
#     203 # Both connection-level and execute-level callbacks are invoked if set
#     204 if self._on_start_query_execution:
#
# File ~/miniforge3/envs/la_env/lib/python3.14/site-packages/pyathena/common.py:653, in BaseCursor._execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle)
#     651     except Exception as e:
#     652         _logger.exception("Failed to execute query.")
# --> 653         raise DatabaseError(*e.args) from e
#     654 return query_id
#
# DatabaseError: An error occurred (InvalidRequestException) when calling the StartQueryExecution operation: line 12:1: mismatched input 'ROW'. Expecting: 'COMMENT', 'WITH', <EOF>

# %% [markdown]
# `` /records/csv.gz/locationid=2178/year=2022/month=05/location-2178-20220503.csv.gz ``
