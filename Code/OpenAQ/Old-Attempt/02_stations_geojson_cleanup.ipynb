# %% [markdown]
# conda install numpy=1.25

# %%
import geopandas as gpd

# %%
stations = gpd.read_file("../LA_Air_Quality_Map/Data/Outputs/stations.geojson")
# Out:
# Skipping field bounds: unsupported OGR type: 3

# %%
stations.head()
# Out:
#      id              name pollutant                          locality  \
# 0   847  South Long Beach      pm25                              None
# 1  1019          Pasadena        o3                              None
# 2  1036       Pico Rivera        o3                              None
# 3  1042    Piru - Pacific        o3                              None
# 4  1052            Pomona        co  Los Angeles-Long Beach-Santa Ana
#
#    isMobile  isMonitor                                    instruments  \
# 0     False       True  [ { "id": 2, "name": "Government Monitor" } ]
# 1     False       True  [ { "id": 2, "name": "Government Monitor" } ]
# 2     False       True  [ { "id": 2, "name": "Government Monitor" } ]
# 3     False       True  [ { "id": 2, "name": "Government Monitor" } ]
# 4     False       True  [ { "id": 2, "name": "Government Monitor" } ]
#
#                                              sensors distance  country.id  \
# ...

# %% [markdown]
# To make this dataframe more suited to ArcGIS i.e for better conversion to a GeoJSON, I'm going to remove nested features.
#
# I already coverted the "sensors" feature (nested) into a standalone "pollutant" feature. The "instruments" feature does not appear to be that important, so I'll simply drop it (along with sensors).

# %%
stations.head()
# Out:
#                   name pollutant                          locality  isMobile  \
# id
# 847   South Long Beach      pm25                              None     False
# 1019          Pasadena        o3                              None     False
# 1036       Pico Rivera        o3                              None     False
# 1042    Piru - Pacific        o3                              None     False
# 1052            Pomona        co  Los Angeles-Long Beach-Santa Ana     False
#
#       isMonitor                                    instruments  \
# id
# 847        True  [ { "id": 2, "name": "Government Monitor" } ]
# 1019       True  [ { "id": 2, "name": "Government Monitor" } ]
# 1036       True  [ { "id": 2, "name": "Government Monitor" } ]
# 1042       True  [ { "id": 2, "name": "Government Monitor" } ]
# 1052       True  [ { "id": 2, "name": "Government Monitor" } ]
#
#                                                 sensors distance  country.id  \
# id
# ...

# %%
stations.drop(columns=['instruments','sensors'],inplace=True)

# %%
stations.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# Like the DEM and LA County outline, the station data is in WGS 84.

# %%
stations.head()
# Out:
#      id              name pollutant                          locality  \
# 0   847  South Long Beach      pm25                              None
# 1  1019          Pasadena        o3                              None
# 2  1036       Pico Rivera        o3                              None
# 3  1042    Piru - Pacific        o3                              None
# 4  1052            Pomona        co  Los Angeles-Long Beach-Santa Ana
#
#    isMobile  isMonitor  country.id country.code   country.name  owner.id  \
# 0     False       True         155           US  United States         4
# 1     False       True         155           US  United States         4
# 2     False       True         155           US  United States         4
# 3     False       True         155           US  United States         4
# 4     False       True         155           US  United States         4
#
#                           owner.name  provider.id provider.name  \
# ...

# %%
stations.to_file("Data/Outputs/edited_stations.geojson", driver="GeoJSON")

# %%
stations['geometry']
# Out:
# id
# 847        POINT (-118.17528 33.79222)
# 1019         POINT (-118.1081 34.0833)
# 1036         POINT (-118.0592 34.0131)
# 1042           POINT (-118.81 34.4044)
# 1052         POINT (-117.7506 34.0667)
#                       ...
# 4550834     POINT (-118.8001 34.28459)
# 4683223    POINT (-118.80014 34.28448)
# 4869634    POINT (-118.34638 34.04782)
# 5026276     POINT (-118.41222 34.2615)
# 5161748    POINT (-118.61775 34.42187)
# Name: geometry, Length: 386, dtype: geometry

# %%
stations[:1]
# Out:
#                  name pollutant locality  isMobile  isMonitor distance  \
# id
# 847  South Long Beach      pm25     None     False       True     None
#
#      country.id country.code   country.name  owner.id  \
# id
# 847         155           US  United States         4
#
#                             owner.name  provider.id provider.name  \
# id
# 847  Unknown Governmental Organization          119        AirNow
#
#      coordinates.latitude  coordinates.longitude       datetimeFirst.local  \
# id
# 847             33.792221            -118.175278 2016-03-06 20:00:00+00:00
#
#            datetimeLast.local                     geometry
# id
# 847 2022-05-05 22:00:00+00:00  POINT (-118.17528 33.79222)

# %%
stations.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 386 entries, 847 to 5161748
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   386 non-null    object
#  1   pollutant              386 non-null    object
#  2   locality               38 non-null     object
#  3   isMobile               386 non-null    bool
#  4   isMonitor              386 non-null    bool
#  5   distance               0 non-null      object
#  6   country.id             386 non-null    int32
#  7   country.code           386 non-null    object
#  8   country.name           386 non-null    object
#  9   owner.id               386 non-null    int32
#  10  owner.name             386 non-null    object
#  11  provider.id            386 non-null    int32
#  12  provider.name          386 non-null    object
#  13  coordinates.latitude   386 non-null    float64
# ...

# %%
stations.drop(columns='distance',inplace=True)

# %%
stations.to_file("Data/Outputs/edited_stations1.geojson", driver="GeoJSON")

# %%
stations.geom_type.value_counts()
# Out:
# Point    386
# Name: count, dtype: int64
